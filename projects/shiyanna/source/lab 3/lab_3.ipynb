# %% [markdown]
# Формируем данные

# %%
import os
import re 

def get_file_tokens(path):
    tokens = []
    with open(path, "r") as f:
        line = f.readline()
        while line:
            if line:
                if line!='\n':
                    token = line.split('\t')
                    t=token[len(token)-1]
                    tokens.append(t[:len(t)-1])
            line = f.readline()
    f.close()
    return tokens

# %%
import os
import glob

def GetAllTokens(rootDir):
    tokens=[]
    for lists in os.listdir(rootDir):
                    path = os.path.join(rootDir, lists)
                    for filename in glob.glob(path+'\\*'):
                       tokens = tokens + get_file_tokens(filename)
    return tokens

# %%
lemmas = GetAllTokens('D:\\S\\NLP\\nlp-22-autumn\\projects\\shiyan_v3\\assets\\annotated-corpus\\train\\')

# %%
lemmas+=GetAllTokens('D:\\S\\NLP\\nlp-22-autumn\\projects\\shiyan_v3\\assets\\annotated-corpus\\test\\')

# %%
def write_dict(path,t):
    with open(path, "w") as f:
        for i in t:
            f.write(i)
            f.write('\n')
    f.close()

# %%
write_dict("lemmas_p.txt",lemmas)

# %% [markdown]
# Удаление знаков пунктуации

# %%
import re

lemm=[]
for l in lemmas:
    if not re.match('\.|\?|\,|\:|\!|\<|\>|\-|\'|\"|\:|\(|\)|\;',l):
        lemm.append(l)

# %%
lemm
# Out:
# ['From',
#  'mathew',
#  'mathew@mantis.co.uk',
#  'Subject',
#  'Alt',
#  'Atheism',
#  'FAQ',
#  'Atheist',
#  'Resources',
#  'Summary',
#  'Books',
#  'address',
#  'music',
#  'anything',
#  'related',
#  'to',
#  'atheism',
#  'Keywords',
#  'FAQ',
#  'atheism',
#  'book',
#  'music',
#  'fiction',
#  'address',
#  'contact',
#  'Expires',
#  'Thu',
#  '29 Apr 1993',
#  '11:57:19',
#  'GMT',
#  'Distribution',
#  'world',
#  'Organization',
#  'Mantis',
#  'Consultants',
#  'Cambridge',
#  'UK',
#  'Supersedes',
#  '19930301143317@mantis.co.uk',
#  'Lines',
#  '2',
#  '9',
#  '0',
#  'Archive',
#  'name',
#  'atheism',
#  '/',
#  'resource',
#  'Alt',
#  'atheism',
#  'archive',
#  'name',
#  'resource',
#  'Last',
#  'modified',
#  '11 December 1992',
#  'Version',
#  '1',
#  '0',
#  'Atheist',
#  'Resources',
#  'Addresses',
#  'of',
#  'Atheist',
#  'Organizations',
#  'USA',
#  'FREEDOM',
#  'FROM',
#  'RELIGION',
#  'FOUNDATION',
#  'Darwin',
#  'fish',
#  'bumper',
#  'sticker',
#  'and',
#  'assorted',
#  'other',
#  'atheist',
#  'paraphernalia',
#  'are',
#  'available',
#  'from',
#  'the',
#  'Freedom',
#  'From',
#  'Religion',
#  'Foundation',
#  'in',
#  'the',
#  'US',
#  'Write',
#  'to',
#  'FFRF',
#  'P',
#  'O',
#  'Box',
#  '7',
#  '5',
#  '0',
#  'Madison',
#  'WI',
#  '53701',
#  'Telephone',
#  'EVOLUTION',
#  'DESIGNS',
#  'Evolution',
#  'Designs',
#  'sell',
#  'the',
#  'Darwin',
#  'fish',
#  "It's",
#  'a',
#  'fish',
#  'symbol',
#  'like',
#  'the',
#  'one',
#  'Christians',
#  'stick',
#  'on',
#  'their',
#  'car',
#  'but',
#  'with',
#  'foot',
#  'and',
#  'the',
#  'word',
#  'Darwin',
#  'written',
#  'inside',
#  'The',
#  'deluxe',
#  'moulded',
#  '3',
#  'D',
#  'plastic',
#  'fish',
#  'is',
#  '$4.95',
#  'postpaid',
#  'in',
#  'the',
#  'US',
#  'Write',
#  'to',
#  'Evolution',
#  'Designs',
#  '7',
#  '1',
#  '1',
#  '9',
#  'Laurel',
#  'Canyon',
#  '#',
#  '4',
#  'North',
#  'Hollywood',
#  'CA',
#  '91605',
#  'People',
#  'in',
#  'the',
#  'San',
#  'Francisco',
#  'Bay',
#  'area',
#  'can',
#  'get',
#  'Darwin',
#  'Fish',
#  'from',
#  'Lynn',
#  'Gold',
#  'try',
#  'mailing',
#  'figmo@netcom.com',
#  'For',
#  'net',
#  'people',
#  'who',
#  'go',
#  'to',
#  'Lynn',
#  'directly',
#  'the',
#  'price',
#  'is',
#  '$4.95',
#  'per',
#  'fish',
#  'AMERICAN',
#  'ATHEIST',
#  'PRESS',
#  'AAP',
#  'publish',
#  'various',
#  'atheist',
#  'book',
#  'critique',
#  'of',
#  'the',
#  'Bible',
#  'list',
#  'of',
#  'Biblical',
#  'contradiction',
#  'and',
#  'so',
#  'on',
#  'One',
#  'such',
#  'book',
#  'is',
#  'The',
#  'Bible',
#  'Handbook',
#  'by',
#  'W',
#  'P',
#  'Ball',
#  'and',
#  'G',
#  'W',
#  'Foote',
#  'American',
#  'Atheist',
#  'Press',
#  '3',
#  '7',
#  '2',
#  'pp',
#  'ISBN',
#  '0-910309',
#  '2',
#  '6',
#  '4',
#  '2',
#  'nd',
#  'edition',
#  '1',
#  '9',
#  '8',
#  '6',
#  'Bible',
#  'contradiction',
#  'absurdity',
#  'atrocity',
#  'immorality',
#  'contains',
#  'Ball',
#  'Foote',
#  'The',
#  'Bible',
#  'Contradicts',
#  'Itself',
#  'AAP',
#  'Based',
#  'on',
#  'the',
#  'King',
#  'James',
#  'version',
#  'of',
#  'the',
#  'Bible',
#  'Write',
#  'to',
#  'American',
#  'Atheist',
#  'Press',
#  'P',
#  'O',
#  'Box',
#  '140195',
#  'Austin',
#  'TX',
#  '78714-0195',
#  'or',
#  '7',
#  '2',
#  '1',
#  '5',
#  'Cameron',
#  'Road',
#  'Austin',
#  'TX',
#  '78752-2973',
#  'Telephone',
#  'Fax',
#  'PROMETHEUS',
#  'BOOKS',
#  'Sell',
#  'book',
#  'including',
#  "Haught's",
#  'Holy',
#  'Horrors',
#  'see',
#  'below',
#  'Write',
#  'to',
#  '7',
#  '0',
#  '0',
#  'East',
#  'Amherst',
#  'Street',
#  'Buffalo',
#  'New',
#  'York',
#  '14215',
#  'Telephone',
#  'An',
#  'alternate',
#  'address',
#  'which',
#  'may',
#  'be',
#  'newer',
#  'or',
#  'older',
#  'is',
#  'Prometheus',
#  'Books',
#  '5',
#  '9',
#  'Glenn',
#  'Drive',
#  'Buffalo',
#  'NY',
#  '14228-2197',
#  'AFRICAN',
#  'AMERICANS',
#  'FOR',
#  'HUMANISM',
#  'An',
#  'organization',
#  'promoting',
#  'black',
#  'secular',
#  'humanism',
#  'and',
#  'uncovering',
#  'the',
#  'history',
#  'of',
#  'black',
#  'freethought',
#  'They',
#  'publish',
#  'a',
#  'quarterly',
#  'newsletter',
#  'AAH',
#  'EXAMINER',
#  'Write',
#  'to',
#  'Norm',
#  'R',
#  'Allen',
#  'Jr',
#  'African',
#  'Americans',
#  'for',
#  'Humanism',
#  'P',
#  'O',
#  'Box',
#  '6',
#  '6',
#  '4',
#  'Buffalo',
#  'NY',
#  '14226',
#  'United',
#  'Kingdom',
#  'Rationalist',
#  'Press',
#  'Association',
#  'National',
#  'Secular',
#  'Society',
#  '8',
#  '8',
#  'Islington',
#  'High',
#  'Street',
#  '7',
#  '0',
#  '2',
#  'Holloway',
#  'Road',
#  'London',
#  'N',
#  '1',
#  '8',
#  'EW',
#  'London',
#  'N',
#  '1',
#  '9',
#  '3',
#  'NL',
#  'nl',
#  'NL',
#  '071 226',
#  '7',
#  '2',
#  '5',
#  '1',
#  '0',
#  '7',
#  '1',
#  '2',
#  '7',
#  '2',
#  '1',
#  '2',
#  '6',
#  '6',
#  'British',
#  'Humanist',
#  'Association',
#  'South',
#  'Place',
#  'Ethical',
#  'Society',
#  '1',
#  '4',
#  "Lamb's",
#  'Conduit',
#  'Passage',
#  'Conway',
#  'Hall',
#  'London',
#  'WC',
#  '1',
#  'R',
#  '4',
#  'RH',
#  'Red',
#  'Lion',
#  'Square',
#  'square',
#  'Square',
#  '071 430',
#  '0',
#  '9',
#  '0',
#  '8',
#  'London',
#  'WC',
#  '1',
#  'R',
#  '4',
#  'RL',
#  'fax 071 430',
#  '1',
#  '2',
#  '7',
#  '1',
#  '0',
#  '7',
#  '1',
#  '8',
#  '3',
#  '1',
#  '7',
#  '7',
#  '2',
#  '3',
#  'The',
#  'National',
#  'Secular',
#  'Society',
#  'publish',
#  'The',
#  'Freethinker',
#  'a',
#  'monthly',
#  'magazine',
#  'founded',
#  'in',
#  '1',
#  '8',
#  '8',
#  '1',
#  'Germany',
#  'IBKA',
#  'e',
#  'V',
#  'Internationaler',
#  'Bund',
#  'der',
#  'Konfessionslosen',
#  'und',
#  'Atheisten',
#  'Postfach',
#  '8',
#  '8',
#  '0',
#  'D',
#  '1',
#  '0',
#  '00 Berlin 41',
#  'Germany',
#  'IBKA',
#  'publish',
#  'a',
#  'journal',
#  'MIZ',
#  'Materialien',
#  'und',
#  'Informationen',
#  'zur',
#  'Zeit',
#  'Politisches',
#  'Journal',
#  'der',
#  'Konfessionslosesn',
#  'und',
#  'Atheisten',
#  'Hrsg',
#  'IBKA',
#  'e',
#  'V',
#  'MIZ',
#  'Vertrieb',
#  'Postfach',
#  '8',
#  '8',
#  '0',
#  'D',
#  '1',
#  '0',
#  '00 Berlin 41',
#  'Germany',
#  'For',
#  'atheist',
#  'book',
#  'write',
#  'to',
#  'IBDK',
#  'Internationaler',
#  'B',
#  'ucherdienst',
#  'der',
#  'Konfessionslosen',
#  'Postfach',
#  '3',
#  '0',
#  '0',
#  '5',
#  'D',
#  '3',
#  '0',
#  '00 Hannover 1',
#  'Germany',
#  'Telephone',
#  '0511/2112',
#  '1',
#  '6',
#  'Books',
#  'Fiction',
#  'THOMAS',
#  'M',
#  'DISCH',
#  'The',
#  'Santa',
#  'Claus',
#  'Compromise',
#  'Short',
#  'story',
#  'The',
#  'ultimate',
#  'proof',
#  'that',
#  'Santa',
#  'exists',
#  'All',
#  'character',
#  'and',
#  'event',
#  'are',
#  'fictitious',
#  'Any',
#  'similarity',
#  'to',
#  'living',
#  'or',
#  'dead',
#  'god',
#  'uh',
#  'well',
#  'WALTER',
#  'M',
#  'MILLER',
#  'JR',
#  'A',
#  'Canticle',
#  'for',
#  'Leibowitz',
#  'One',
#  'gem',
#  'in',
#  'this',
#  'post',
#  'atomic',
#  'doomsday',
#  'novel',
#  'is',
#  'the',
#  'monk',
#  'who',
#  'spent',
#  'their',
#  'life',
#  'copying',
#  'blueprint',
#  'from',
#  'Saint',
#  'Leibowitz',
#  'filling',
#  'the',
#  'sheet',
#  'of',
#  'paper',
#  'with',
#  'ink',
#  'and',
#  'leaving',
#  'white',
#  'line',
#  'and',
#  'letter',
#  'EDGAR',
#  'PANGBORN',
#  'Davy',
#  'Post',
#  'atomic',
#  'doomsday',
#  'novel',
#  'set',
#  'in',
#  'clerical',
#  'state',
#  'The',
#  'church',
#  'for',
#  'example',
#  'forbids',
#  'that',
#  'anyone',
#  'produce',
#  'describe',
#  'or',
#  'use',
#  'any',
#  'substance',
#  'containing',
#  'atom',
#  'PHILIP',
#  'K',
#  'DICK',
#  'Philip',
#  'K',
#  'Dick',
#  'Dick',
#  'wrote',
#  'many',
#  'philosophical',
#  'and',
#  'thought',
#  'provoking',
#  'short',
#  'story',
#  'and',
#  'novel',
#  'His',
#  'story',
#  'are',
#  'bizarre',
#  'at',
#  'time',
#  'but',
#  'very',
#  'approachable',
#  'He',
#  'wrote',
#  'mainly',
#  'SF',
#  'but',
#  'he',
#  'wrote',
#  'about',
#  'people',
#  'truth',
#  'and',
#  'religion',
#  'rather',
#  'than',
#  'technology',
#  'Although',
#  'he',
#  'often',
#  'believed',
#  'that',
#  'he',
#  'had',
#  'met',
#  'some',
#  'sort',
#  'of',
#  'God',
#  'he',
#  'remained',
#  'sceptical',
#  'Amongst',
#  'his',
#  'novel',
#  'the',
#  'following',
#  'are',
#  'of',
#  'some',
#  'relevance',
#  'Galactic',
#  'Pot',
#  'Healer',
#  'A',
#  'fallible',
#  'alien',
#  'deity',
#  'summons',
#  'a',
#  'group',
#  'of',
#  'Earth',
#  'craftsman',
#  'and',
#  'woman',
#  'to',
#  'a',
#  'remote',
#  'planet',
#  'to',
#  'raise',
#  'a',
#  'giant',
#  'cathedral',
#  'from',
#  'beneath',
#  'the',
#  'ocean',
#  'When',
#  'the',
#  'deity',
#  'begin',
#  'to',
#  'demand',
#  'faith',
#  'from',
#  'the',
#  'earthers',
#  'pot',
#  'healer',
#  'Joe',
#  'Fernwright',
#  'is',
#  'unable',
#  'to',
#  'comply',
#  'A',
#  'polished',
#  'ironic',
#  'and',
#  'amusing',
#  'novel',
#  'A',
#  'Maze',
#  'of',
#  'Death',
#  'Noteworthy',
#  'for',
#  'it',
#  'description',
#  'of',
#  'a',
#  'technology',
#  'based',
#  'religion',
#  'VALIS',
#  'The',
#  'schizophrenic',
#  'hero',
#  'search',
#  'for',
#  'the',
#  'hidden',
#  'mystery',
#  'of',
#  'Gnostic',
#  'Christianity',
#  'after',
#  'reality',
#  'is',
#  'fired',
#  'into',
#  'his',
#  'brain',
#  'by',
#  'a',
#  'pink',
#  'laser',
#  'beam',
#  'of',
#  'unknown',
#  'but',
#  'possibly',
#  'divine',
#  'origin',
#  'He',
#  'is',
#  'accompanied',
#  'by',
#  'his',
#  'dogmatic',
#  'and',
#  'dismissively',
#  'atheist',
#  'friend',
#  'and',
#  'assorted',
#  'other',
#  'odd',
#  'character',
#  'The',
#  'Divine',
#  'Invasion',
#  'God',
#  'invades',
#  'Earth',
#  'by',
#  'making',
#  'a',
#  'young',
#  'woman',
#  'pregnant',
#  'a',
#  'she',
#  'return',
#  'from',
#  'another',
#  'star',
#  'system',
#  'Unfortunately',
#  'she',
#  'is',
#  'terminally',
#  'ill',
#  'and',
#  'must',
#  'be',
#  'assisted',
#  'by',
#  'a',
#  'dead',
#  'man',
#  'whose',
#  'brain',
#  'is',
#  'wired',
#  'to',
#  '2',
#  '4',
#  'hour',
#  'easy',
#  'listening',
#  'music',
#  'MARGARET',
#  'ATWOOD',
#  'The',
#  "Handmaid's",
#  'Tale',
#  'A',
#  'story',
#  'based',
#  'on',
#  'the',
#  'premise',
#  'that',
#  'the',
#  'US',
#  'Congress',
#  'is',
#  'mysteriously',
#  'assassinated',
#  'and',
#  'fundamentalist',
#  'quickly',
#  'take',
#  'charge',
#  'of',
#  'the',
#  'nation',
#  'to',
#  'set',
#  'it',
#  'right',
#  'again',
#  'The',
#  'book',
#  'is',
#  'the',
#  'diary',
#  'of',
#  'a',
#  "woman's",
#  'life',
#  'a',
#  'she',
#  'try',
#  'to',
#  'live',
#  'under',
#  'the',
#  'new',
#  'Christian',
#  'theocracy',
#  "Women's",
#  'right',
#  'to',
#  'own',
#  'property',
#  'is',
#  'revoked',
#  'and',
#  'their',
#  'bank',
#  'account',
#  'are',
#  'closed',
#  'sinful',
#  'luxury',
#  'are',
#  'outlawed',
#  'and',
#  'the',
#  'radio',
#  'is',
#  'only',
#  'used',
#  'for',
#  'reading',
#  'from',
#  'the',
#  'Bible',
#  'Crimes',
#  'are',
#  'punished',
#  'retroactively',
#  'doctor',
#  'who',
#  'performed',
#  'legal',
#  'abortion',
#  'in',
#  'the',
#  'old',
#  'world',
#  'are',
#  'hunted',
#  'down',
#  'and',
#  'hanged',
#  "Atwood's",
#  'writing',
#  'style',
#  'is',
#  'difficult',
#  'to',
#  'get',
#  'used',
#  'to',
#  'at',
#  'first',
#  'but',
#  'the',
#  'tale',
#  'grows',
#  'more',
#  'and',
#  'more',
#  'chilling',
#  'a',
#  'it',
#  'go',
#  'on',
#  ...]

# %% [markdown]
# Приведение к нижнему регистру

# %%
lem=[]
for l in lemm:
    lem.append(l.lower())

# %%
lem
# Out:
# ['from',
#  'mathew',
#  'mathew@mantis.co.uk',
#  'subject',
#  'alt',
#  'atheism',
#  'faq',
#  'atheist',
#  'resources',
#  'summary',
#  'books',
#  'address',
#  'music',
#  'anything',
#  'related',
#  'to',
#  'atheism',
#  'keywords',
#  'faq',
#  'atheism',
#  'book',
#  'music',
#  'fiction',
#  'address',
#  'contact',
#  'expires',
#  'thu',
#  '29 apr 1993',
#  '11:57:19',
#  'gmt',
#  'distribution',
#  'world',
#  'organization',
#  'mantis',
#  'consultants',
#  'cambridge',
#  'uk',
#  'supersedes',
#  '19930301143317@mantis.co.uk',
#  'lines',
#  '2',
#  '9',
#  '0',
#  'archive',
#  'name',
#  'atheism',
#  '/',
#  'resource',
#  'alt',
#  'atheism',
#  'archive',
#  'name',
#  'resource',
#  'last',
#  'modified',
#  '11 december 1992',
#  'version',
#  '1',
#  '0',
#  'atheist',
#  'resources',
#  'addresses',
#  'of',
#  'atheist',
#  'organizations',
#  'usa',
#  'freedom',
#  'from',
#  'religion',
#  'foundation',
#  'darwin',
#  'fish',
#  'bumper',
#  'sticker',
#  'and',
#  'assorted',
#  'other',
#  'atheist',
#  'paraphernalia',
#  'are',
#  'available',
#  'from',
#  'the',
#  'freedom',
#  'from',
#  'religion',
#  'foundation',
#  'in',
#  'the',
#  'us',
#  'write',
#  'to',
#  'ffrf',
#  'p',
#  'o',
#  'box',
#  '7',
#  '5',
#  '0',
#  'madison',
#  'wi',
#  '53701',
#  'telephone',
#  'evolution',
#  'designs',
#  'evolution',
#  'designs',
#  'sell',
#  'the',
#  'darwin',
#  'fish',
#  "it's",
#  'a',
#  'fish',
#  'symbol',
#  'like',
#  'the',
#  'one',
#  'christians',
#  'stick',
#  'on',
#  'their',
#  'car',
#  'but',
#  'with',
#  'foot',
#  'and',
#  'the',
#  'word',
#  'darwin',
#  'written',
#  'inside',
#  'the',
#  'deluxe',
#  'moulded',
#  '3',
#  'd',
#  'plastic',
#  'fish',
#  'is',
#  '$4.95',
#  'postpaid',
#  'in',
#  'the',
#  'us',
#  'write',
#  'to',
#  'evolution',
#  'designs',
#  '7',
#  '1',
#  '1',
#  '9',
#  'laurel',
#  'canyon',
#  '#',
#  '4',
#  'north',
#  'hollywood',
#  'ca',
#  '91605',
#  'people',
#  'in',
#  'the',
#  'san',
#  'francisco',
#  'bay',
#  'area',
#  'can',
#  'get',
#  'darwin',
#  'fish',
#  'from',
#  'lynn',
#  'gold',
#  'try',
#  'mailing',
#  'figmo@netcom.com',
#  'for',
#  'net',
#  'people',
#  'who',
#  'go',
#  'to',
#  'lynn',
#  'directly',
#  'the',
#  'price',
#  'is',
#  '$4.95',
#  'per',
#  'fish',
#  'american',
#  'atheist',
#  'press',
#  'aap',
#  'publish',
#  'various',
#  'atheist',
#  'book',
#  'critique',
#  'of',
#  'the',
#  'bible',
#  'list',
#  'of',
#  'biblical',
#  'contradiction',
#  'and',
#  'so',
#  'on',
#  'one',
#  'such',
#  'book',
#  'is',
#  'the',
#  'bible',
#  'handbook',
#  'by',
#  'w',
#  'p',
#  'ball',
#  'and',
#  'g',
#  'w',
#  'foote',
#  'american',
#  'atheist',
#  'press',
#  '3',
#  '7',
#  '2',
#  'pp',
#  'isbn',
#  '0-910309',
#  '2',
#  '6',
#  '4',
#  '2',
#  'nd',
#  'edition',
#  '1',
#  '9',
#  '8',
#  '6',
#  'bible',
#  'contradiction',
#  'absurdity',
#  'atrocity',
#  'immorality',
#  'contains',
#  'ball',
#  'foote',
#  'the',
#  'bible',
#  'contradicts',
#  'itself',
#  'aap',
#  'based',
#  'on',
#  'the',
#  'king',
#  'james',
#  'version',
#  'of',
#  'the',
#  'bible',
#  'write',
#  'to',
#  'american',
#  'atheist',
#  'press',
#  'p',
#  'o',
#  'box',
#  '140195',
#  'austin',
#  'tx',
#  '78714-0195',
#  'or',
#  '7',
#  '2',
#  '1',
#  '5',
#  'cameron',
#  'road',
#  'austin',
#  'tx',
#  '78752-2973',
#  'telephone',
#  'fax',
#  'prometheus',
#  'books',
#  'sell',
#  'book',
#  'including',
#  "haught's",
#  'holy',
#  'horrors',
#  'see',
#  'below',
#  'write',
#  'to',
#  '7',
#  '0',
#  '0',
#  'east',
#  'amherst',
#  'street',
#  'buffalo',
#  'new',
#  'york',
#  '14215',
#  'telephone',
#  'an',
#  'alternate',
#  'address',
#  'which',
#  'may',
#  'be',
#  'newer',
#  'or',
#  'older',
#  'is',
#  'prometheus',
#  'books',
#  '5',
#  '9',
#  'glenn',
#  'drive',
#  'buffalo',
#  'ny',
#  '14228-2197',
#  'african',
#  'americans',
#  'for',
#  'humanism',
#  'an',
#  'organization',
#  'promoting',
#  'black',
#  'secular',
#  'humanism',
#  'and',
#  'uncovering',
#  'the',
#  'history',
#  'of',
#  'black',
#  'freethought',
#  'they',
#  'publish',
#  'a',
#  'quarterly',
#  'newsletter',
#  'aah',
#  'examiner',
#  'write',
#  'to',
#  'norm',
#  'r',
#  'allen',
#  'jr',
#  'african',
#  'americans',
#  'for',
#  'humanism',
#  'p',
#  'o',
#  'box',
#  '6',
#  '6',
#  '4',
#  'buffalo',
#  'ny',
#  '14226',
#  'united',
#  'kingdom',
#  'rationalist',
#  'press',
#  'association',
#  'national',
#  'secular',
#  'society',
#  '8',
#  '8',
#  'islington',
#  'high',
#  'street',
#  '7',
#  '0',
#  '2',
#  'holloway',
#  'road',
#  'london',
#  'n',
#  '1',
#  '8',
#  'ew',
#  'london',
#  'n',
#  '1',
#  '9',
#  '3',
#  'nl',
#  'nl',
#  'nl',
#  '071 226',
#  '7',
#  '2',
#  '5',
#  '1',
#  '0',
#  '7',
#  '1',
#  '2',
#  '7',
#  '2',
#  '1',
#  '2',
#  '6',
#  '6',
#  'british',
#  'humanist',
#  'association',
#  'south',
#  'place',
#  'ethical',
#  'society',
#  '1',
#  '4',
#  "lamb's",
#  'conduit',
#  'passage',
#  'conway',
#  'hall',
#  'london',
#  'wc',
#  '1',
#  'r',
#  '4',
#  'rh',
#  'red',
#  'lion',
#  'square',
#  'square',
#  'square',
#  '071 430',
#  '0',
#  '9',
#  '0',
#  '8',
#  'london',
#  'wc',
#  '1',
#  'r',
#  '4',
#  'rl',
#  'fax 071 430',
#  '1',
#  '2',
#  '7',
#  '1',
#  '0',
#  '7',
#  '1',
#  '8',
#  '3',
#  '1',
#  '7',
#  '7',
#  '2',
#  '3',
#  'the',
#  'national',
#  'secular',
#  'society',
#  'publish',
#  'the',
#  'freethinker',
#  'a',
#  'monthly',
#  'magazine',
#  'founded',
#  'in',
#  '1',
#  '8',
#  '8',
#  '1',
#  'germany',
#  'ibka',
#  'e',
#  'v',
#  'internationaler',
#  'bund',
#  'der',
#  'konfessionslosen',
#  'und',
#  'atheisten',
#  'postfach',
#  '8',
#  '8',
#  '0',
#  'd',
#  '1',
#  '0',
#  '00 berlin 41',
#  'germany',
#  'ibka',
#  'publish',
#  'a',
#  'journal',
#  'miz',
#  'materialien',
#  'und',
#  'informationen',
#  'zur',
#  'zeit',
#  'politisches',
#  'journal',
#  'der',
#  'konfessionslosesn',
#  'und',
#  'atheisten',
#  'hrsg',
#  'ibka',
#  'e',
#  'v',
#  'miz',
#  'vertrieb',
#  'postfach',
#  '8',
#  '8',
#  '0',
#  'd',
#  '1',
#  '0',
#  '00 berlin 41',
#  'germany',
#  'for',
#  'atheist',
#  'book',
#  'write',
#  'to',
#  'ibdk',
#  'internationaler',
#  'b',
#  'ucherdienst',
#  'der',
#  'konfessionslosen',
#  'postfach',
#  '3',
#  '0',
#  '0',
#  '5',
#  'd',
#  '3',
#  '0',
#  '00 hannover 1',
#  'germany',
#  'telephone',
#  '0511/2112',
#  '1',
#  '6',
#  'books',
#  'fiction',
#  'thomas',
#  'm',
#  'disch',
#  'the',
#  'santa',
#  'claus',
#  'compromise',
#  'short',
#  'story',
#  'the',
#  'ultimate',
#  'proof',
#  'that',
#  'santa',
#  'exists',
#  'all',
#  'character',
#  'and',
#  'event',
#  'are',
#  'fictitious',
#  'any',
#  'similarity',
#  'to',
#  'living',
#  'or',
#  'dead',
#  'god',
#  'uh',
#  'well',
#  'walter',
#  'm',
#  'miller',
#  'jr',
#  'a',
#  'canticle',
#  'for',
#  'leibowitz',
#  'one',
#  'gem',
#  'in',
#  'this',
#  'post',
#  'atomic',
#  'doomsday',
#  'novel',
#  'is',
#  'the',
#  'monk',
#  'who',
#  'spent',
#  'their',
#  'life',
#  'copying',
#  'blueprint',
#  'from',
#  'saint',
#  'leibowitz',
#  'filling',
#  'the',
#  'sheet',
#  'of',
#  'paper',
#  'with',
#  'ink',
#  'and',
#  'leaving',
#  'white',
#  'line',
#  'and',
#  'letter',
#  'edgar',
#  'pangborn',
#  'davy',
#  'post',
#  'atomic',
#  'doomsday',
#  'novel',
#  'set',
#  'in',
#  'clerical',
#  'state',
#  'the',
#  'church',
#  'for',
#  'example',
#  'forbids',
#  'that',
#  'anyone',
#  'produce',
#  'describe',
#  'or',
#  'use',
#  'any',
#  'substance',
#  'containing',
#  'atom',
#  'philip',
#  'k',
#  'dick',
#  'philip',
#  'k',
#  'dick',
#  'dick',
#  'wrote',
#  'many',
#  'philosophical',
#  'and',
#  'thought',
#  'provoking',
#  'short',
#  'story',
#  'and',
#  'novel',
#  'his',
#  'story',
#  'are',
#  'bizarre',
#  'at',
#  'time',
#  'but',
#  'very',
#  'approachable',
#  'he',
#  'wrote',
#  'mainly',
#  'sf',
#  'but',
#  'he',
#  'wrote',
#  'about',
#  'people',
#  'truth',
#  'and',
#  'religion',
#  'rather',
#  'than',
#  'technology',
#  'although',
#  'he',
#  'often',
#  'believed',
#  'that',
#  'he',
#  'had',
#  'met',
#  'some',
#  'sort',
#  'of',
#  'god',
#  'he',
#  'remained',
#  'sceptical',
#  'amongst',
#  'his',
#  'novel',
#  'the',
#  'following',
#  'are',
#  'of',
#  'some',
#  'relevance',
#  'galactic',
#  'pot',
#  'healer',
#  'a',
#  'fallible',
#  'alien',
#  'deity',
#  'summons',
#  'a',
#  'group',
#  'of',
#  'earth',
#  'craftsman',
#  'and',
#  'woman',
#  'to',
#  'a',
#  'remote',
#  'planet',
#  'to',
#  'raise',
#  'a',
#  'giant',
#  'cathedral',
#  'from',
#  'beneath',
#  'the',
#  'ocean',
#  'when',
#  'the',
#  'deity',
#  'begin',
#  'to',
#  'demand',
#  'faith',
#  'from',
#  'the',
#  'earthers',
#  'pot',
#  'healer',
#  'joe',
#  'fernwright',
#  'is',
#  'unable',
#  'to',
#  'comply',
#  'a',
#  'polished',
#  'ironic',
#  'and',
#  'amusing',
#  'novel',
#  'a',
#  'maze',
#  'of',
#  'death',
#  'noteworthy',
#  'for',
#  'it',
#  'description',
#  'of',
#  'a',
#  'technology',
#  'based',
#  'religion',
#  'valis',
#  'the',
#  'schizophrenic',
#  'hero',
#  'search',
#  'for',
#  'the',
#  'hidden',
#  'mystery',
#  'of',
#  'gnostic',
#  'christianity',
#  'after',
#  'reality',
#  'is',
#  'fired',
#  'into',
#  'his',
#  'brain',
#  'by',
#  'a',
#  'pink',
#  'laser',
#  'beam',
#  'of',
#  'unknown',
#  'but',
#  'possibly',
#  'divine',
#  'origin',
#  'he',
#  'is',
#  'accompanied',
#  'by',
#  'his',
#  'dogmatic',
#  'and',
#  'dismissively',
#  'atheist',
#  'friend',
#  'and',
#  'assorted',
#  'other',
#  'odd',
#  'character',
#  'the',
#  'divine',
#  'invasion',
#  'god',
#  'invades',
#  'earth',
#  'by',
#  'making',
#  'a',
#  'young',
#  'woman',
#  'pregnant',
#  'a',
#  'she',
#  'return',
#  'from',
#  'another',
#  'star',
#  'system',
#  'unfortunately',
#  'she',
#  'is',
#  'terminally',
#  'ill',
#  'and',
#  'must',
#  'be',
#  'assisted',
#  'by',
#  'a',
#  'dead',
#  'man',
#  'whose',
#  'brain',
#  'is',
#  'wired',
#  'to',
#  '2',
#  '4',
#  'hour',
#  'easy',
#  'listening',
#  'music',
#  'margaret',
#  'atwood',
#  'the',
#  "handmaid's",
#  'tale',
#  'a',
#  'story',
#  'based',
#  'on',
#  'the',
#  'premise',
#  'that',
#  'the',
#  'us',
#  'congress',
#  'is',
#  'mysteriously',
#  'assassinated',
#  'and',
#  'fundamentalist',
#  'quickly',
#  'take',
#  'charge',
#  'of',
#  'the',
#  'nation',
#  'to',
#  'set',
#  'it',
#  'right',
#  'again',
#  'the',
#  'book',
#  'is',
#  'the',
#  'diary',
#  'of',
#  'a',
#  "woman's",
#  'life',
#  'a',
#  'she',
#  'try',
#  'to',
#  'live',
#  'under',
#  'the',
#  'new',
#  'christian',
#  'theocracy',
#  "women's",
#  'right',
#  'to',
#  'own',
#  'property',
#  'is',
#  'revoked',
#  'and',
#  'their',
#  'bank',
#  'account',
#  'are',
#  'closed',
#  'sinful',
#  'luxury',
#  'are',
#  'outlawed',
#  'and',
#  'the',
#  'radio',
#  'is',
#  'only',
#  'used',
#  'for',
#  'reading',
#  'from',
#  'the',
#  'bible',
#  'crimes',
#  'are',
#  'punished',
#  'retroactively',
#  'doctor',
#  'who',
#  'performed',
#  'legal',
#  'abortion',
#  'in',
#  'the',
#  'old',
#  'world',
#  'are',
#  'hunted',
#  'down',
#  'and',
#  'hanged',
#  "atwood's",
#  'writing',
#  'style',
#  'is',
#  'difficult',
#  'to',
#  'get',
#  'used',
#  'to',
#  'at',
#  'first',
#  'but',
#  'the',
#  'tale',
#  'grows',
#  'more',
#  'and',
#  'more',
#  'chilling',
#  'a',
#  'it',
#  'go',
#  'on',
#  ...]

# %% [markdown]
# Удаление стоп слов

# %%
from nltk.corpus import stopwords
import nltk

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

lm=[]
for l in lem:
	if l not in stop_words:
		lm.append(l)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\an066\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
lm
# Out:
# ['mathew',
#  'mathew@mantis.co.uk',
#  'subject',
#  'alt',
#  'atheism',
#  'faq',
#  'atheist',
#  'resources',
#  'summary',
#  'books',
#  'address',
#  'music',
#  'anything',
#  'related',
#  'atheism',
#  'keywords',
#  'faq',
#  'atheism',
#  'book',
#  'music',
#  'fiction',
#  'address',
#  'contact',
#  'expires',
#  'thu',
#  '29 apr 1993',
#  '11:57:19',
#  'gmt',
#  'distribution',
#  'world',
#  'organization',
#  'mantis',
#  'consultants',
#  'cambridge',
#  'uk',
#  'supersedes',
#  '19930301143317@mantis.co.uk',
#  'lines',
#  '2',
#  '9',
#  '0',
#  'archive',
#  'name',
#  'atheism',
#  '/',
#  'resource',
#  'alt',
#  'atheism',
#  'archive',
#  'name',
#  'resource',
#  'last',
#  'modified',
#  '11 december 1992',
#  'version',
#  '1',
#  '0',
#  'atheist',
#  'resources',
#  'addresses',
#  'atheist',
#  'organizations',
#  'usa',
#  'freedom',
#  'religion',
#  'foundation',
#  'darwin',
#  'fish',
#  'bumper',
#  'sticker',
#  'assorted',
#  'atheist',
#  'paraphernalia',
#  'available',
#  'freedom',
#  'religion',
#  'foundation',
#  'us',
#  'write',
#  'ffrf',
#  'p',
#  'box',
#  '7',
#  '5',
#  '0',
#  'madison',
#  'wi',
#  '53701',
#  'telephone',
#  'evolution',
#  'designs',
#  'evolution',
#  'designs',
#  'sell',
#  'darwin',
#  'fish',
#  'fish',
#  'symbol',
#  'like',
#  'one',
#  'christians',
#  'stick',
#  'car',
#  'foot',
#  'word',
#  'darwin',
#  'written',
#  'inside',
#  'deluxe',
#  'moulded',
#  '3',
#  'plastic',
#  'fish',
#  '$4.95',
#  'postpaid',
#  'us',
#  'write',
#  'evolution',
#  'designs',
#  '7',
#  '1',
#  '1',
#  '9',
#  'laurel',
#  'canyon',
#  '#',
#  '4',
#  'north',
#  'hollywood',
#  'ca',
#  '91605',
#  'people',
#  'san',
#  'francisco',
#  'bay',
#  'area',
#  'get',
#  'darwin',
#  'fish',
#  'lynn',
#  'gold',
#  'try',
#  'mailing',
#  'figmo@netcom.com',
#  'net',
#  'people',
#  'go',
#  'lynn',
#  'directly',
#  'price',
#  '$4.95',
#  'per',
#  'fish',
#  'american',
#  'atheist',
#  'press',
#  'aap',
#  'publish',
#  'various',
#  'atheist',
#  'book',
#  'critique',
#  'bible',
#  'list',
#  'biblical',
#  'contradiction',
#  'one',
#  'book',
#  'bible',
#  'handbook',
#  'w',
#  'p',
#  'ball',
#  'g',
#  'w',
#  'foote',
#  'american',
#  'atheist',
#  'press',
#  '3',
#  '7',
#  '2',
#  'pp',
#  'isbn',
#  '0-910309',
#  '2',
#  '6',
#  '4',
#  '2',
#  'nd',
#  'edition',
#  '1',
#  '9',
#  '8',
#  '6',
#  'bible',
#  'contradiction',
#  'absurdity',
#  'atrocity',
#  'immorality',
#  'contains',
#  'ball',
#  'foote',
#  'bible',
#  'contradicts',
#  'aap',
#  'based',
#  'king',
#  'james',
#  'version',
#  'bible',
#  'write',
#  'american',
#  'atheist',
#  'press',
#  'p',
#  'box',
#  '140195',
#  'austin',
#  'tx',
#  '78714-0195',
#  '7',
#  '2',
#  '1',
#  '5',
#  'cameron',
#  'road',
#  'austin',
#  'tx',
#  '78752-2973',
#  'telephone',
#  'fax',
#  'prometheus',
#  'books',
#  'sell',
#  'book',
#  'including',
#  "haught's",
#  'holy',
#  'horrors',
#  'see',
#  'write',
#  '7',
#  '0',
#  '0',
#  'east',
#  'amherst',
#  'street',
#  'buffalo',
#  'new',
#  'york',
#  '14215',
#  'telephone',
#  'alternate',
#  'address',
#  'may',
#  'newer',
#  'older',
#  'prometheus',
#  'books',
#  '5',
#  '9',
#  'glenn',
#  'drive',
#  'buffalo',
#  'ny',
#  '14228-2197',
#  'african',
#  'americans',
#  'humanism',
#  'organization',
#  'promoting',
#  'black',
#  'secular',
#  'humanism',
#  'uncovering',
#  'history',
#  'black',
#  'freethought',
#  'publish',
#  'quarterly',
#  'newsletter',
#  'aah',
#  'examiner',
#  'write',
#  'norm',
#  'r',
#  'allen',
#  'jr',
#  'african',
#  'americans',
#  'humanism',
#  'p',
#  'box',
#  '6',
#  '6',
#  '4',
#  'buffalo',
#  'ny',
#  '14226',
#  'united',
#  'kingdom',
#  'rationalist',
#  'press',
#  'association',
#  'national',
#  'secular',
#  'society',
#  '8',
#  '8',
#  'islington',
#  'high',
#  'street',
#  '7',
#  '0',
#  '2',
#  'holloway',
#  'road',
#  'london',
#  'n',
#  '1',
#  '8',
#  'ew',
#  'london',
#  'n',
#  '1',
#  '9',
#  '3',
#  'nl',
#  'nl',
#  'nl',
#  '071 226',
#  '7',
#  '2',
#  '5',
#  '1',
#  '0',
#  '7',
#  '1',
#  '2',
#  '7',
#  '2',
#  '1',
#  '2',
#  '6',
#  '6',
#  'british',
#  'humanist',
#  'association',
#  'south',
#  'place',
#  'ethical',
#  'society',
#  '1',
#  '4',
#  "lamb's",
#  'conduit',
#  'passage',
#  'conway',
#  'hall',
#  'london',
#  'wc',
#  '1',
#  'r',
#  '4',
#  'rh',
#  'red',
#  'lion',
#  'square',
#  'square',
#  'square',
#  '071 430',
#  '0',
#  '9',
#  '0',
#  '8',
#  'london',
#  'wc',
#  '1',
#  'r',
#  '4',
#  'rl',
#  'fax 071 430',
#  '1',
#  '2',
#  '7',
#  '1',
#  '0',
#  '7',
#  '1',
#  '8',
#  '3',
#  '1',
#  '7',
#  '7',
#  '2',
#  '3',
#  'national',
#  'secular',
#  'society',
#  'publish',
#  'freethinker',
#  'monthly',
#  'magazine',
#  'founded',
#  '1',
#  '8',
#  '8',
#  '1',
#  'germany',
#  'ibka',
#  'e',
#  'v',
#  'internationaler',
#  'bund',
#  'der',
#  'konfessionslosen',
#  'und',
#  'atheisten',
#  'postfach',
#  '8',
#  '8',
#  '0',
#  '1',
#  '0',
#  '00 berlin 41',
#  'germany',
#  'ibka',
#  'publish',
#  'journal',
#  'miz',
#  'materialien',
#  'und',
#  'informationen',
#  'zur',
#  'zeit',
#  'politisches',
#  'journal',
#  'der',
#  'konfessionslosesn',
#  'und',
#  'atheisten',
#  'hrsg',
#  'ibka',
#  'e',
#  'v',
#  'miz',
#  'vertrieb',
#  'postfach',
#  '8',
#  '8',
#  '0',
#  '1',
#  '0',
#  '00 berlin 41',
#  'germany',
#  'atheist',
#  'book',
#  'write',
#  'ibdk',
#  'internationaler',
#  'b',
#  'ucherdienst',
#  'der',
#  'konfessionslosen',
#  'postfach',
#  '3',
#  '0',
#  '0',
#  '5',
#  '3',
#  '0',
#  '00 hannover 1',
#  'germany',
#  'telephone',
#  '0511/2112',
#  '1',
#  '6',
#  'books',
#  'fiction',
#  'thomas',
#  'disch',
#  'santa',
#  'claus',
#  'compromise',
#  'short',
#  'story',
#  'ultimate',
#  'proof',
#  'santa',
#  'exists',
#  'character',
#  'event',
#  'fictitious',
#  'similarity',
#  'living',
#  'dead',
#  'god',
#  'uh',
#  'well',
#  'walter',
#  'miller',
#  'jr',
#  'canticle',
#  'leibowitz',
#  'one',
#  'gem',
#  'post',
#  'atomic',
#  'doomsday',
#  'novel',
#  'monk',
#  'spent',
#  'life',
#  'copying',
#  'blueprint',
#  'saint',
#  'leibowitz',
#  'filling',
#  'sheet',
#  'paper',
#  'ink',
#  'leaving',
#  'white',
#  'line',
#  'letter',
#  'edgar',
#  'pangborn',
#  'davy',
#  'post',
#  'atomic',
#  'doomsday',
#  'novel',
#  'set',
#  'clerical',
#  'state',
#  'church',
#  'example',
#  'forbids',
#  'anyone',
#  'produce',
#  'describe',
#  'use',
#  'substance',
#  'containing',
#  'atom',
#  'philip',
#  'k',
#  'dick',
#  'philip',
#  'k',
#  'dick',
#  'dick',
#  'wrote',
#  'many',
#  'philosophical',
#  'thought',
#  'provoking',
#  'short',
#  'story',
#  'novel',
#  'story',
#  'bizarre',
#  'time',
#  'approachable',
#  'wrote',
#  'mainly',
#  'sf',
#  'wrote',
#  'people',
#  'truth',
#  'religion',
#  'rather',
#  'technology',
#  'although',
#  'often',
#  'believed',
#  'met',
#  'sort',
#  'god',
#  'remained',
#  'sceptical',
#  'amongst',
#  'novel',
#  'following',
#  'relevance',
#  'galactic',
#  'pot',
#  'healer',
#  'fallible',
#  'alien',
#  'deity',
#  'summons',
#  'group',
#  'earth',
#  'craftsman',
#  'woman',
#  'remote',
#  'planet',
#  'raise',
#  'giant',
#  'cathedral',
#  'beneath',
#  'ocean',
#  'deity',
#  'begin',
#  'demand',
#  'faith',
#  'earthers',
#  'pot',
#  'healer',
#  'joe',
#  'fernwright',
#  'unable',
#  'comply',
#  'polished',
#  'ironic',
#  'amusing',
#  'novel',
#  'maze',
#  'death',
#  'noteworthy',
#  'description',
#  'technology',
#  'based',
#  'religion',
#  'valis',
#  'schizophrenic',
#  'hero',
#  'search',
#  'hidden',
#  'mystery',
#  'gnostic',
#  'christianity',
#  'reality',
#  'fired',
#  'brain',
#  'pink',
#  'laser',
#  'beam',
#  'unknown',
#  'possibly',
#  'divine',
#  'origin',
#  'accompanied',
#  'dogmatic',
#  'dismissively',
#  'atheist',
#  'friend',
#  'assorted',
#  'odd',
#  'character',
#  'divine',
#  'invasion',
#  'god',
#  'invades',
#  'earth',
#  'making',
#  'young',
#  'woman',
#  'pregnant',
#  'return',
#  'another',
#  'star',
#  'system',
#  'unfortunately',
#  'terminally',
#  'ill',
#  'must',
#  'assisted',
#  'dead',
#  'man',
#  'whose',
#  'brain',
#  'wired',
#  '2',
#  '4',
#  'hour',
#  'easy',
#  'listening',
#  'music',
#  'margaret',
#  'atwood',
#  "handmaid's",
#  'tale',
#  'story',
#  'based',
#  'premise',
#  'us',
#  'congress',
#  'mysteriously',
#  'assassinated',
#  'fundamentalist',
#  'quickly',
#  'take',
#  'charge',
#  'nation',
#  'set',
#  'right',
#  'book',
#  'diary',
#  "woman's",
#  'life',
#  'try',
#  'live',
#  'new',
#  'christian',
#  'theocracy',
#  "women's",
#  'right',
#  'property',
#  'revoked',
#  'bank',
#  'account',
#  'closed',
#  'sinful',
#  'luxury',
#  'outlawed',
#  'radio',
#  'used',
#  'reading',
#  'bible',
#  'crimes',
#  'punished',
#  'retroactively',
#  'doctor',
#  'performed',
#  'legal',
#  'abortion',
#  'old',
#  'world',
#  'hunted',
#  'hanged',
#  "atwood's",
#  'writing',
#  'style',
#  'difficult',
#  'get',
#  'used',
#  'first',
#  'tale',
#  'grows',
#  'chilling',
#  'go',
#  'various',
#  'authors',
#  'bible',
#  'somewhat',
#  'dull',
#  'rambling',
#  'work',
#  'ha',
#  'often',
#  'criticized',
#  'however',
#  'probably',
#  'worth',
#  'reading',
#  'know',
#  'fuss',
#  'exists',
#  'many',
#  'different',
#  'version',
#  'make',
#  'sure',
#  'get',
#  'one',
#  'true',
#  'version',
#  'books',
#  'non',
#  'fiction',
#  'peter',
#  'de',
#  'rosa',
#  'vicars',
#  'christ',
#  'bantam',
#  'press',
#  '1',
#  '9',
#  '8',
#  '8',
#  'although',
#  'de',
#  'rosa',
#  'seems',
#  'christian',
#  'even',
#  'catholic',
#  'enlighting',
#  'history',
#  'papal',
#  'immorality',
#  'adultery',
#  'fallacy',
#  'etc',
#  'german',
#  'translation',
#  'gottes',
#  'erste',
#  'diener',
#  'die',
#  'dunkle',
#  'seite',
#  'de',
#  'papsttums',
#  'droemer',
#  'knaur',
#  '1',
#  '9',
#  '8',
#  '9',
#  'michael',
#  'martin',
#  'atheism',
#  'philosophical',
#  'justification',
#  'temple',
#  'university',
#  'press',
#  'philadelphia',
#  'usa',
#  'detailed',
#  'scholarly',
#  'justification',
#  'atheism',
#  'contains',
#  'outstanding',
#  'appendix',
#  'defining',
#  'terminology',
#  'usage',
#  'necessarily',
#  'tendentious',
#  'area',
#  'argues',
#  'negative',
#  'atheism',
#  'e',
#  'non',
#  'belief',
#  'existence',
#  'god',
#  'also',
#  'positive',
#  'atheism',
#  'belief',
#  'non',
#  'existence',
#  'god',
#  'includes',
#  'great',
#  'refutation',
#  'challenging',
#  'argument',
#  'god',
#  'particular',
#  'attention',
#  'paid',
#  'refuting',
#  'contempory',
#  'theist',
#  'platinga',
#  'swinburne',
#  '5',
#  '4',
#  '1',
#  'page',
#  'isbn',
#  '0-87722',
#  '642-3',
#  'hardcover',
#  'paperback',
#  'also',
#  'available',
#  'case',
#  'christianity',
#  'temple',
#  'university',
#  'press',
#  'comprehensive',
#  'critique',
#  'christianity',
#  'considers',
#  'best',
#  'contemporary',
#  'defence',
#  'christianity',
#  'ultimately',
#  'demonstrates',
#  'unsupportable',
#  '/',
#  'incoherent',
#  '2',
#  '7',
#  '3',
#  'page',
#  'isbn',
#  '0-87722',
#  '767-5',
#  'james',
#  'turner',
#  'without',
#  'god',
#  'without',
#  'creed',
#  'johns',
#  'hopkins',
#  'university',
#  'press',
#  'baltimore',
#  'md',
#  'usa',
#  'subtitled',
#  'origins',
#  'unbelief',
#  'america',
#  'examines',
#  'way',
#  'unbelief',
#  'whether',
#  'agnostic',
#  'atheistic',
#  'became',
#  'mainstream',
#  'alternative',
#  'world',
#  'view',
#  'focusses',
#  'period',
#  '1770-1900',
#  'considering',
#  'france',
#  'britain',
#  'emphasis',
#  'american',
#  'particularly',
#  'new',
#  'england',
#  'development',
#  'neither',
#  'religious',
#  'history',
#  'secularization',
#  'atheism',
#  'without',
#  'god',
#  'without',
#  'creed',
#  'rather',
#  'intellectual',
#  'history',
#  'fate',
#  'single',
#  'idea',
#  'belief',
#  'god',
#  'exists',
#  '3',
#  '1',
#  '6',
#  'page',
#  'isbn',
#  'hardcover',
#  '0-8018',
#  '2',
#  '4',
#  '9',
#  '4',
#  'x',
#  'paper',
#  '0-8018',
#  '3407-4',
#  'george',
#  'seldes',
#  'editor',
#  'great',
#  'thought',
#  'ballantine',
#  'books',
#  'new',
#  'york',
#  'usa',
#  'dictionary',
#  'quotation',
#  'different',
#  'kind',
#  'concentrating',
#  'statement',
#  'writing',
#  'explicitly',
#  'implicitly',
#  'present',
#  "person's",
#  'philosophy',
#  'world',
#  'view',
#  'includes',
#  ...]

# %%
write_dict("lemmas.txt",lm)

# %% [markdown]
# Извлечение триграмм и подсчет их частот

# %%
def read_dict(path):
    dictionary = []
    with open(path, "r") as f:
        while True:
            line=f.readline()
            if not line:
                break
            dictionary.append(line.replace('\n',''))
    return dictionary

# %%
data=read_dict("lemmas.txt")

# %%
data
# Out:
# ['mathew',
#  'mathew@mantis.co.uk',
#  'subject',
#  'alt',
#  'atheism',
#  'faq',
#  'atheist',
#  'resources',
#  'summary',
#  'books',
#  'address',
#  'music',
#  'anything',
#  'related',
#  'atheism',
#  'keywords',
#  'faq',
#  'atheism',
#  'book',
#  'music',
#  'fiction',
#  'address',
#  'contact',
#  'expires',
#  'thu',
#  '29 apr 1993',
#  '11:57:19',
#  'gmt',
#  'distribution',
#  'world',
#  'organization',
#  'mantis',
#  'consultants',
#  'cambridge',
#  'uk',
#  'supersedes',
#  '19930301143317@mantis.co.uk',
#  'lines',
#  '2',
#  '9',
#  '0',
#  'archive',
#  'name',
#  'atheism',
#  '/',
#  'resource',
#  'alt',
#  'atheism',
#  'archive',
#  'name',
#  'resource',
#  'last',
#  'modified',
#  '11 december 1992',
#  'version',
#  '1',
#  '0',
#  'atheist',
#  'resources',
#  'addresses',
#  'atheist',
#  'organizations',
#  'usa',
#  'freedom',
#  'religion',
#  'foundation',
#  'darwin',
#  'fish',
#  'bumper',
#  'sticker',
#  'assorted',
#  'atheist',
#  'paraphernalia',
#  'available',
#  'freedom',
#  'religion',
#  'foundation',
#  'us',
#  'write',
#  'ffrf',
#  'p',
#  'box',
#  '7',
#  '5',
#  '0',
#  'madison',
#  'wi',
#  '53701',
#  'telephone',
#  'evolution',
#  'designs',
#  'evolution',
#  'designs',
#  'sell',
#  'darwin',
#  'fish',
#  'fish',
#  'symbol',
#  'like',
#  'one',
#  'christians',
#  'stick',
#  'car',
#  'foot',
#  'word',
#  'darwin',
#  'written',
#  'inside',
#  'deluxe',
#  'moulded',
#  '3',
#  'plastic',
#  'fish',
#  '$4.95',
#  'postpaid',
#  'us',
#  'write',
#  'evolution',
#  'designs',
#  '7',
#  '1',
#  '1',
#  '9',
#  'laurel',
#  'canyon',
#  '#',
#  '4',
#  'north',
#  'hollywood',
#  'ca',
#  '91605',
#  'people',
#  'san',
#  'francisco',
#  'bay',
#  'area',
#  'get',
#  'darwin',
#  'fish',
#  'lynn',
#  'gold',
#  'try',
#  'mailing',
#  'figmo@netcom.com',
#  'net',
#  'people',
#  'go',
#  'lynn',
#  'directly',
#  'price',
#  '$4.95',
#  'per',
#  'fish',
#  'american',
#  'atheist',
#  'press',
#  'aap',
#  'publish',
#  'various',
#  'atheist',
#  'book',
#  'critique',
#  'bible',
#  'list',
#  'biblical',
#  'contradiction',
#  'one',
#  'book',
#  'bible',
#  'handbook',
#  'w',
#  'p',
#  'ball',
#  'g',
#  'w',
#  'foote',
#  'american',
#  'atheist',
#  'press',
#  '3',
#  '7',
#  '2',
#  'pp',
#  'isbn',
#  '0-910309',
#  '2',
#  '6',
#  '4',
#  '2',
#  'nd',
#  'edition',
#  '1',
#  '9',
#  '8',
#  '6',
#  'bible',
#  'contradiction',
#  'absurdity',
#  'atrocity',
#  'immorality',
#  'contains',
#  'ball',
#  'foote',
#  'bible',
#  'contradicts',
#  'aap',
#  'based',
#  'king',
#  'james',
#  'version',
#  'bible',
#  'write',
#  'american',
#  'atheist',
#  'press',
#  'p',
#  'box',
#  '140195',
#  'austin',
#  'tx',
#  '78714-0195',
#  '7',
#  '2',
#  '1',
#  '5',
#  'cameron',
#  'road',
#  'austin',
#  'tx',
#  '78752-2973',
#  'telephone',
#  'fax',
#  'prometheus',
#  'books',
#  'sell',
#  'book',
#  'including',
#  "haught's",
#  'holy',
#  'horrors',
#  'see',
#  'write',
#  '7',
#  '0',
#  '0',
#  'east',
#  'amherst',
#  'street',
#  'buffalo',
#  'new',
#  'york',
#  '14215',
#  'telephone',
#  'alternate',
#  'address',
#  'may',
#  'newer',
#  'older',
#  'prometheus',
#  'books',
#  '5',
#  '9',
#  'glenn',
#  'drive',
#  'buffalo',
#  'ny',
#  '14228-2197',
#  'african',
#  'americans',
#  'humanism',
#  'organization',
#  'promoting',
#  'black',
#  'secular',
#  'humanism',
#  'uncovering',
#  'history',
#  'black',
#  'freethought',
#  'publish',
#  'quarterly',
#  'newsletter',
#  'aah',
#  'examiner',
#  'write',
#  'norm',
#  'r',
#  'allen',
#  'jr',
#  'african',
#  'americans',
#  'humanism',
#  'p',
#  'box',
#  '6',
#  '6',
#  '4',
#  'buffalo',
#  'ny',
#  '14226',
#  'united',
#  'kingdom',
#  'rationalist',
#  'press',
#  'association',
#  'national',
#  'secular',
#  'society',
#  '8',
#  '8',
#  'islington',
#  'high',
#  'street',
#  '7',
#  '0',
#  '2',
#  'holloway',
#  'road',
#  'london',
#  'n',
#  '1',
#  '8',
#  'ew',
#  'london',
#  'n',
#  '1',
#  '9',
#  '3',
#  'nl',
#  'nl',
#  'nl',
#  '071 226',
#  '7',
#  '2',
#  '5',
#  '1',
#  '0',
#  '7',
#  '1',
#  '2',
#  '7',
#  '2',
#  '1',
#  '2',
#  '6',
#  '6',
#  'british',
#  'humanist',
#  'association',
#  'south',
#  'place',
#  'ethical',
#  'society',
#  '1',
#  '4',
#  "lamb's",
#  'conduit',
#  'passage',
#  'conway',
#  'hall',
#  'london',
#  'wc',
#  '1',
#  'r',
#  '4',
#  'rh',
#  'red',
#  'lion',
#  'square',
#  'square',
#  'square',
#  '071 430',
#  '0',
#  '9',
#  '0',
#  '8',
#  'london',
#  'wc',
#  '1',
#  'r',
#  '4',
#  'rl',
#  'fax 071 430',
#  '1',
#  '2',
#  '7',
#  '1',
#  '0',
#  '7',
#  '1',
#  '8',
#  '3',
#  '1',
#  '7',
#  '7',
#  '2',
#  '3',
#  'national',
#  'secular',
#  'society',
#  'publish',
#  'freethinker',
#  'monthly',
#  'magazine',
#  'founded',
#  '1',
#  '8',
#  '8',
#  '1',
#  'germany',
#  'ibka',
#  'e',
#  'v',
#  'internationaler',
#  'bund',
#  'der',
#  'konfessionslosen',
#  'und',
#  'atheisten',
#  'postfach',
#  '8',
#  '8',
#  '0',
#  '1',
#  '0',
#  '00 berlin 41',
#  'germany',
#  'ibka',
#  'publish',
#  'journal',
#  'miz',
#  'materialien',
#  'und',
#  'informationen',
#  'zur',
#  'zeit',
#  'politisches',
#  'journal',
#  'der',
#  'konfessionslosesn',
#  'und',
#  'atheisten',
#  'hrsg',
#  'ibka',
#  'e',
#  'v',
#  'miz',
#  'vertrieb',
#  'postfach',
#  '8',
#  '8',
#  '0',
#  '1',
#  '0',
#  '00 berlin 41',
#  'germany',
#  'atheist',
#  'book',
#  'write',
#  'ibdk',
#  'internationaler',
#  'b',
#  'ucherdienst',
#  'der',
#  'konfessionslosen',
#  'postfach',
#  '3',
#  '0',
#  '0',
#  '5',
#  '3',
#  '0',
#  '00 hannover 1',
#  'germany',
#  'telephone',
#  '0511/2112',
#  '1',
#  '6',
#  'books',
#  'fiction',
#  'thomas',
#  'disch',
#  'santa',
#  'claus',
#  'compromise',
#  'short',
#  'story',
#  'ultimate',
#  'proof',
#  'santa',
#  'exists',
#  'character',
#  'event',
#  'fictitious',
#  'similarity',
#  'living',
#  'dead',
#  'god',
#  'uh',
#  'well',
#  'walter',
#  'miller',
#  'jr',
#  'canticle',
#  'leibowitz',
#  'one',
#  'gem',
#  'post',
#  'atomic',
#  'doomsday',
#  'novel',
#  'monk',
#  'spent',
#  'life',
#  'copying',
#  'blueprint',
#  'saint',
#  'leibowitz',
#  'filling',
#  'sheet',
#  'paper',
#  'ink',
#  'leaving',
#  'white',
#  'line',
#  'letter',
#  'edgar',
#  'pangborn',
#  'davy',
#  'post',
#  'atomic',
#  'doomsday',
#  'novel',
#  'set',
#  'clerical',
#  'state',
#  'church',
#  'example',
#  'forbids',
#  'anyone',
#  'produce',
#  'describe',
#  'use',
#  'substance',
#  'containing',
#  'atom',
#  'philip',
#  'k',
#  'dick',
#  'philip',
#  'k',
#  'dick',
#  'dick',
#  'wrote',
#  'many',
#  'philosophical',
#  'thought',
#  'provoking',
#  'short',
#  'story',
#  'novel',
#  'story',
#  'bizarre',
#  'time',
#  'approachable',
#  'wrote',
#  'mainly',
#  'sf',
#  'wrote',
#  'people',
#  'truth',
#  'religion',
#  'rather',
#  'technology',
#  'although',
#  'often',
#  'believed',
#  'met',
#  'sort',
#  'god',
#  'remained',
#  'sceptical',
#  'amongst',
#  'novel',
#  'following',
#  'relevance',
#  'galactic',
#  'pot',
#  'healer',
#  'fallible',
#  'alien',
#  'deity',
#  'summons',
#  'group',
#  'earth',
#  'craftsman',
#  'woman',
#  'remote',
#  'planet',
#  'raise',
#  'giant',
#  'cathedral',
#  'beneath',
#  'ocean',
#  'deity',
#  'begin',
#  'demand',
#  'faith',
#  'earthers',
#  'pot',
#  'healer',
#  'joe',
#  'fernwright',
#  'unable',
#  'comply',
#  'polished',
#  'ironic',
#  'amusing',
#  'novel',
#  'maze',
#  'death',
#  'noteworthy',
#  'description',
#  'technology',
#  'based',
#  'religion',
#  'valis',
#  'schizophrenic',
#  'hero',
#  'search',
#  'hidden',
#  'mystery',
#  'gnostic',
#  'christianity',
#  'reality',
#  'fired',
#  'brain',
#  'pink',
#  'laser',
#  'beam',
#  'unknown',
#  'possibly',
#  'divine',
#  'origin',
#  'accompanied',
#  'dogmatic',
#  'dismissively',
#  'atheist',
#  'friend',
#  'assorted',
#  'odd',
#  'character',
#  'divine',
#  'invasion',
#  'god',
#  'invades',
#  'earth',
#  'making',
#  'young',
#  'woman',
#  'pregnant',
#  'return',
#  'another',
#  'star',
#  'system',
#  'unfortunately',
#  'terminally',
#  'ill',
#  'must',
#  'assisted',
#  'dead',
#  'man',
#  'whose',
#  'brain',
#  'wired',
#  '2',
#  '4',
#  'hour',
#  'easy',
#  'listening',
#  'music',
#  'margaret',
#  'atwood',
#  "handmaid's",
#  'tale',
#  'story',
#  'based',
#  'premise',
#  'us',
#  'congress',
#  'mysteriously',
#  'assassinated',
#  'fundamentalist',
#  'quickly',
#  'take',
#  'charge',
#  'nation',
#  'set',
#  'right',
#  'book',
#  'diary',
#  "woman's",
#  'life',
#  'try',
#  'live',
#  'new',
#  'christian',
#  'theocracy',
#  "women's",
#  'right',
#  'property',
#  'revoked',
#  'bank',
#  'account',
#  'closed',
#  'sinful',
#  'luxury',
#  'outlawed',
#  'radio',
#  'used',
#  'reading',
#  'bible',
#  'crimes',
#  'punished',
#  'retroactively',
#  'doctor',
#  'performed',
#  'legal',
#  'abortion',
#  'old',
#  'world',
#  'hunted',
#  'hanged',
#  "atwood's",
#  'writing',
#  'style',
#  'difficult',
#  'get',
#  'used',
#  'first',
#  'tale',
#  'grows',
#  'chilling',
#  'go',
#  'various',
#  'authors',
#  'bible',
#  'somewhat',
#  'dull',
#  'rambling',
#  'work',
#  'ha',
#  'often',
#  'criticized',
#  'however',
#  'probably',
#  'worth',
#  'reading',
#  'know',
#  'fuss',
#  'exists',
#  'many',
#  'different',
#  'version',
#  'make',
#  'sure',
#  'get',
#  'one',
#  'true',
#  'version',
#  'books',
#  'non',
#  'fiction',
#  'peter',
#  'de',
#  'rosa',
#  'vicars',
#  'christ',
#  'bantam',
#  'press',
#  '1',
#  '9',
#  '8',
#  '8',
#  'although',
#  'de',
#  'rosa',
#  'seems',
#  'christian',
#  'even',
#  'catholic',
#  'enlighting',
#  'history',
#  'papal',
#  'immorality',
#  'adultery',
#  'fallacy',
#  'etc',
#  'german',
#  'translation',
#  'gottes',
#  'erste',
#  'diener',
#  'die',
#  'dunkle',
#  'seite',
#  'de',
#  'papsttums',
#  'droemer',
#  'knaur',
#  '1',
#  '9',
#  '8',
#  '9',
#  'michael',
#  'martin',
#  'atheism',
#  'philosophical',
#  'justification',
#  'temple',
#  'university',
#  'press',
#  'philadelphia',
#  'usa',
#  'detailed',
#  'scholarly',
#  'justification',
#  'atheism',
#  'contains',
#  'outstanding',
#  'appendix',
#  'defining',
#  'terminology',
#  'usage',
#  'necessarily',
#  'tendentious',
#  'area',
#  'argues',
#  'negative',
#  'atheism',
#  'e',
#  'non',
#  'belief',
#  'existence',
#  'god',
#  'also',
#  'positive',
#  'atheism',
#  'belief',
#  'non',
#  'existence',
#  'god',
#  'includes',
#  'great',
#  'refutation',
#  'challenging',
#  'argument',
#  'god',
#  'particular',
#  'attention',
#  'paid',
#  'refuting',
#  'contempory',
#  'theist',
#  'platinga',
#  'swinburne',
#  '5',
#  '4',
#  '1',
#  'page',
#  'isbn',
#  '0-87722',
#  '642-3',
#  'hardcover',
#  'paperback',
#  'also',
#  'available',
#  'case',
#  'christianity',
#  'temple',
#  'university',
#  'press',
#  'comprehensive',
#  'critique',
#  'christianity',
#  'considers',
#  'best',
#  'contemporary',
#  'defence',
#  'christianity',
#  'ultimately',
#  'demonstrates',
#  'unsupportable',
#  '/',
#  'incoherent',
#  '2',
#  '7',
#  '3',
#  'page',
#  'isbn',
#  '0-87722',
#  '767-5',
#  'james',
#  'turner',
#  'without',
#  'god',
#  'without',
#  'creed',
#  'johns',
#  'hopkins',
#  'university',
#  'press',
#  'baltimore',
#  'md',
#  'usa',
#  'subtitled',
#  'origins',
#  'unbelief',
#  'america',
#  'examines',
#  'way',
#  'unbelief',
#  'whether',
#  'agnostic',
#  'atheistic',
#  'became',
#  'mainstream',
#  'alternative',
#  'world',
#  'view',
#  'focusses',
#  'period',
#  '1770-1900',
#  'considering',
#  'france',
#  'britain',
#  'emphasis',
#  'american',
#  'particularly',
#  'new',
#  'england',
#  'development',
#  'neither',
#  'religious',
#  'history',
#  'secularization',
#  'atheism',
#  'without',
#  'god',
#  'without',
#  'creed',
#  'rather',
#  'intellectual',
#  'history',
#  'fate',
#  'single',
#  'idea',
#  'belief',
#  'god',
#  'exists',
#  '3',
#  '1',
#  '6',
#  'page',
#  'isbn',
#  'hardcover',
#  '0-8018',
#  '2',
#  '4',
#  '9',
#  '4',
#  'x',
#  'paper',
#  '0-8018',
#  '3407-4',
#  'george',
#  'seldes',
#  'editor',
#  'great',
#  'thought',
#  'ballantine',
#  'books',
#  'new',
#  'york',
#  'usa',
#  'dictionary',
#  'quotation',
#  'different',
#  'kind',
#  'concentrating',
#  'statement',
#  'writing',
#  'explicitly',
#  'implicitly',
#  'present',
#  "person's",
#  'philosophy',
#  'world',
#  'view',
#  'includes',
#  ...]

# %%
threegrams = []
for i in range(len(data) - 2):
        threegrams.append((data[i], data[i+1], data[i+2]))

# %%
threegrams
# Out:
# [('mathew', 'mathew@mantis.co.uk', 'subject'),
#  ('mathew@mantis.co.uk', 'subject', 'alt'),
#  ('subject', 'alt', 'atheism'),
#  ('alt', 'atheism', 'faq'),
#  ('atheism', 'faq', 'atheist'),
#  ('faq', 'atheist', 'resources'),
#  ('atheist', 'resources', 'summary'),
#  ('resources', 'summary', 'books'),
#  ('summary', 'books', 'address'),
#  ('books', 'address', 'music'),
#  ('address', 'music', 'anything'),
#  ('music', 'anything', 'related'),
#  ('anything', 'related', 'atheism'),
#  ('related', 'atheism', 'keywords'),
#  ('atheism', 'keywords', 'faq'),
#  ('keywords', 'faq', 'atheism'),
#  ('faq', 'atheism', 'book'),
#  ('atheism', 'book', 'music'),
#  ('book', 'music', 'fiction'),
#  ('music', 'fiction', 'address'),
#  ('fiction', 'address', 'contact'),
#  ('address', 'contact', 'expires'),
#  ('contact', 'expires', 'thu'),
#  ('expires', 'thu', '29 apr 1993'),
#  ('thu', '29 apr 1993', '11:57:19'),
#  ('29 apr 1993', '11:57:19', 'gmt'),
#  ('11:57:19', 'gmt', 'distribution'),
#  ('gmt', 'distribution', 'world'),
#  ('distribution', 'world', 'organization'),
#  ('world', 'organization', 'mantis'),
#  ('organization', 'mantis', 'consultants'),
#  ('mantis', 'consultants', 'cambridge'),
#  ('consultants', 'cambridge', 'uk'),
#  ('cambridge', 'uk', 'supersedes'),
#  ('uk', 'supersedes', '19930301143317@mantis.co.uk'),
#  ('supersedes', '19930301143317@mantis.co.uk', 'lines'),
#  ('19930301143317@mantis.co.uk', 'lines', '2'),
#  ('lines', '2', '9'),
#  ('2', '9', '0'),
#  ('9', '0', 'archive'),
#  ('0', 'archive', 'name'),
#  ('archive', 'name', 'atheism'),
#  ('name', 'atheism', '/'),
#  ('atheism', '/', 'resource'),
#  ('/', 'resource', 'alt'),
#  ('resource', 'alt', 'atheism'),
#  ('alt', 'atheism', 'archive'),
#  ('atheism', 'archive', 'name'),
#  ('archive', 'name', 'resource'),
#  ('name', 'resource', 'last'),
#  ('resource', 'last', 'modified'),
#  ('last', 'modified', '11 december 1992'),
#  ('modified', '11 december 1992', 'version'),
#  ('11 december 1992', 'version', '1'),
#  ('version', '1', '0'),
#  ('1', '0', 'atheist'),
#  ('0', 'atheist', 'resources'),
#  ('atheist', 'resources', 'addresses'),
#  ('resources', 'addresses', 'atheist'),
#  ('addresses', 'atheist', 'organizations'),
#  ('atheist', 'organizations', 'usa'),
#  ('organizations', 'usa', 'freedom'),
#  ('usa', 'freedom', 'religion'),
#  ('freedom', 'religion', 'foundation'),
#  ('religion', 'foundation', 'darwin'),
#  ('foundation', 'darwin', 'fish'),
#  ('darwin', 'fish', 'bumper'),
#  ('fish', 'bumper', 'sticker'),
#  ('bumper', 'sticker', 'assorted'),
#  ('sticker', 'assorted', 'atheist'),
#  ('assorted', 'atheist', 'paraphernalia'),
#  ('atheist', 'paraphernalia', 'available'),
#  ('paraphernalia', 'available', 'freedom'),
#  ('available', 'freedom', 'religion'),
#  ('freedom', 'religion', 'foundation'),
#  ('religion', 'foundation', 'us'),
#  ('foundation', 'us', 'write'),
#  ('us', 'write', 'ffrf'),
#  ('write', 'ffrf', 'p'),
#  ('ffrf', 'p', 'box'),
#  ('p', 'box', '7'),
#  ('box', '7', '5'),
#  ('7', '5', '0'),
#  ('5', '0', 'madison'),
#  ('0', 'madison', 'wi'),
#  ('madison', 'wi', '53701'),
#  ('wi', '53701', 'telephone'),
#  ('53701', 'telephone', 'evolution'),
#  ('telephone', 'evolution', 'designs'),
#  ('evolution', 'designs', 'evolution'),
#  ('designs', 'evolution', 'designs'),
#  ('evolution', 'designs', 'sell'),
#  ('designs', 'sell', 'darwin'),
#  ('sell', 'darwin', 'fish'),
#  ('darwin', 'fish', 'fish'),
#  ('fish', 'fish', 'symbol'),
#  ('fish', 'symbol', 'like'),
#  ('symbol', 'like', 'one'),
#  ('like', 'one', 'christians'),
#  ('one', 'christians', 'stick'),
#  ('christians', 'stick', 'car'),
#  ('stick', 'car', 'foot'),
#  ('car', 'foot', 'word'),
#  ('foot', 'word', 'darwin'),
#  ('word', 'darwin', 'written'),
#  ('darwin', 'written', 'inside'),
#  ('written', 'inside', 'deluxe'),
#  ('inside', 'deluxe', 'moulded'),
#  ('deluxe', 'moulded', '3'),
#  ('moulded', '3', 'plastic'),
#  ('3', 'plastic', 'fish'),
#  ('plastic', 'fish', '$4.95'),
#  ('fish', '$4.95', 'postpaid'),
#  ('$4.95', 'postpaid', 'us'),
#  ('postpaid', 'us', 'write'),
#  ('us', 'write', 'evolution'),
#  ('write', 'evolution', 'designs'),
#  ('evolution', 'designs', '7'),
#  ('designs', '7', '1'),
#  ('7', '1', '1'),
#  ('1', '1', '9'),
#  ('1', '9', 'laurel'),
#  ('9', 'laurel', 'canyon'),
#  ('laurel', 'canyon', '#'),
#  ('canyon', '#', '4'),
#  ('#', '4', 'north'),
#  ('4', 'north', 'hollywood'),
#  ('north', 'hollywood', 'ca'),
#  ('hollywood', 'ca', '91605'),
#  ('ca', '91605', 'people'),
#  ('91605', 'people', 'san'),
#  ('people', 'san', 'francisco'),
#  ('san', 'francisco', 'bay'),
#  ('francisco', 'bay', 'area'),
#  ('bay', 'area', 'get'),
#  ('area', 'get', 'darwin'),
#  ('get', 'darwin', 'fish'),
#  ('darwin', 'fish', 'lynn'),
#  ('fish', 'lynn', 'gold'),
#  ('lynn', 'gold', 'try'),
#  ('gold', 'try', 'mailing'),
#  ('try', 'mailing', 'figmo@netcom.com'),
#  ('mailing', 'figmo@netcom.com', 'net'),
#  ('figmo@netcom.com', 'net', 'people'),
#  ('net', 'people', 'go'),
#  ('people', 'go', 'lynn'),
#  ('go', 'lynn', 'directly'),
#  ('lynn', 'directly', 'price'),
#  ('directly', 'price', '$4.95'),
#  ('price', '$4.95', 'per'),
#  ('$4.95', 'per', 'fish'),
#  ('per', 'fish', 'american'),
#  ('fish', 'american', 'atheist'),
#  ('american', 'atheist', 'press'),
#  ('atheist', 'press', 'aap'),
#  ('press', 'aap', 'publish'),
#  ('aap', 'publish', 'various'),
#  ('publish', 'various', 'atheist'),
#  ('various', 'atheist', 'book'),
#  ('atheist', 'book', 'critique'),
#  ('book', 'critique', 'bible'),
#  ('critique', 'bible', 'list'),
#  ('bible', 'list', 'biblical'),
#  ('list', 'biblical', 'contradiction'),
#  ('biblical', 'contradiction', 'one'),
#  ('contradiction', 'one', 'book'),
#  ('one', 'book', 'bible'),
#  ('book', 'bible', 'handbook'),
#  ('bible', 'handbook', 'w'),
#  ('handbook', 'w', 'p'),
#  ('w', 'p', 'ball'),
#  ('p', 'ball', 'g'),
#  ('ball', 'g', 'w'),
#  ('g', 'w', 'foote'),
#  ('w', 'foote', 'american'),
#  ('foote', 'american', 'atheist'),
#  ('american', 'atheist', 'press'),
#  ('atheist', 'press', '3'),
#  ('press', '3', '7'),
#  ('3', '7', '2'),
#  ('7', '2', 'pp'),
#  ('2', 'pp', 'isbn'),
#  ('pp', 'isbn', '0-910309'),
#  ('isbn', '0-910309', '2'),
#  ('0-910309', '2', '6'),
#  ('2', '6', '4'),
#  ('6', '4', '2'),
#  ('4', '2', 'nd'),
#  ('2', 'nd', 'edition'),
#  ('nd', 'edition', '1'),
#  ('edition', '1', '9'),
#  ('1', '9', '8'),
#  ('9', '8', '6'),
#  ('8', '6', 'bible'),
#  ('6', 'bible', 'contradiction'),
#  ('bible', 'contradiction', 'absurdity'),
#  ('contradiction', 'absurdity', 'atrocity'),
#  ('absurdity', 'atrocity', 'immorality'),
#  ('atrocity', 'immorality', 'contains'),
#  ('immorality', 'contains', 'ball'),
#  ('contains', 'ball', 'foote'),
#  ('ball', 'foote', 'bible'),
#  ('foote', 'bible', 'contradicts'),
#  ('bible', 'contradicts', 'aap'),
#  ('contradicts', 'aap', 'based'),
#  ('aap', 'based', 'king'),
#  ('based', 'king', 'james'),
#  ('king', 'james', 'version'),
#  ('james', 'version', 'bible'),
#  ('version', 'bible', 'write'),
#  ('bible', 'write', 'american'),
#  ('write', 'american', 'atheist'),
#  ('american', 'atheist', 'press'),
#  ('atheist', 'press', 'p'),
#  ('press', 'p', 'box'),
#  ('p', 'box', '140195'),
#  ('box', '140195', 'austin'),
#  ('140195', 'austin', 'tx'),
#  ('austin', 'tx', '78714-0195'),
#  ('tx', '78714-0195', '7'),
#  ('78714-0195', '7', '2'),
#  ('7', '2', '1'),
#  ('2', '1', '5'),
#  ('1', '5', 'cameron'),
#  ('5', 'cameron', 'road'),
#  ('cameron', 'road', 'austin'),
#  ('road', 'austin', 'tx'),
#  ('austin', 'tx', '78752-2973'),
#  ('tx', '78752-2973', 'telephone'),
#  ('78752-2973', 'telephone', 'fax'),
#  ('telephone', 'fax', 'prometheus'),
#  ('fax', 'prometheus', 'books'),
#  ('prometheus', 'books', 'sell'),
#  ('books', 'sell', 'book'),
#  ('sell', 'book', 'including'),
#  ('book', 'including', "haught's"),
#  ('including', "haught's", 'holy'),
#  ("haught's", 'holy', 'horrors'),
#  ('holy', 'horrors', 'see'),
#  ('horrors', 'see', 'write'),
#  ('see', 'write', '7'),
#  ('write', '7', '0'),
#  ('7', '0', '0'),
#  ('0', '0', 'east'),
#  ('0', 'east', 'amherst'),
#  ('east', 'amherst', 'street'),
#  ('amherst', 'street', 'buffalo'),
#  ('street', 'buffalo', 'new'),
#  ('buffalo', 'new', 'york'),
#  ('new', 'york', '14215'),
#  ('york', '14215', 'telephone'),
#  ('14215', 'telephone', 'alternate'),
#  ('telephone', 'alternate', 'address'),
#  ('alternate', 'address', 'may'),
#  ('address', 'may', 'newer'),
#  ('may', 'newer', 'older'),
#  ('newer', 'older', 'prometheus'),
#  ('older', 'prometheus', 'books'),
#  ('prometheus', 'books', '5'),
#  ('books', '5', '9'),
#  ('5', '9', 'glenn'),
#  ('9', 'glenn', 'drive'),
#  ('glenn', 'drive', 'buffalo'),
#  ('drive', 'buffalo', 'ny'),
#  ('buffalo', 'ny', '14228-2197'),
#  ('ny', '14228-2197', 'african'),
#  ('14228-2197', 'african', 'americans'),
#  ('african', 'americans', 'humanism'),
#  ('americans', 'humanism', 'organization'),
#  ('humanism', 'organization', 'promoting'),
#  ('organization', 'promoting', 'black'),
#  ('promoting', 'black', 'secular'),
#  ('black', 'secular', 'humanism'),
#  ('secular', 'humanism', 'uncovering'),
#  ('humanism', 'uncovering', 'history'),
#  ('uncovering', 'history', 'black'),
#  ('history', 'black', 'freethought'),
#  ('black', 'freethought', 'publish'),
#  ('freethought', 'publish', 'quarterly'),
#  ('publish', 'quarterly', 'newsletter'),
#  ('quarterly', 'newsletter', 'aah'),
#  ('newsletter', 'aah', 'examiner'),
#  ('aah', 'examiner', 'write'),
#  ('examiner', 'write', 'norm'),
#  ('write', 'norm', 'r'),
#  ('norm', 'r', 'allen'),
#  ('r', 'allen', 'jr'),
#  ('allen', 'jr', 'african'),
#  ('jr', 'african', 'americans'),
#  ('african', 'americans', 'humanism'),
#  ('americans', 'humanism', 'p'),
#  ('humanism', 'p', 'box'),
#  ('p', 'box', '6'),
#  ('box', '6', '6'),
#  ('6', '6', '4'),
#  ('6', '4', 'buffalo'),
#  ('4', 'buffalo', 'ny'),
#  ('buffalo', 'ny', '14226'),
#  ('ny', '14226', 'united'),
#  ('14226', 'united', 'kingdom'),
#  ('united', 'kingdom', 'rationalist'),
#  ('kingdom', 'rationalist', 'press'),
#  ('rationalist', 'press', 'association'),
#  ('press', 'association', 'national'),
#  ('association', 'national', 'secular'),
#  ('national', 'secular', 'society'),
#  ('secular', 'society', '8'),
#  ('society', '8', '8'),
#  ('8', '8', 'islington'),
#  ('8', 'islington', 'high'),
#  ('islington', 'high', 'street'),
#  ('high', 'street', '7'),
#  ('street', '7', '0'),
#  ('7', '0', '2'),
#  ('0', '2', 'holloway'),
#  ('2', 'holloway', 'road'),
#  ('holloway', 'road', 'london'),
#  ('road', 'london', 'n'),
#  ('london', 'n', '1'),
#  ('n', '1', '8'),
#  ('1', '8', 'ew'),
#  ('8', 'ew', 'london'),
#  ('ew', 'london', 'n'),
#  ('london', 'n', '1'),
#  ('n', '1', '9'),
#  ('1', '9', '3'),
#  ('9', '3', 'nl'),
#  ('3', 'nl', 'nl'),
#  ('nl', 'nl', 'nl'),
#  ('nl', 'nl', '071 226'),
#  ('nl', '071 226', '7'),
#  ('071 226', '7', '2'),
#  ('7', '2', '5'),
#  ('2', '5', '1'),
#  ('5', '1', '0'),
#  ('1', '0', '7'),
#  ('0', '7', '1'),
#  ('7', '1', '2'),
#  ('1', '2', '7'),
#  ('2', '7', '2'),
#  ('7', '2', '1'),
#  ('2', '1', '2'),
#  ('1', '2', '6'),
#  ('2', '6', '6'),
#  ('6', '6', 'british'),
#  ('6', 'british', 'humanist'),
#  ('british', 'humanist', 'association'),
#  ('humanist', 'association', 'south'),
#  ('association', 'south', 'place'),
#  ('south', 'place', 'ethical'),
#  ('place', 'ethical', 'society'),
#  ('ethical', 'society', '1'),
#  ('society', '1', '4'),
#  ('1', '4', "lamb's"),
#  ('4', "lamb's", 'conduit'),
#  ("lamb's", 'conduit', 'passage'),
#  ('conduit', 'passage', 'conway'),
#  ('passage', 'conway', 'hall'),
#  ('conway', 'hall', 'london'),
#  ('hall', 'london', 'wc'),
#  ('london', 'wc', '1'),
#  ('wc', '1', 'r'),
#  ('1', 'r', '4'),
#  ('r', '4', 'rh'),
#  ('4', 'rh', 'red'),
#  ('rh', 'red', 'lion'),
#  ('red', 'lion', 'square'),
#  ('lion', 'square', 'square'),
#  ('square', 'square', 'square'),
#  ('square', 'square', '071 430'),
#  ('square', '071 430', '0'),
#  ('071 430', '0', '9'),
#  ('0', '9', '0'),
#  ('9', '0', '8'),
#  ('0', '8', 'london'),
#  ('8', 'london', 'wc'),
#  ('london', 'wc', '1'),
#  ('wc', '1', 'r'),
#  ('1', 'r', '4'),
#  ('r', '4', 'rl'),
#  ('4', 'rl', 'fax 071 430'),
#  ('rl', 'fax 071 430', '1'),
#  ('fax 071 430', '1', '2'),
#  ('1', '2', '7'),
#  ('2', '7', '1'),
#  ('7', '1', '0'),
#  ('1', '0', '7'),
#  ('0', '7', '1'),
#  ('7', '1', '8'),
#  ('1', '8', '3'),
#  ('8', '3', '1'),
#  ('3', '1', '7'),
#  ('1', '7', '7'),
#  ('7', '7', '2'),
#  ('7', '2', '3'),
#  ('2', '3', 'national'),
#  ('3', 'national', 'secular'),
#  ('national', 'secular', 'society'),
#  ('secular', 'society', 'publish'),
#  ('society', 'publish', 'freethinker'),
#  ('publish', 'freethinker', 'monthly'),
#  ('freethinker', 'monthly', 'magazine'),
#  ('monthly', 'magazine', 'founded'),
#  ('magazine', 'founded', '1'),
#  ('founded', '1', '8'),
#  ('1', '8', '8'),
#  ('8', '8', '1'),
#  ('8', '1', 'germany'),
#  ('1', 'germany', 'ibka'),
#  ('germany', 'ibka', 'e'),
#  ('ibka', 'e', 'v'),
#  ('e', 'v', 'internationaler'),
#  ('v', 'internationaler', 'bund'),
#  ('internationaler', 'bund', 'der'),
#  ('bund', 'der', 'konfessionslosen'),
#  ('der', 'konfessionslosen', 'und'),
#  ('konfessionslosen', 'und', 'atheisten'),
#  ('und', 'atheisten', 'postfach'),
#  ('atheisten', 'postfach', '8'),
#  ('postfach', '8', '8'),
#  ('8', '8', '0'),
#  ('8', '0', '1'),
#  ('0', '1', '0'),
#  ('1', '0', '00 berlin 41'),
#  ('0', '00 berlin 41', 'germany'),
#  ('00 berlin 41', 'germany', 'ibka'),
#  ('germany', 'ibka', 'publish'),
#  ('ibka', 'publish', 'journal'),
#  ('publish', 'journal', 'miz'),
#  ('journal', 'miz', 'materialien'),
#  ('miz', 'materialien', 'und'),
#  ('materialien', 'und', 'informationen'),
#  ('und', 'informationen', 'zur'),
#  ('informationen', 'zur', 'zeit'),
#  ('zur', 'zeit', 'politisches'),
#  ('zeit', 'politisches', 'journal'),
#  ('politisches', 'journal', 'der'),
#  ('journal', 'der', 'konfessionslosesn'),
#  ('der', 'konfessionslosesn', 'und'),
#  ('konfessionslosesn', 'und', 'atheisten'),
#  ('und', 'atheisten', 'hrsg'),
#  ('atheisten', 'hrsg', 'ibka'),
#  ('hrsg', 'ibka', 'e'),
#  ('ibka', 'e', 'v'),
#  ('e', 'v', 'miz'),
#  ('v', 'miz', 'vertrieb'),
#  ('miz', 'vertrieb', 'postfach'),
#  ('vertrieb', 'postfach', '8'),
#  ('postfach', '8', '8'),
#  ('8', '8', '0'),
#  ('8', '0', '1'),
#  ('0', '1', '0'),
#  ('1', '0', '00 berlin 41'),
#  ('0', '00 berlin 41', 'germany'),
#  ('00 berlin 41', 'germany', 'atheist'),
#  ('germany', 'atheist', 'book'),
#  ('atheist', 'book', 'write'),
#  ('book', 'write', 'ibdk'),
#  ('write', 'ibdk', 'internationaler'),
#  ('ibdk', 'internationaler', 'b'),
#  ('internationaler', 'b', 'ucherdienst'),
#  ('b', 'ucherdienst', 'der'),
#  ('ucherdienst', 'der', 'konfessionslosen'),
#  ('der', 'konfessionslosen', 'postfach'),
#  ('konfessionslosen', 'postfach', '3'),
#  ('postfach', '3', '0'),
#  ('3', '0', '0'),
#  ('0', '0', '5'),
#  ('0', '5', '3'),
#  ('5', '3', '0'),
#  ('3', '0', '00 hannover 1'),
#  ('0', '00 hannover 1', 'germany'),
#  ('00 hannover 1', 'germany', 'telephone'),
#  ('germany', 'telephone', '0511/2112'),
#  ('telephone', '0511/2112', '1'),
#  ('0511/2112', '1', '6'),
#  ('1', '6', 'books'),
#  ('6', 'books', 'fiction'),
#  ('books', 'fiction', 'thomas'),
#  ('fiction', 'thomas', 'disch'),
#  ('thomas', 'disch', 'santa'),
#  ('disch', 'santa', 'claus'),
#  ('santa', 'claus', 'compromise'),
#  ('claus', 'compromise', 'short'),
#  ('compromise', 'short', 'story'),
#  ('short', 'story', 'ultimate'),
#  ('story', 'ultimate', 'proof'),
#  ('ultimate', 'proof', 'santa'),
#  ('proof', 'santa', 'exists'),
#  ('santa', 'exists', 'character'),
#  ('exists', 'character', 'event'),
#  ('character', 'event', 'fictitious'),
#  ('event', 'fictitious', 'similarity'),
#  ('fictitious', 'similarity', 'living'),
#  ('similarity', 'living', 'dead'),
#  ('living', 'dead', 'god'),
#  ('dead', 'god', 'uh'),
#  ('god', 'uh', 'well'),
#  ('uh', 'well', 'walter'),
#  ('well', 'walter', 'miller'),
#  ('walter', 'miller', 'jr'),
#  ('miller', 'jr', 'canticle'),
#  ('jr', 'canticle', 'leibowitz'),
#  ('canticle', 'leibowitz', 'one'),
#  ('leibowitz', 'one', 'gem'),
#  ('one', 'gem', 'post'),
#  ('gem', 'post', 'atomic'),
#  ('post', 'atomic', 'doomsday'),
#  ('atomic', 'doomsday', 'novel'),
#  ('doomsday', 'novel', 'monk'),
#  ('novel', 'monk', 'spent'),
#  ('monk', 'spent', 'life'),
#  ('spent', 'life', 'copying'),
#  ('life', 'copying', 'blueprint'),
#  ('copying', 'blueprint', 'saint'),
#  ('blueprint', 'saint', 'leibowitz'),
#  ('saint', 'leibowitz', 'filling'),
#  ('leibowitz', 'filling', 'sheet'),
#  ('filling', 'sheet', 'paper'),
#  ('sheet', 'paper', 'ink'),
#  ('paper', 'ink', 'leaving'),
#  ('ink', 'leaving', 'white'),
#  ('leaving', 'white', 'line'),
#  ('white', 'line', 'letter'),
#  ('line', 'letter', 'edgar'),
#  ('letter', 'edgar', 'pangborn'),
#  ('edgar', 'pangborn', 'davy'),
#  ('pangborn', 'davy', 'post'),
#  ('davy', 'post', 'atomic'),
#  ('post', 'atomic', 'doomsday'),
#  ('atomic', 'doomsday', 'novel'),
#  ('doomsday', 'novel', 'set'),
#  ('novel', 'set', 'clerical'),
#  ('set', 'clerical', 'state'),
#  ('clerical', 'state', 'church'),
#  ('state', 'church', 'example'),
#  ('church', 'example', 'forbids'),
#  ('example', 'forbids', 'anyone'),
#  ('forbids', 'anyone', 'produce'),
#  ('anyone', 'produce', 'describe'),
#  ('produce', 'describe', 'use'),
#  ('describe', 'use', 'substance'),
#  ('use', 'substance', 'containing'),
#  ('substance', 'containing', 'atom'),
#  ('containing', 'atom', 'philip'),
#  ('atom', 'philip', 'k'),
#  ('philip', 'k', 'dick'),
#  ('k', 'dick', 'philip'),
#  ('dick', 'philip', 'k'),
#  ('philip', 'k', 'dick'),
#  ('k', 'dick', 'dick'),
#  ('dick', 'dick', 'wrote'),
#  ('dick', 'wrote', 'many'),
#  ('wrote', 'many', 'philosophical'),
#  ('many', 'philosophical', 'thought'),
#  ('philosophical', 'thought', 'provoking'),
#  ('thought', 'provoking', 'short'),
#  ('provoking', 'short', 'story'),
#  ('short', 'story', 'novel'),
#  ('story', 'novel', 'story'),
#  ('novel', 'story', 'bizarre'),
#  ('story', 'bizarre', 'time'),
#  ('bizarre', 'time', 'approachable'),
#  ('time', 'approachable', 'wrote'),
#  ('approachable', 'wrote', 'mainly'),
#  ('wrote', 'mainly', 'sf'),
#  ('mainly', 'sf', 'wrote'),
#  ('sf', 'wrote', 'people'),
#  ('wrote', 'people', 'truth'),
#  ('people', 'truth', 'religion'),
#  ('truth', 'religion', 'rather'),
#  ('religion', 'rather', 'technology'),
#  ('rather', 'technology', 'although'),
#  ('technology', 'although', 'often'),
#  ('although', 'often', 'believed'),
#  ('often', 'believed', 'met'),
#  ('believed', 'met', 'sort'),
#  ('met', 'sort', 'god'),
#  ('sort', 'god', 'remained'),
#  ('god', 'remained', 'sceptical'),
#  ('remained', 'sceptical', 'amongst'),
#  ('sceptical', 'amongst', 'novel'),
#  ('amongst', 'novel', 'following'),
#  ('novel', 'following', 'relevance'),
#  ('following', 'relevance', 'galactic'),
#  ('relevance', 'galactic', 'pot'),
#  ('galactic', 'pot', 'healer'),
#  ('pot', 'healer', 'fallible'),
#  ('healer', 'fallible', 'alien'),
#  ('fallible', 'alien', 'deity'),
#  ('alien', 'deity', 'summons'),
#  ('deity', 'summons', 'group'),
#  ('summons', 'group', 'earth'),
#  ('group', 'earth', 'craftsman'),
#  ('earth', 'craftsman', 'woman'),
#  ('craftsman', 'woman', 'remote'),
#  ('woman', 'remote', 'planet'),
#  ('remote', 'planet', 'raise'),
#  ('planet', 'raise', 'giant'),
#  ('raise', 'giant', 'cathedral'),
#  ('giant', 'cathedral', 'beneath'),
#  ('cathedral', 'beneath', 'ocean'),
#  ('beneath', 'ocean', 'deity'),
#  ('ocean', 'deity', 'begin'),
#  ('deity', 'begin', 'demand'),
#  ('begin', 'demand', 'faith'),
#  ('demand', 'faith', 'earthers'),
#  ('faith', 'earthers', 'pot'),
#  ('earthers', 'pot', 'healer'),
#  ('pot', 'healer', 'joe'),
#  ('healer', 'joe', 'fernwright'),
#  ('joe', 'fernwright', 'unable'),
#  ('fernwright', 'unable', 'comply'),
#  ('unable', 'comply', 'polished'),
#  ('comply', 'polished', 'ironic'),
#  ('polished', 'ironic', 'amusing'),
#  ('ironic', 'amusing', 'novel'),
#  ('amusing', 'novel', 'maze'),
#  ('novel', 'maze', 'death'),
#  ('maze', 'death', 'noteworthy'),
#  ('death', 'noteworthy', 'description'),
#  ('noteworthy', 'description', 'technology'),
#  ('description', 'technology', 'based'),
#  ('technology', 'based', 'religion'),
#  ('based', 'religion', 'valis'),
#  ('religion', 'valis', 'schizophrenic'),
#  ('valis', 'schizophrenic', 'hero'),
#  ('schizophrenic', 'hero', 'search'),
#  ('hero', 'search', 'hidden'),
#  ('search', 'hidden', 'mystery'),
#  ('hidden', 'mystery', 'gnostic'),
#  ('mystery', 'gnostic', 'christianity'),
#  ('gnostic', 'christianity', 'reality'),
#  ('christianity', 'reality', 'fired'),
#  ('reality', 'fired', 'brain'),
#  ('fired', 'brain', 'pink'),
#  ('brain', 'pink', 'laser'),
#  ('pink', 'laser', 'beam'),
#  ('laser', 'beam', 'unknown'),
#  ('beam', 'unknown', 'possibly'),
#  ('unknown', 'possibly', 'divine'),
#  ('possibly', 'divine', 'origin'),
#  ('divine', 'origin', 'accompanied'),
#  ('origin', 'accompanied', 'dogmatic'),
#  ('accompanied', 'dogmatic', 'dismissively'),
#  ('dogmatic', 'dismissively', 'atheist'),
#  ('dismissively', 'atheist', 'friend'),
#  ('atheist', 'friend', 'assorted'),
#  ('friend', 'assorted', 'odd'),
#  ('assorted', 'odd', 'character'),
#  ('odd', 'character', 'divine'),
#  ('character', 'divine', 'invasion'),
#  ('divine', 'invasion', 'god'),
#  ('invasion', 'god', 'invades'),
#  ('god', 'invades', 'earth'),
#  ('invades', 'earth', 'making'),
#  ('earth', 'making', 'young'),
#  ('making', 'young', 'woman'),
#  ('young', 'woman', 'pregnant'),
#  ('woman', 'pregnant', 'return'),
#  ('pregnant', 'return', 'another'),
#  ('return', 'another', 'star'),
#  ('another', 'star', 'system'),
#  ('star', 'system', 'unfortunately'),
#  ('system', 'unfortunately', 'terminally'),
#  ('unfortunately', 'terminally', 'ill'),
#  ('terminally', 'ill', 'must'),
#  ('ill', 'must', 'assisted'),
#  ('must', 'assisted', 'dead'),
#  ('assisted', 'dead', 'man'),
#  ('dead', 'man', 'whose'),
#  ('man', 'whose', 'brain'),
#  ('whose', 'brain', 'wired'),
#  ('brain', 'wired', '2'),
#  ('wired', '2', '4'),
#  ('2', '4', 'hour'),
#  ('4', 'hour', 'easy'),
#  ('hour', 'easy', 'listening'),
#  ('easy', 'listening', 'music'),
#  ('listening', 'music', 'margaret'),
#  ('music', 'margaret', 'atwood'),
#  ('margaret', 'atwood', "handmaid's"),
#  ('atwood', "handmaid's", 'tale'),
#  ("handmaid's", 'tale', 'story'),
#  ('tale', 'story', 'based'),
#  ('story', 'based', 'premise'),
#  ('based', 'premise', 'us'),
#  ('premise', 'us', 'congress'),
#  ('us', 'congress', 'mysteriously'),
#  ('congress', 'mysteriously', 'assassinated'),
#  ('mysteriously', 'assassinated', 'fundamentalist'),
#  ('assassinated', 'fundamentalist', 'quickly'),
#  ('fundamentalist', 'quickly', 'take'),
#  ('quickly', 'take', 'charge'),
#  ('take', 'charge', 'nation'),
#  ('charge', 'nation', 'set'),
#  ('nation', 'set', 'right'),
#  ('set', 'right', 'book'),
#  ('right', 'book', 'diary'),
#  ('book', 'diary', "woman's"),
#  ('diary', "woman's", 'life'),
#  ("woman's", 'life', 'try'),
#  ('life', 'try', 'live'),
#  ('try', 'live', 'new'),
#  ('live', 'new', 'christian'),
#  ('new', 'christian', 'theocracy'),
#  ('christian', 'theocracy', "women's"),
#  ('theocracy', "women's", 'right'),
#  ("women's", 'right', 'property'),
#  ('right', 'property', 'revoked'),
#  ('property', 'revoked', 'bank'),
#  ('revoked', 'bank', 'account'),
#  ('bank', 'account', 'closed'),
#  ('account', 'closed', 'sinful'),
#  ('closed', 'sinful', 'luxury'),
#  ('sinful', 'luxury', 'outlawed'),
#  ('luxury', 'outlawed', 'radio'),
#  ('outlawed', 'radio', 'used'),
#  ('radio', 'used', 'reading'),
#  ('used', 'reading', 'bible'),
#  ('reading', 'bible', 'crimes'),
#  ('bible', 'crimes', 'punished'),
#  ('crimes', 'punished', 'retroactively'),
#  ('punished', 'retroactively', 'doctor'),
#  ('retroactively', 'doctor', 'performed'),
#  ('doctor', 'performed', 'legal'),
#  ('performed', 'legal', 'abortion'),
#  ('legal', 'abortion', 'old'),
#  ('abortion', 'old', 'world'),
#  ('old', 'world', 'hunted'),
#  ('world', 'hunted', 'hanged'),
#  ('hunted', 'hanged', "atwood's"),
#  ('hanged', "atwood's", 'writing'),
#  ("atwood's", 'writing', 'style'),
#  ('writing', 'style', 'difficult'),
#  ('style', 'difficult', 'get'),
#  ('difficult', 'get', 'used'),
#  ('get', 'used', 'first'),
#  ('used', 'first', 'tale'),
#  ('first', 'tale', 'grows'),
#  ('tale', 'grows', 'chilling'),
#  ('grows', 'chilling', 'go'),
#  ('chilling', 'go', 'various'),
#  ('go', 'various', 'authors'),
#  ('various', 'authors', 'bible'),
#  ('authors', 'bible', 'somewhat'),
#  ('bible', 'somewhat', 'dull'),
#  ('somewhat', 'dull', 'rambling'),
#  ('dull', 'rambling', 'work'),
#  ('rambling', 'work', 'ha'),
#  ('work', 'ha', 'often'),
#  ('ha', 'often', 'criticized'),
#  ('often', 'criticized', 'however'),
#  ('criticized', 'however', 'probably'),
#  ('however', 'probably', 'worth'),
#  ('probably', 'worth', 'reading'),
#  ('worth', 'reading', 'know'),
#  ('reading', 'know', 'fuss'),
#  ('know', 'fuss', 'exists'),
#  ('fuss', 'exists', 'many'),
#  ('exists', 'many', 'different'),
#  ('many', 'different', 'version'),
#  ('different', 'version', 'make'),
#  ('version', 'make', 'sure'),
#  ('make', 'sure', 'get'),
#  ('sure', 'get', 'one'),
#  ('get', 'one', 'true'),
#  ('one', 'true', 'version'),
#  ('true', 'version', 'books'),
#  ('version', 'books', 'non'),
#  ('books', 'non', 'fiction'),
#  ('non', 'fiction', 'peter'),
#  ('fiction', 'peter', 'de'),
#  ('peter', 'de', 'rosa'),
#  ('de', 'rosa', 'vicars'),
#  ('rosa', 'vicars', 'christ'),
#  ('vicars', 'christ', 'bantam'),
#  ('christ', 'bantam', 'press'),
#  ('bantam', 'press', '1'),
#  ('press', '1', '9'),
#  ('1', '9', '8'),
#  ('9', '8', '8'),
#  ('8', '8', 'although'),
#  ('8', 'although', 'de'),
#  ('although', 'de', 'rosa'),
#  ('de', 'rosa', 'seems'),
#  ('rosa', 'seems', 'christian'),
#  ('seems', 'christian', 'even'),
#  ('christian', 'even', 'catholic'),
#  ('even', 'catholic', 'enlighting'),
#  ('catholic', 'enlighting', 'history'),
#  ('enlighting', 'history', 'papal'),
#  ('history', 'papal', 'immorality'),
#  ('papal', 'immorality', 'adultery'),
#  ('immorality', 'adultery', 'fallacy'),
#  ('adultery', 'fallacy', 'etc'),
#  ('fallacy', 'etc', 'german'),
#  ('etc', 'german', 'translation'),
#  ('german', 'translation', 'gottes'),
#  ('translation', 'gottes', 'erste'),
#  ('gottes', 'erste', 'diener'),
#  ('erste', 'diener', 'die'),
#  ('diener', 'die', 'dunkle'),
#  ('die', 'dunkle', 'seite'),
#  ('dunkle', 'seite', 'de'),
#  ('seite', 'de', 'papsttums'),
#  ('de', 'papsttums', 'droemer'),
#  ('papsttums', 'droemer', 'knaur'),
#  ('droemer', 'knaur', '1'),
#  ('knaur', '1', '9'),
#  ('1', '9', '8'),
#  ('9', '8', '9'),
#  ('8', '9', 'michael'),
#  ('9', 'michael', 'martin'),
#  ('michael', 'martin', 'atheism'),
#  ('martin', 'atheism', 'philosophical'),
#  ('atheism', 'philosophical', 'justification'),
#  ('philosophical', 'justification', 'temple'),
#  ('justification', 'temple', 'university'),
#  ('temple', 'university', 'press'),
#  ('university', 'press', 'philadelphia'),
#  ('press', 'philadelphia', 'usa'),
#  ('philadelphia', 'usa', 'detailed'),
#  ('usa', 'detailed', 'scholarly'),
#  ('detailed', 'scholarly', 'justification'),
#  ('scholarly', 'justification', 'atheism'),
#  ('justification', 'atheism', 'contains'),
#  ('atheism', 'contains', 'outstanding'),
#  ('contains', 'outstanding', 'appendix'),
#  ('outstanding', 'appendix', 'defining'),
#  ('appendix', 'defining', 'terminology'),
#  ('defining', 'terminology', 'usage'),
#  ('terminology', 'usage', 'necessarily'),
#  ('usage', 'necessarily', 'tendentious'),
#  ('necessarily', 'tendentious', 'area'),
#  ('tendentious', 'area', 'argues'),
#  ('area', 'argues', 'negative'),
#  ('argues', 'negative', 'atheism'),
#  ('negative', 'atheism', 'e'),
#  ('atheism', 'e', 'non'),
#  ('e', 'non', 'belief'),
#  ('non', 'belief', 'existence'),
#  ('belief', 'existence', 'god'),
#  ('existence', 'god', 'also'),
#  ('god', 'also', 'positive'),
#  ('also', 'positive', 'atheism'),
#  ('positive', 'atheism', 'belief'),
#  ('atheism', 'belief', 'non'),
#  ('belief', 'non', 'existence'),
#  ('non', 'existence', 'god'),
#  ('existence', 'god', 'includes'),
#  ('god', 'includes', 'great'),
#  ('includes', 'great', 'refutation'),
#  ('great', 'refutation', 'challenging'),
#  ('refutation', 'challenging', 'argument'),
#  ('challenging', 'argument', 'god'),
#  ('argument', 'god', 'particular'),
#  ('god', 'particular', 'attention'),
#  ('particular', 'attention', 'paid'),
#  ('attention', 'paid', 'refuting'),
#  ('paid', 'refuting', 'contempory'),
#  ('refuting', 'contempory', 'theist'),
#  ('contempory', 'theist', 'platinga'),
#  ('theist', 'platinga', 'swinburne'),
#  ('platinga', 'swinburne', '5'),
#  ('swinburne', '5', '4'),
#  ('5', '4', '1'),
#  ('4', '1', 'page'),
#  ('1', 'page', 'isbn'),
#  ('page', 'isbn', '0-87722'),
#  ('isbn', '0-87722', '642-3'),
#  ('0-87722', '642-3', 'hardcover'),
#  ('642-3', 'hardcover', 'paperback'),
#  ('hardcover', 'paperback', 'also'),
#  ('paperback', 'also', 'available'),
#  ('also', 'available', 'case'),
#  ('available', 'case', 'christianity'),
#  ('case', 'christianity', 'temple'),
#  ('christianity', 'temple', 'university'),
#  ('temple', 'university', 'press'),
#  ('university', 'press', 'comprehensive'),
#  ('press', 'comprehensive', 'critique'),
#  ('comprehensive', 'critique', 'christianity'),
#  ('critique', 'christianity', 'considers'),
#  ('christianity', 'considers', 'best'),
#  ('considers', 'best', 'contemporary'),
#  ('best', 'contemporary', 'defence'),
#  ('contemporary', 'defence', 'christianity'),
#  ('defence', 'christianity', 'ultimately'),
#  ('christianity', 'ultimately', 'demonstrates'),
#  ('ultimately', 'demonstrates', 'unsupportable'),
#  ('demonstrates', 'unsupportable', '/'),
#  ('unsupportable', '/', 'incoherent'),
#  ('/', 'incoherent', '2'),
#  ('incoherent', '2', '7'),
#  ('2', '7', '3'),
#  ('7', '3', 'page'),
#  ('3', 'page', 'isbn'),
#  ('page', 'isbn', '0-87722'),
#  ('isbn', '0-87722', '767-5'),
#  ('0-87722', '767-5', 'james'),
#  ('767-5', 'james', 'turner'),
#  ('james', 'turner', 'without'),
#  ('turner', 'without', 'god'),
#  ('without', 'god', 'without'),
#  ('god', 'without', 'creed'),
#  ('without', 'creed', 'johns'),
#  ('creed', 'johns', 'hopkins'),
#  ('johns', 'hopkins', 'university'),
#  ('hopkins', 'university', 'press'),
#  ('university', 'press', 'baltimore'),
#  ('press', 'baltimore', 'md'),
#  ('baltimore', 'md', 'usa'),
#  ('md', 'usa', 'subtitled'),
#  ('usa', 'subtitled', 'origins'),
#  ('subtitled', 'origins', 'unbelief'),
#  ('origins', 'unbelief', 'america'),
#  ('unbelief', 'america', 'examines'),
#  ('america', 'examines', 'way'),
#  ('examines', 'way', 'unbelief'),
#  ('way', 'unbelief', 'whether'),
#  ('unbelief', 'whether', 'agnostic'),
#  ('whether', 'agnostic', 'atheistic'),
#  ('agnostic', 'atheistic', 'became'),
#  ('atheistic', 'became', 'mainstream'),
#  ('became', 'mainstream', 'alternative'),
#  ('mainstream', 'alternative', 'world'),
#  ('alternative', 'world', 'view'),
#  ('world', 'view', 'focusses'),
#  ('view', 'focusses', 'period'),
#  ('focusses', 'period', '1770-1900'),
#  ('period', '1770-1900', 'considering'),
#  ('1770-1900', 'considering', 'france'),
#  ('considering', 'france', 'britain'),
#  ('france', 'britain', 'emphasis'),
#  ('britain', 'emphasis', 'american'),
#  ('emphasis', 'american', 'particularly'),
#  ('american', 'particularly', 'new'),
#  ('particularly', 'new', 'england'),
#  ('new', 'england', 'development'),
#  ('england', 'development', 'neither'),
#  ('development', 'neither', 'religious'),
#  ('neither', 'religious', 'history'),
#  ('religious', 'history', 'secularization'),
#  ('history', 'secularization', 'atheism'),
#  ('secularization', 'atheism', 'without'),
#  ('atheism', 'without', 'god'),
#  ('without', 'god', 'without'),
#  ('god', 'without', 'creed'),
#  ('without', 'creed', 'rather'),
#  ('creed', 'rather', 'intellectual'),
#  ('rather', 'intellectual', 'history'),
#  ('intellectual', 'history', 'fate'),
#  ('history', 'fate', 'single'),
#  ('fate', 'single', 'idea'),
#  ('single', 'idea', 'belief'),
#  ('idea', 'belief', 'god'),
#  ('belief', 'god', 'exists'),
#  ('god', 'exists', '3'),
#  ('exists', '3', '1'),
#  ('3', '1', '6'),
#  ('1', '6', 'page'),
#  ('6', 'page', 'isbn'),
#  ('page', 'isbn', 'hardcover'),
#  ('isbn', 'hardcover', '0-8018'),
#  ('hardcover', '0-8018', '2'),
#  ('0-8018', '2', '4'),
#  ('2', '4', '9'),
#  ('4', '9', '4'),
#  ('9', '4', 'x'),
#  ('4', 'x', 'paper'),
#  ('x', 'paper', '0-8018'),
#  ('paper', '0-8018', '3407-4'),
#  ('0-8018', '3407-4', 'george'),
#  ('3407-4', 'george', 'seldes'),
#  ('george', 'seldes', 'editor'),
#  ('seldes', 'editor', 'great'),
#  ('editor', 'great', 'thought'),
#  ('great', 'thought', 'ballantine'),
#  ('thought', 'ballantine', 'books'),
#  ('ballantine', 'books', 'new'),
#  ('books', 'new', 'york'),
#  ('new', 'york', 'usa'),
#  ('york', 'usa', 'dictionary'),
#  ('usa', 'dictionary', 'quotation'),
#  ('dictionary', 'quotation', 'different'),
#  ('quotation', 'different', 'kind'),
#  ('different', 'kind', 'concentrating'),
#  ('kind', 'concentrating', 'statement'),
#  ('concentrating', 'statement', 'writing'),
#  ('statement', 'writing', 'explicitly'),
#  ('writing', 'explicitly', 'implicitly'),
#  ('explicitly', 'implicitly', 'present'),
#  ('implicitly', 'present', "person's"),
#  ('present', "person's", 'philosophy'),
#  ("person's", 'philosophy', 'world'),
#  ('philosophy', 'world', 'view'),
#  ('world', 'view', 'includes'),
#  ('view', 'includes', 'obscure'),
#  ('includes', 'obscure', 'often'),
#  ...]

# %%
freqs_treegram= dict()
for threegram in threegrams:
    freqs_treegram[threegram] = freqs_treegram.get(threegram, 0) + 1

# %%
freqs_treegram
# Out:
# {('mathew', 'mathew@mantis.co.uk', 'subject'): 37,
#  ('mathew@mantis.co.uk', 'subject', 'alt'): 7,
#  ('subject', 'alt', 'atheism'): 9,
#  ('alt', 'atheism', 'faq'): 24,
#  ('atheism', 'faq', 'atheist'): 4,
#  ('faq', 'atheist', 'resources'): 4,
#  ('atheist', 'resources', 'summary'): 2,
#  ('resources', 'summary', 'books'): 2,
#  ('summary', 'books', 'address'): 2,
#  ('books', 'address', 'music'): 2,
#  ('address', 'music', 'anything'): 2,
#  ('music', 'anything', 'related'): 2,
#  ('anything', 'related', 'atheism'): 2,
#  ('related', 'atheism', 'keywords'): 2,
#  ('atheism', 'keywords', 'faq'): 4,
#  ('keywords', 'faq', 'atheism'): 8,
#  ('faq', 'atheism', 'book'): 2,
#  ('atheism', 'book', 'music'): 2,
#  ('book', 'music', 'fiction'): 2,
#  ('music', 'fiction', 'address'): 2,
#  ('fiction', 'address', 'contact'): 2,
#  ('address', 'contact', 'expires'): 2,
#  ('contact', 'expires', 'thu'): 2,
#  ('expires', 'thu', '29 apr 1993'): 1,
#  ('thu', '29 apr 1993', '11:57:19'): 1,
#  ('29 apr 1993', '11:57:19', 'gmt'): 1,
#  ('11:57:19', 'gmt', 'distribution'): 1,
#  ('gmt', 'distribution', 'world'): 11,
#  ('distribution', 'world', 'organization'): 393,
#  ('world', 'organization', 'mantis'): 11,
#  ('organization', 'mantis', 'consultants'): 45,
#  ('mantis', 'consultants', 'cambridge'): 45,
#  ('consultants', 'cambridge', 'uk'): 45,
#  ('cambridge', 'uk', 'supersedes'): 7,
#  ('uk', 'supersedes', '19930301143317@mantis.co.uk'): 1,
#  ('supersedes', '19930301143317@mantis.co.uk', 'lines'): 1,
#  ('19930301143317@mantis.co.uk', 'lines', '2'): 1,
#  ('lines', '2', '9'): 373,
#  ('2', '9', '0'): 68,
#  ('9', '0', 'archive'): 2,
#  ('0', 'archive', 'name'): 8,
#  ('archive', 'name', 'atheism'): 7,
#  ('name', 'atheism', '/'): 7,
#  ('atheism', '/', 'resource'): 4,
#  ('/', 'resource', 'alt'): 2,
#  ('resource', 'alt', 'atheism'): 2,
#  ('alt', 'atheism', 'archive'): 7,
#  ('atheism', 'archive', 'name'): 7,
#  ('archive', 'name', 'resource'): 2,
#  ('name', 'resource', 'last'): 2,
#  ('resource', 'last', 'modified'): 2,
#  ('last', 'modified', '11 december 1992'): 1,
#  ('modified', '11 december 1992', 'version'): 1,
#  ('11 december 1992', 'version', '1'): 1,
#  ('version', '1', '0'): 64,
#  ('1', '0', 'atheist'): 1,
#  ('0', 'atheist', 'resources'): 1,
#  ('atheist', 'resources', 'addresses'): 2,
#  ('resources', 'addresses', 'atheist'): 2,
#  ('addresses', 'atheist', 'organizations'): 2,
#  ('atheist', 'organizations', 'usa'): 2,
#  ('organizations', 'usa', 'freedom'): 2,
#  ('usa', 'freedom', 'religion'): 2,
#  ('freedom', 'religion', 'foundation'): 5,
#  ('religion', 'foundation', 'darwin'): 2,
#  ('foundation', 'darwin', 'fish'): 2,
#  ('darwin', 'fish', 'bumper'): 2,
#  ('fish', 'bumper', 'sticker'): 2,
#  ('bumper', 'sticker', 'assorted'): 2,
#  ('sticker', 'assorted', 'atheist'): 2,
#  ('assorted', 'atheist', 'paraphernalia'): 2,
#  ('atheist', 'paraphernalia', 'available'): 2,
#  ('paraphernalia', 'available', 'freedom'): 2,
#  ('available', 'freedom', 'religion'): 2,
#  ('religion', 'foundation', 'us'): 2,
#  ('foundation', 'us', 'write'): 2,
#  ('us', 'write', 'ffrf'): 2,
#  ('write', 'ffrf', 'p'): 2,
#  ('ffrf', 'p', 'box'): 2,
#  ('p', 'box', '7'): 15,
#  ('box', '7', '5'): 2,
#  ('7', '5', '0'): 302,
#  ('5', '0', 'madison'): 2,
#  ('0', 'madison', 'wi'): 2,
#  ('madison', 'wi', '53701'): 4,
#  ('wi', '53701', 'telephone'): 2,
#  ('53701', 'telephone', 'evolution'): 2,
#  ('telephone', 'evolution', 'designs'): 2,
#  ('evolution', 'designs', 'evolution'): 2,
#  ('designs', 'evolution', 'designs'): 2,
#  ('evolution', 'designs', 'sell'): 2,
#  ('designs', 'sell', 'darwin'): 2,
#  ('sell', 'darwin', 'fish'): 2,
#  ('darwin', 'fish', 'fish'): 2,
#  ('fish', 'fish', 'symbol'): 2,
#  ('fish', 'symbol', 'like'): 2,
#  ('symbol', 'like', 'one'): 2,
#  ('like', 'one', 'christians'): 2,
#  ('one', 'christians', 'stick'): 2,
#  ('christians', 'stick', 'car'): 2,
#  ('stick', 'car', 'foot'): 2,
#  ('car', 'foot', 'word'): 2,
#  ('foot', 'word', 'darwin'): 2,
#  ('word', 'darwin', 'written'): 2,
#  ('darwin', 'written', 'inside'): 2,
#  ('written', 'inside', 'deluxe'): 2,
#  ('inside', 'deluxe', 'moulded'): 2,
#  ('deluxe', 'moulded', '3'): 2,
#  ('moulded', '3', 'plastic'): 2,
#  ('3', 'plastic', 'fish'): 2,
#  ('plastic', 'fish', '$4.95'): 2,
#  ('fish', '$4.95', 'postpaid'): 2,
#  ('$4.95', 'postpaid', 'us'): 2,
#  ('postpaid', 'us', 'write'): 2,
#  ('us', 'write', 'evolution'): 2,
#  ('write', 'evolution', 'designs'): 2,
#  ('evolution', 'designs', '7'): 2,
#  ('designs', '7', '1'): 2,
#  ('7', '1', '1'): 182,
#  ('1', '1', '9'): 250,
#  ('1', '9', 'laurel'): 2,
#  ('9', 'laurel', 'canyon'): 2,
#  ('laurel', 'canyon', '#'): 2,
#  ('canyon', '#', '4'): 2,
#  ('#', '4', 'north'): 2,
#  ('4', 'north', 'hollywood'): 2,
#  ('north', 'hollywood', 'ca'): 2,
#  ('hollywood', 'ca', '91605'): 2,
#  ('ca', '91605', 'people'): 2,
#  ('91605', 'people', 'san'): 2,
#  ('people', 'san', 'francisco'): 3,
#  ('san', 'francisco', 'bay'): 18,
#  ('francisco', 'bay', 'area'): 19,
#  ('bay', 'area', 'get'): 3,
#  ('area', 'get', 'darwin'): 2,
#  ('get', 'darwin', 'fish'): 2,
#  ('darwin', 'fish', 'lynn'): 2,
#  ('fish', 'lynn', 'gold'): 2,
#  ('lynn', 'gold', 'try'): 2,
#  ('gold', 'try', 'mailing'): 2,
#  ('try', 'mailing', 'figmo@netcom.com'): 2,
#  ('mailing', 'figmo@netcom.com', 'net'): 2,
#  ('figmo@netcom.com', 'net', 'people'): 2,
#  ('net', 'people', 'go'): 2,
#  ('people', 'go', 'lynn'): 2,
#  ('go', 'lynn', 'directly'): 2,
#  ('lynn', 'directly', 'price'): 2,
#  ('directly', 'price', '$4.95'): 2,
#  ('price', '$4.95', 'per'): 2,
#  ('$4.95', 'per', 'fish'): 2,
#  ('per', 'fish', 'american'): 1,
#  ('fish', 'american', 'atheist'): 1,
#  ('american', 'atheist', 'press'): 8,
#  ('atheist', 'press', 'aap'): 2,
#  ('press', 'aap', 'publish'): 2,
#  ('aap', 'publish', 'various'): 2,
#  ('publish', 'various', 'atheist'): 2,
#  ('various', 'atheist', 'book'): 2,
#  ('atheist', 'book', 'critique'): 2,
#  ('book', 'critique', 'bible'): 2,
#  ('critique', 'bible', 'list'): 2,
#  ('bible', 'list', 'biblical'): 2,
#  ('list', 'biblical', 'contradiction'): 12,
#  ('biblical', 'contradiction', 'one'): 2,
#  ('contradiction', 'one', 'book'): 2,
#  ('one', 'book', 'bible'): 2,
#  ('book', 'bible', 'handbook'): 2,
#  ('bible', 'handbook', 'w'): 2,
#  ('handbook', 'w', 'p'): 2,
#  ('w', 'p', 'ball'): 2,
#  ('p', 'ball', 'g'): 2,
#  ('ball', 'g', 'w'): 2,
#  ('g', 'w', 'foote'): 2,
#  ('w', 'foote', 'american'): 2,
#  ('foote', 'american', 'atheist'): 2,
#  ('atheist', 'press', '3'): 2,
#  ('press', '3', '7'): 2,
#  ('3', '7', '2'): 86,
#  ('7', '2', 'pp'): 2,
#  ('2', 'pp', 'isbn'): 2,
#  ('pp', 'isbn', '0-910309'): 2,
#  ('isbn', '0-910309', '2'): 2,
#  ('0-910309', '2', '6'): 2,
#  ('2', '6', '4'): 63,
#  ('6', '4', '2'): 74,
#  ('4', '2', 'nd'): 6,
#  ('2', 'nd', 'edition'): 15,
#  ('nd', 'edition', '1'): 2,
#  ('edition', '1', '9'): 7,
#  ('1', '9', '8'): 1567,
#  ('9', '8', '6'): 174,
#  ('8', '6', 'bible'): 2,
#  ('6', 'bible', 'contradiction'): 2,
#  ('bible', 'contradiction', 'absurdity'): 2,
#  ('contradiction', 'absurdity', 'atrocity'): 2,
#  ('absurdity', 'atrocity', 'immorality'): 2,
#  ('atrocity', 'immorality', 'contains'): 2,
#  ('immorality', 'contains', 'ball'): 2,
#  ('contains', 'ball', 'foote'): 2,
#  ('ball', 'foote', 'bible'): 2,
#  ('foote', 'bible', 'contradicts'): 2,
#  ('bible', 'contradicts', 'aap'): 2,
#  ('contradicts', 'aap', 'based'): 2,
#  ('aap', 'based', 'king'): 2,
#  ('based', 'king', 'james'): 2,
#  ('king', 'james', 'version'): 5,
#  ('james', 'version', 'bible'): 3,
#  ('version', 'bible', 'write'): 2,
#  ('bible', 'write', 'american'): 2,
#  ('write', 'american', 'atheist'): 2,
#  ('atheist', 'press', 'p'): 2,
#  ('press', 'p', 'box'): 3,
#  ('p', 'box', '140195'): 2,
#  ('box', '140195', 'austin'): 2,
#  ('140195', 'austin', 'tx'): 2,
#  ('austin', 'tx', '78714-0195'): 2,
#  ('tx', '78714-0195', '7'): 2,
#  ('78714-0195', '7', '2'): 2,
#  ('7', '2', '1'): 107,
#  ('2', '1', '5'): 160,
#  ('1', '5', 'cameron'): 2,
#  ('5', 'cameron', 'road'): 2,
#  ('cameron', 'road', 'austin'): 2,
#  ('road', 'austin', 'tx'): 2,
#  ('austin', 'tx', '78752-2973'): 2,
#  ('tx', '78752-2973', 'telephone'): 2,
#  ('78752-2973', 'telephone', 'fax'): 2,
#  ('telephone', 'fax', 'prometheus'): 2,
#  ('fax', 'prometheus', 'books'): 2,
#  ('prometheus', 'books', 'sell'): 2,
#  ('books', 'sell', 'book'): 2,
#  ('sell', 'book', 'including'): 2,
#  ('book', 'including', "haught's"): 2,
#  ('including', "haught's", 'holy'): 2,
#  ("haught's", 'holy', 'horrors'): 2,
#  ('holy', 'horrors', 'see'): 2,
#  ('horrors', 'see', 'write'): 2,
#  ('see', 'write', '7'): 2,
#  ('write', '7', '0'): 2,
#  ('7', '0', '0'): 297,
#  ('0', '0', 'east'): 5,
#  ('0', 'east', 'amherst'): 2,
#  ('east', 'amherst', 'street'): 2,
#  ('amherst', 'street', 'buffalo'): 2,
#  ('street', 'buffalo', 'new'): 2,
#  ('buffalo', 'new', 'york'): 3,
#  ('new', 'york', '14215'): 2,
#  ('york', '14215', 'telephone'): 2,
#  ('14215', 'telephone', 'alternate'): 2,
#  ('telephone', 'alternate', 'address'): 2,
#  ('alternate', 'address', 'may'): 2,
#  ('address', 'may', 'newer'): 2,
#  ('may', 'newer', 'older'): 2,
#  ('newer', 'older', 'prometheus'): 2,
#  ('older', 'prometheus', 'books'): 2,
#  ('prometheus', 'books', '5'): 2,
#  ('books', '5', '9'): 2,
#  ('5', '9', 'glenn'): 2,
#  ('9', 'glenn', 'drive'): 2,
#  ('glenn', 'drive', 'buffalo'): 2,
#  ('drive', 'buffalo', 'ny'): 2,
#  ('buffalo', 'ny', '14228-2197'): 2,
#  ('ny', '14228-2197', 'african'): 2,
#  ('14228-2197', 'african', 'americans'): 2,
#  ('african', 'americans', 'humanism'): 6,
#  ('americans', 'humanism', 'organization'): 2,
#  ('humanism', 'organization', 'promoting'): 2,
#  ('organization', 'promoting', 'black'): 2,
#  ('promoting', 'black', 'secular'): 2,
#  ('black', 'secular', 'humanism'): 2,
#  ('secular', 'humanism', 'uncovering'): 2,
#  ('humanism', 'uncovering', 'history'): 2,
#  ('uncovering', 'history', 'black'): 2,
#  ('history', 'black', 'freethought'): 2,
#  ('black', 'freethought', 'publish'): 2,
#  ('freethought', 'publish', 'quarterly'): 2,
#  ('publish', 'quarterly', 'newsletter'): 2,
#  ('quarterly', 'newsletter', 'aah'): 2,
#  ('newsletter', 'aah', 'examiner'): 2,
#  ('aah', 'examiner', 'write'): 2,
#  ('examiner', 'write', 'norm'): 2,
#  ('write', 'norm', 'r'): 2,
#  ('norm', 'r', 'allen'): 4,
#  ('r', 'allen', 'jr'): 4,
#  ('allen', 'jr', 'african'): 4,
#  ('jr', 'african', 'americans'): 2,
#  ('americans', 'humanism', 'p'): 2,
#  ('humanism', 'p', 'box'): 2,
#  ('p', 'box', '6'): 15,
#  ('box', '6', '6'): 5,
#  ('6', '6', '4'): 64,
#  ('6', '4', 'buffalo'): 2,
#  ('4', 'buffalo', 'ny'): 2,
#  ('buffalo', 'ny', '14226'): 2,
#  ('ny', '14226', 'united'): 2,
#  ('14226', 'united', 'kingdom'): 2,
#  ('united', 'kingdom', 'rationalist'): 2,
#  ('kingdom', 'rationalist', 'press'): 2,
#  ('rationalist', 'press', 'association'): 2,
#  ('press', 'association', 'national'): 2,
#  ('association', 'national', 'secular'): 2,
#  ('national', 'secular', 'society'): 4,
#  ('secular', 'society', '8'): 2,
#  ('society', '8', '8'): 2,
#  ('8', '8', 'islington'): 2,
#  ('8', 'islington', 'high'): 2,
#  ('islington', 'high', 'street'): 2,
#  ('high', 'street', '7'): 2,
#  ('street', '7', '0'): 2,
#  ('7', '0', '2'): 83,
#  ('0', '2', 'holloway'): 2,
#  ('2', 'holloway', 'road'): 2,
#  ('holloway', 'road', 'london'): 2,
#  ('road', 'london', 'n'): 2,
#  ('london', 'n', '1'): 5,
#  ('n', '1', '8'): 4,
#  ('1', '8', 'ew'): 2,
#  ('8', 'ew', 'london'): 2,
#  ('ew', 'london', 'n'): 2,
#  ('n', '1', '9'): 3,
#  ('1', '9', '3'): 266,
#  ('9', '3', 'nl'): 3,
#  ('3', 'nl', 'nl'): 2,
#  ('nl', 'nl', 'nl'): 2,
#  ('nl', 'nl', '071 226'): 2,
#  ('nl', '071 226', '7'): 2,
#  ('071 226', '7', '2'): 2,
#  ('7', '2', '5'): 109,
#  ('2', '5', '1'): 301,
#  ('5', '1', '0'): 220,
#  ('1', '0', '7'): 197,
#  ('0', '7', '1'): 85,
#  ('7', '1', '2'): 101,
#  ('1', '2', '7'): 241,
#  ('2', '7', '2'): 97,
#  ('2', '1', '2'): 268,
#  ('1', '2', '6'): 147,
#  ('2', '6', '6'): 117,
#  ('6', '6', 'british'): 2,
#  ('6', 'british', 'humanist'): 2,
#  ('british', 'humanist', 'association'): 2,
#  ('humanist', 'association', 'south'): 2,
#  ('association', 'south', 'place'): 2,
#  ('south', 'place', 'ethical'): 2,
#  ('place', 'ethical', 'society'): 2,
#  ('ethical', 'society', '1'): 2,
#  ('society', '1', '4'): 2,
#  ('1', '4', "lamb's"): 2,
#  ('4', "lamb's", 'conduit'): 2,
#  ("lamb's", 'conduit', 'passage'): 2,
#  ('conduit', 'passage', 'conway'): 2,
#  ('passage', 'conway', 'hall'): 2,
#  ('conway', 'hall', 'london'): 2,
#  ('hall', 'london', 'wc'): 2,
#  ('london', 'wc', '1'): 4,
#  ('wc', '1', 'r'): 4,
#  ('1', 'r', '4'): 193,
#  ('r', '4', 'rh'): 2,
#  ('4', 'rh', 'red'): 2,
#  ('rh', 'red', 'lion'): 2,
#  ('red', 'lion', 'square'): 2,
#  ('lion', 'square', 'square'): 2,
#  ('square', 'square', 'square'): 2,
#  ('square', 'square', '071 430'): 2,
#  ('square', '071 430', '0'): 2,
#  ('071 430', '0', '9'): 2,
#  ('0', '9', '0'): 83,
#  ('9', '0', '8'): 36,
#  ('0', '8', 'london'): 4,
#  ('8', 'london', 'wc'): 2,
#  ('r', '4', 'rl'): 2,
#  ('4', 'rl', 'fax 071 430'): 2,
#  ('rl', 'fax 071 430', '1'): 2,
#  ('fax 071 430', '1', '2'): 2,
#  ('2', '7', '1'): 101,
#  ('7', '1', '0'): 116,
#  ('7', '1', '8'): 62,
#  ('1', '8', '3'): 140,
#  ('8', '3', '1'): 66,
#  ('3', '1', '7'): 93,
#  ('1', '7', '7'): 157,
#  ('7', '7', '2'): 77,
#  ('7', '2', '3'): 71,
#  ('2', '3', 'national'): 2,
#  ('3', 'national', 'secular'): 2,
#  ('secular', 'society', 'publish'): 2,
#  ('society', 'publish', 'freethinker'): 2,
#  ('publish', 'freethinker', 'monthly'): 2,
#  ('freethinker', 'monthly', 'magazine'): 2,
#  ('monthly', 'magazine', 'founded'): 2,
#  ('magazine', 'founded', '1'): 2,
#  ('founded', '1', '8'): 2,
#  ('1', '8', '8'): 110,
#  ('8', '8', '1'): 80,
#  ('8', '1', 'germany'): 2,
#  ('1', 'germany', 'ibka'): 2,
#  ('germany', 'ibka', 'e'): 2,
#  ('ibka', 'e', 'v'): 4,
#  ('e', 'v', 'internationaler'): 2,
#  ('v', 'internationaler', 'bund'): 2,
#  ('internationaler', 'bund', 'der'): 2,
#  ('bund', 'der', 'konfessionslosen'): 2,
#  ('der', 'konfessionslosen', 'und'): 2,
#  ('konfessionslosen', 'und', 'atheisten'): 2,
#  ('und', 'atheisten', 'postfach'): 2,
#  ('atheisten', 'postfach', '8'): 2,
#  ('postfach', '8', '8'): 4,
#  ('8', '8', '0'): 51,
#  ('8', '0', '1'): 119,
#  ('0', '1', '0'): 488,
#  ('1', '0', '00 berlin 41'): 4,
#  ('0', '00 berlin 41', 'germany'): 4,
#  ('00 berlin 41', 'germany', 'ibka'): 2,
#  ('germany', 'ibka', 'publish'): 2,
#  ('ibka', 'publish', 'journal'): 2,
#  ('publish', 'journal', 'miz'): 2,
#  ('journal', 'miz', 'materialien'): 2,
#  ('miz', 'materialien', 'und'): 2,
#  ('materialien', 'und', 'informationen'): 2,
#  ('und', 'informationen', 'zur'): 2,
#  ('informationen', 'zur', 'zeit'): 2,
#  ('zur', 'zeit', 'politisches'): 2,
#  ('zeit', 'politisches', 'journal'): 2,
#  ('politisches', 'journal', 'der'): 2,
#  ('journal', 'der', 'konfessionslosesn'): 2,
#  ('der', 'konfessionslosesn', 'und'): 2,
#  ('konfessionslosesn', 'und', 'atheisten'): 2,
#  ('und', 'atheisten', 'hrsg'): 2,
#  ('atheisten', 'hrsg', 'ibka'): 2,
#  ('hrsg', 'ibka', 'e'): 2,
#  ('e', 'v', 'miz'): 2,
#  ('v', 'miz', 'vertrieb'): 2,
#  ('miz', 'vertrieb', 'postfach'): 2,
#  ('vertrieb', 'postfach', '8'): 2,
#  ('00 berlin 41', 'germany', 'atheist'): 2,
#  ('germany', 'atheist', 'book'): 2,
#  ('atheist', 'book', 'write'): 2,
#  ('book', 'write', 'ibdk'): 2,
#  ('write', 'ibdk', 'internationaler'): 2,
#  ('ibdk', 'internationaler', 'b'): 2,
#  ('internationaler', 'b', 'ucherdienst'): 2,
#  ('b', 'ucherdienst', 'der'): 2,
#  ('ucherdienst', 'der', 'konfessionslosen'): 2,
#  ('der', 'konfessionslosen', 'postfach'): 2,
#  ('konfessionslosen', 'postfach', '3'): 2,
#  ('postfach', '3', '0'): 2,
#  ('3', '0', '0'): 1056,
#  ('0', '0', '5'): 128,
#  ('0', '5', '3'): 57,
#  ('5', '3', '0'): 118,
#  ('3', '0', '00 hannover 1'): 2,
#  ('0', '00 hannover 1', 'germany'): 2,
#  ('00 hannover 1', 'germany', 'telephone'): 2,
#  ('germany', 'telephone', '0511/2112'): 2,
#  ('telephone', '0511/2112', '1'): 2,
#  ('0511/2112', '1', '6'): 2,
#  ('1', '6', 'books'): 2,
#  ('6', 'books', 'fiction'): 2,
#  ('books', 'fiction', 'thomas'): 2,
#  ('fiction', 'thomas', 'disch'): 2,
#  ('thomas', 'disch', 'santa'): 2,
#  ('disch', 'santa', 'claus'): 2,
#  ('santa', 'claus', 'compromise'): 2,
#  ('claus', 'compromise', 'short'): 2,
#  ('compromise', 'short', 'story'): 2,
#  ('short', 'story', 'ultimate'): 2,
#  ('story', 'ultimate', 'proof'): 2,
#  ('ultimate', 'proof', 'santa'): 2,
#  ('proof', 'santa', 'exists'): 2,
#  ('santa', 'exists', 'character'): 2,
#  ('exists', 'character', 'event'): 2,
#  ('character', 'event', 'fictitious'): 2,
#  ('event', 'fictitious', 'similarity'): 2,
#  ('fictitious', 'similarity', 'living'): 2,
#  ('similarity', 'living', 'dead'): 2,
#  ('living', 'dead', 'god'): 2,
#  ('dead', 'god', 'uh'): 2,
#  ('god', 'uh', 'well'): 2,
#  ('uh', 'well', 'walter'): 2,
#  ('well', 'walter', 'miller'): 2,
#  ('walter', 'miller', 'jr'): 2,
#  ('miller', 'jr', 'canticle'): 2,
#  ('jr', 'canticle', 'leibowitz'): 2,
#  ('canticle', 'leibowitz', 'one'): 2,
#  ('leibowitz', 'one', 'gem'): 2,
#  ('one', 'gem', 'post'): 2,
#  ('gem', 'post', 'atomic'): 2,
#  ('post', 'atomic', 'doomsday'): 4,
#  ('atomic', 'doomsday', 'novel'): 4,
#  ('doomsday', 'novel', 'monk'): 2,
#  ('novel', 'monk', 'spent'): 2,
#  ('monk', 'spent', 'life'): 2,
#  ('spent', 'life', 'copying'): 2,
#  ('life', 'copying', 'blueprint'): 2,
#  ('copying', 'blueprint', 'saint'): 2,
#  ('blueprint', 'saint', 'leibowitz'): 2,
#  ('saint', 'leibowitz', 'filling'): 2,
#  ('leibowitz', 'filling', 'sheet'): 2,
#  ('filling', 'sheet', 'paper'): 2,
#  ('sheet', 'paper', 'ink'): 2,
#  ('paper', 'ink', 'leaving'): 2,
#  ('ink', 'leaving', 'white'): 2,
#  ('leaving', 'white', 'line'): 2,
#  ('white', 'line', 'letter'): 2,
#  ('line', 'letter', 'edgar'): 2,
#  ('letter', 'edgar', 'pangborn'): 2,
#  ('edgar', 'pangborn', 'davy'): 2,
#  ('pangborn', 'davy', 'post'): 2,
#  ('davy', 'post', 'atomic'): 2,
#  ('doomsday', 'novel', 'set'): 2,
#  ('novel', 'set', 'clerical'): 2,
#  ('set', 'clerical', 'state'): 2,
#  ('clerical', 'state', 'church'): 2,
#  ('state', 'church', 'example'): 2,
#  ('church', 'example', 'forbids'): 2,
#  ('example', 'forbids', 'anyone'): 2,
#  ('forbids', 'anyone', 'produce'): 2,
#  ('anyone', 'produce', 'describe'): 2,
#  ('produce', 'describe', 'use'): 2,
#  ('describe', 'use', 'substance'): 2,
#  ('use', 'substance', 'containing'): 2,
#  ('substance', 'containing', 'atom'): 2,
#  ('containing', 'atom', 'philip'): 2,
#  ('atom', 'philip', 'k'): 2,
#  ('philip', 'k', 'dick'): 4,
#  ('k', 'dick', 'philip'): 2,
#  ('dick', 'philip', 'k'): 2,
#  ('k', 'dick', 'dick'): 2,
#  ('dick', 'dick', 'wrote'): 2,
#  ('dick', 'wrote', 'many'): 2,
#  ('wrote', 'many', 'philosophical'): 2,
#  ('many', 'philosophical', 'thought'): 2,
#  ('philosophical', 'thought', 'provoking'): 2,
#  ('thought', 'provoking', 'short'): 2,
#  ('provoking', 'short', 'story'): 2,
#  ('short', 'story', 'novel'): 2,
#  ('story', 'novel', 'story'): 2,
#  ('novel', 'story', 'bizarre'): 2,
#  ('story', 'bizarre', 'time'): 2,
#  ('bizarre', 'time', 'approachable'): 2,
#  ('time', 'approachable', 'wrote'): 2,
#  ('approachable', 'wrote', 'mainly'): 2,
#  ('wrote', 'mainly', 'sf'): 2,
#  ('mainly', 'sf', 'wrote'): 2,
#  ('sf', 'wrote', 'people'): 2,
#  ('wrote', 'people', 'truth'): 2,
#  ('people', 'truth', 'religion'): 2,
#  ('truth', 'religion', 'rather'): 2,
#  ('religion', 'rather', 'technology'): 2,
#  ('rather', 'technology', 'although'): 2,
#  ('technology', 'although', 'often'): 2,
#  ('although', 'often', 'believed'): 2,
#  ('often', 'believed', 'met'): 2,
#  ('believed', 'met', 'sort'): 2,
#  ('met', 'sort', 'god'): 2,
#  ('sort', 'god', 'remained'): 2,
#  ('god', 'remained', 'sceptical'): 2,
#  ('remained', 'sceptical', 'amongst'): 2,
#  ('sceptical', 'amongst', 'novel'): 2,
#  ('amongst', 'novel', 'following'): 2,
#  ('novel', 'following', 'relevance'): 2,
#  ('following', 'relevance', 'galactic'): 2,
#  ('relevance', 'galactic', 'pot'): 2,
#  ('galactic', 'pot', 'healer'): 2,
#  ('pot', 'healer', 'fallible'): 2,
#  ('healer', 'fallible', 'alien'): 2,
#  ('fallible', 'alien', 'deity'): 2,
#  ('alien', 'deity', 'summons'): 2,
#  ('deity', 'summons', 'group'): 2,
#  ('summons', 'group', 'earth'): 2,
#  ('group', 'earth', 'craftsman'): 2,
#  ('earth', 'craftsman', 'woman'): 2,
#  ('craftsman', 'woman', 'remote'): 2,
#  ('woman', 'remote', 'planet'): 2,
#  ('remote', 'planet', 'raise'): 2,
#  ('planet', 'raise', 'giant'): 2,
#  ('raise', 'giant', 'cathedral'): 2,
#  ('giant', 'cathedral', 'beneath'): 2,
#  ('cathedral', 'beneath', 'ocean'): 2,
#  ('beneath', 'ocean', 'deity'): 2,
#  ('ocean', 'deity', 'begin'): 2,
#  ('deity', 'begin', 'demand'): 2,
#  ('begin', 'demand', 'faith'): 2,
#  ('demand', 'faith', 'earthers'): 2,
#  ('faith', 'earthers', 'pot'): 2,
#  ('earthers', 'pot', 'healer'): 2,
#  ('pot', 'healer', 'joe'): 2,
#  ('healer', 'joe', 'fernwright'): 2,
#  ('joe', 'fernwright', 'unable'): 2,
#  ('fernwright', 'unable', 'comply'): 2,
#  ('unable', 'comply', 'polished'): 2,
#  ('comply', 'polished', 'ironic'): 2,
#  ('polished', 'ironic', 'amusing'): 2,
#  ('ironic', 'amusing', 'novel'): 2,
#  ('amusing', 'novel', 'maze'): 2,
#  ('novel', 'maze', 'death'): 2,
#  ('maze', 'death', 'noteworthy'): 2,
#  ('death', 'noteworthy', 'description'): 2,
#  ('noteworthy', 'description', 'technology'): 2,
#  ('description', 'technology', 'based'): 2,
#  ('technology', 'based', 'religion'): 2,
#  ('based', 'religion', 'valis'): 2,
#  ('religion', 'valis', 'schizophrenic'): 2,
#  ('valis', 'schizophrenic', 'hero'): 2,
#  ('schizophrenic', 'hero', 'search'): 2,
#  ('hero', 'search', 'hidden'): 2,
#  ('search', 'hidden', 'mystery'): 2,
#  ('hidden', 'mystery', 'gnostic'): 2,
#  ('mystery', 'gnostic', 'christianity'): 2,
#  ('gnostic', 'christianity', 'reality'): 2,
#  ('christianity', 'reality', 'fired'): 2,
#  ('reality', 'fired', 'brain'): 2,
#  ('fired', 'brain', 'pink'): 2,
#  ('brain', 'pink', 'laser'): 2,
#  ('pink', 'laser', 'beam'): 2,
#  ('laser', 'beam', 'unknown'): 2,
#  ('beam', 'unknown', 'possibly'): 2,
#  ('unknown', 'possibly', 'divine'): 2,
#  ('possibly', 'divine', 'origin'): 2,
#  ('divine', 'origin', 'accompanied'): 2,
#  ('origin', 'accompanied', 'dogmatic'): 2,
#  ('accompanied', 'dogmatic', 'dismissively'): 2,
#  ('dogmatic', 'dismissively', 'atheist'): 2,
#  ('dismissively', 'atheist', 'friend'): 2,
#  ('atheist', 'friend', 'assorted'): 2,
#  ('friend', 'assorted', 'odd'): 2,
#  ('assorted', 'odd', 'character'): 2,
#  ('odd', 'character', 'divine'): 2,
#  ('character', 'divine', 'invasion'): 2,
#  ('divine', 'invasion', 'god'): 2,
#  ('invasion', 'god', 'invades'): 2,
#  ('god', 'invades', 'earth'): 2,
#  ('invades', 'earth', 'making'): 2,
#  ('earth', 'making', 'young'): 2,
#  ('making', 'young', 'woman'): 2,
#  ('young', 'woman', 'pregnant'): 2,
#  ('woman', 'pregnant', 'return'): 2,
#  ('pregnant', 'return', 'another'): 2,
#  ('return', 'another', 'star'): 2,
#  ('another', 'star', 'system'): 2,
#  ('star', 'system', 'unfortunately'): 2,
#  ('system', 'unfortunately', 'terminally'): 2,
#  ('unfortunately', 'terminally', 'ill'): 2,
#  ('terminally', 'ill', 'must'): 2,
#  ('ill', 'must', 'assisted'): 2,
#  ('must', 'assisted', 'dead'): 2,
#  ('assisted', 'dead', 'man'): 2,
#  ('dead', 'man', 'whose'): 2,
#  ('man', 'whose', 'brain'): 2,
#  ('whose', 'brain', 'wired'): 2,
#  ('brain', 'wired', '2'): 2,
#  ('wired', '2', '4'): 2,
#  ('2', '4', 'hour'): 143,
#  ('4', 'hour', 'easy'): 2,
#  ('hour', 'easy', 'listening'): 2,
#  ('easy', 'listening', 'music'): 2,
#  ('listening', 'music', 'margaret'): 2,
#  ('music', 'margaret', 'atwood'): 2,
#  ('margaret', 'atwood', "handmaid's"): 2,
#  ('atwood', "handmaid's", 'tale'): 2,
#  ("handmaid's", 'tale', 'story'): 2,
#  ('tale', 'story', 'based'): 2,
#  ('story', 'based', 'premise'): 2,
#  ('based', 'premise', 'us'): 2,
#  ('premise', 'us', 'congress'): 2,
#  ('us', 'congress', 'mysteriously'): 2,
#  ('congress', 'mysteriously', 'assassinated'): 2,
#  ('mysteriously', 'assassinated', 'fundamentalist'): 2,
#  ('assassinated', 'fundamentalist', 'quickly'): 2,
#  ('fundamentalist', 'quickly', 'take'): 2,
#  ('quickly', 'take', 'charge'): 2,
#  ('take', 'charge', 'nation'): 2,
#  ('charge', 'nation', 'set'): 2,
#  ('nation', 'set', 'right'): 2,
#  ('set', 'right', 'book'): 2,
#  ('right', 'book', 'diary'): 2,
#  ('book', 'diary', "woman's"): 2,
#  ('diary', "woman's", 'life'): 2,
#  ("woman's", 'life', 'try'): 2,
#  ('life', 'try', 'live'): 2,
#  ('try', 'live', 'new'): 2,
#  ('live', 'new', 'christian'): 2,
#  ('new', 'christian', 'theocracy'): 2,
#  ('christian', 'theocracy', "women's"): 2,
#  ('theocracy', "women's", 'right'): 2,
#  ("women's", 'right', 'property'): 2,
#  ('right', 'property', 'revoked'): 2,
#  ('property', 'revoked', 'bank'): 2,
#  ('revoked', 'bank', 'account'): 2,
#  ('bank', 'account', 'closed'): 2,
#  ('account', 'closed', 'sinful'): 2,
#  ('closed', 'sinful', 'luxury'): 2,
#  ('sinful', 'luxury', 'outlawed'): 2,
#  ('luxury', 'outlawed', 'radio'): 2,
#  ('outlawed', 'radio', 'used'): 2,
#  ('radio', 'used', 'reading'): 2,
#  ('used', 'reading', 'bible'): 2,
#  ('reading', 'bible', 'crimes'): 2,
#  ('bible', 'crimes', 'punished'): 2,
#  ('crimes', 'punished', 'retroactively'): 2,
#  ('punished', 'retroactively', 'doctor'): 2,
#  ('retroactively', 'doctor', 'performed'): 2,
#  ('doctor', 'performed', 'legal'): 2,
#  ('performed', 'legal', 'abortion'): 2,
#  ('legal', 'abortion', 'old'): 2,
#  ('abortion', 'old', 'world'): 2,
#  ('old', 'world', 'hunted'): 2,
#  ('world', 'hunted', 'hanged'): 2,
#  ('hunted', 'hanged', "atwood's"): 2,
#  ('hanged', "atwood's", 'writing'): 2,
#  ("atwood's", 'writing', 'style'): 2,
#  ('writing', 'style', 'difficult'): 2,
#  ('style', 'difficult', 'get'): 2,
#  ('difficult', 'get', 'used'): 2,
#  ('get', 'used', 'first'): 2,
#  ('used', 'first', 'tale'): 2,
#  ('first', 'tale', 'grows'): 2,
#  ('tale', 'grows', 'chilling'): 2,
#  ('grows', 'chilling', 'go'): 2,
#  ('chilling', 'go', 'various'): 2,
#  ('go', 'various', 'authors'): 2,
#  ('various', 'authors', 'bible'): 2,
#  ('authors', 'bible', 'somewhat'): 2,
#  ('bible', 'somewhat', 'dull'): 2,
#  ('somewhat', 'dull', 'rambling'): 2,
#  ('dull', 'rambling', 'work'): 2,
#  ('rambling', 'work', 'ha'): 2,
#  ('work', 'ha', 'often'): 4,
#  ('ha', 'often', 'criticized'): 2,
#  ('often', 'criticized', 'however'): 2,
#  ('criticized', 'however', 'probably'): 2,
#  ('however', 'probably', 'worth'): 2,
#  ('probably', 'worth', 'reading'): 2,
#  ('worth', 'reading', 'know'): 2,
#  ('reading', 'know', 'fuss'): 2,
#  ('know', 'fuss', 'exists'): 2,
#  ('fuss', 'exists', 'many'): 2,
#  ('exists', 'many', 'different'): 2,
#  ('many', 'different', 'version'): 4,
#  ('different', 'version', 'make'): 2,
#  ('version', 'make', 'sure'): 2,
#  ('make', 'sure', 'get'): 15,
#  ('sure', 'get', 'one'): 3,
#  ('get', 'one', 'true'): 2,
#  ('one', 'true', 'version'): 2,
#  ('true', 'version', 'books'): 2,
#  ('version', 'books', 'non'): 2,
#  ('books', 'non', 'fiction'): 2,
#  ('non', 'fiction', 'peter'): 2,
#  ('fiction', 'peter', 'de'): 2,
#  ('peter', 'de', 'rosa'): 2,
#  ('de', 'rosa', 'vicars'): 2,
#  ('rosa', 'vicars', 'christ'): 2,
#  ('vicars', 'christ', 'bantam'): 2,
#  ('christ', 'bantam', 'press'): 2,
#  ('bantam', 'press', '1'): 2,
#  ('press', '1', '9'): 74,
#  ('9', '8', '8'): 290,
#  ('8', '8', 'although'): 6,
#  ('8', 'although', 'de'): 2,
#  ('although', 'de', 'rosa'): 2,
#  ('de', 'rosa', 'seems'): 2,
#  ('rosa', 'seems', 'christian'): 2,
#  ('seems', 'christian', 'even'): 2,
#  ('christian', 'even', 'catholic'): 2,
#  ('even', 'catholic', 'enlighting'): 2,
#  ('catholic', 'enlighting', 'history'): 2,
#  ('enlighting', 'history', 'papal'): 2,
#  ('history', 'papal', 'immorality'): 2,
#  ('papal', 'immorality', 'adultery'): 2,
#  ('immorality', 'adultery', 'fallacy'): 2,
#  ('adultery', 'fallacy', 'etc'): 2,
#  ('fallacy', 'etc', 'german'): 2,
#  ('etc', 'german', 'translation'): 2,
#  ('german', 'translation', 'gottes'): 2,
#  ('translation', 'gottes', 'erste'): 2,
#  ('gottes', 'erste', 'diener'): 2,
#  ('erste', 'diener', 'die'): 2,
#  ('diener', 'die', 'dunkle'): 2,
#  ('die', 'dunkle', 'seite'): 2,
#  ('dunkle', 'seite', 'de'): 2,
#  ('seite', 'de', 'papsttums'): 2,
#  ('de', 'papsttums', 'droemer'): 2,
#  ('papsttums', 'droemer', 'knaur'): 2,
#  ('droemer', 'knaur', '1'): 2,
#  ('knaur', '1', '9'): 2,
#  ('9', '8', '9'): 251,
#  ('8', '9', 'michael'): 2,
#  ('9', 'michael', 'martin'): 2,
#  ('michael', 'martin', 'atheism'): 2,
#  ('martin', 'atheism', 'philosophical'): 2,
#  ('atheism', 'philosophical', 'justification'): 2,
#  ('philosophical', 'justification', 'temple'): 2,
#  ('justification', 'temple', 'university'): 2,
#  ('temple', 'university', 'press'): 4,
#  ('university', 'press', 'philadelphia'): 2,
#  ('press', 'philadelphia', 'usa'): 2,
#  ('philadelphia', 'usa', 'detailed'): 2,
#  ('usa', 'detailed', 'scholarly'): 2,
#  ('detailed', 'scholarly', 'justification'): 2,
#  ('scholarly', 'justification', 'atheism'): 2,
#  ('justification', 'atheism', 'contains'): 2,
#  ('atheism', 'contains', 'outstanding'): 2,
#  ('contains', 'outstanding', 'appendix'): 2,
#  ('outstanding', 'appendix', 'defining'): 2,
#  ('appendix', 'defining', 'terminology'): 2,
#  ('defining', 'terminology', 'usage'): 2,
#  ('terminology', 'usage', 'necessarily'): 2,
#  ('usage', 'necessarily', 'tendentious'): 2,
#  ('necessarily', 'tendentious', 'area'): 2,
#  ('tendentious', 'area', 'argues'): 2,
#  ('area', 'argues', 'negative'): 2,
#  ('argues', 'negative', 'atheism'): 2,
#  ('negative', 'atheism', 'e'): 2,
#  ('atheism', 'e', 'non'): 2,
#  ('e', 'non', 'belief'): 2,
#  ('non', 'belief', 'existence'): 2,
#  ('belief', 'existence', 'god'): 5,
#  ('existence', 'god', 'also'): 3,
#  ('god', 'also', 'positive'): 2,
#  ('also', 'positive', 'atheism'): 2,
#  ('positive', 'atheism', 'belief'): 2,
#  ('atheism', 'belief', 'non'): 2,
#  ('belief', 'non', 'existence'): 2,
#  ('non', 'existence', 'god'): 12,
#  ('existence', 'god', 'includes'): 2,
#  ('god', 'includes', 'great'): 2,
#  ('includes', 'great', 'refutation'): 2,
#  ('great', 'refutation', 'challenging'): 2,
#  ('refutation', 'challenging', 'argument'): 2,
#  ('challenging', 'argument', 'god'): 2,
#  ('argument', 'god', 'particular'): 2,
#  ('god', 'particular', 'attention'): 2,
#  ('particular', 'attention', 'paid'): 3,
#  ('attention', 'paid', 'refuting'): 2,
#  ('paid', 'refuting', 'contempory'): 2,
#  ('refuting', 'contempory', 'theist'): 2,
#  ('contempory', 'theist', 'platinga'): 2,
#  ('theist', 'platinga', 'swinburne'): 2,
#  ('platinga', 'swinburne', '5'): 2,
#  ('swinburne', '5', '4'): 2,
#  ('5', '4', '1'): 89,
#  ('4', '1', 'page'): 3,
#  ('1', 'page', 'isbn'): 2,
#  ('page', 'isbn', '0-87722'): 4,
#  ('isbn', '0-87722', '642-3'): 2,
#  ('0-87722', '642-3', 'hardcover'): 2,
#  ('642-3', 'hardcover', 'paperback'): 2,
#  ('hardcover', 'paperback', 'also'): 2,
#  ('paperback', 'also', 'available'): 2,
#  ('also', 'available', 'case'): 2,
#  ('available', 'case', 'christianity'): 2,
#  ('case', 'christianity', 'temple'): 2,
#  ('christianity', 'temple', 'university'): 2,
#  ('university', 'press', 'comprehensive'): 2,
#  ('press', 'comprehensive', 'critique'): 2,
#  ('comprehensive', 'critique', 'christianity'): 2,
#  ('critique', 'christianity', 'considers'): 2,
#  ('christianity', 'considers', 'best'): 2,
#  ('considers', 'best', 'contemporary'): 2,
#  ('best', 'contemporary', 'defence'): 2,
#  ('contemporary', 'defence', 'christianity'): 2,
#  ('defence', 'christianity', 'ultimately'): 2,
#  ('christianity', 'ultimately', 'demonstrates'): 2,
#  ('ultimately', 'demonstrates', 'unsupportable'): 2,
#  ('demonstrates', 'unsupportable', '/'): 2,
#  ('unsupportable', '/', 'incoherent'): 2,
#  ('/', 'incoherent', '2'): 2,
#  ('incoherent', '2', '7'): 2,
#  ('2', '7', '3'): 70,
#  ('7', '3', 'page'): 3,
#  ('3', 'page', 'isbn'): 2,
#  ('isbn', '0-87722', '767-5'): 2,
#  ('0-87722', '767-5', 'james'): 2,
#  ('767-5', 'james', 'turner'): 2,
#  ('james', 'turner', 'without'): 2,
#  ('turner', 'without', 'god'): 2,
#  ('without', 'god', 'without'): 4,
#  ('god', 'without', 'creed'): 4,
#  ('without', 'creed', 'johns'): 2,
#  ('creed', 'johns', 'hopkins'): 2,
#  ('johns', 'hopkins', 'university'): 69,
#  ('hopkins', 'university', 'press'): 7,
#  ('university', 'press', 'baltimore'): 7,
#  ('press', 'baltimore', 'md'): 2,
#  ('baltimore', 'md', 'usa'): 29,
#  ('md', 'usa', 'subtitled'): 2,
#  ('usa', 'subtitled', 'origins'): 2,
#  ('subtitled', 'origins', 'unbelief'): 2,
#  ('origins', 'unbelief', 'america'): 2,
#  ('unbelief', 'america', 'examines'): 2,
#  ('america', 'examines', 'way'): 2,
#  ('examines', 'way', 'unbelief'): 2,
#  ('way', 'unbelief', 'whether'): 2,
#  ('unbelief', 'whether', 'agnostic'): 2,
#  ('whether', 'agnostic', 'atheistic'): 2,
#  ('agnostic', 'atheistic', 'became'): 2,
#  ('atheistic', 'became', 'mainstream'): 2,
#  ('became', 'mainstream', 'alternative'): 2,
#  ('mainstream', 'alternative', 'world'): 2,
#  ('alternative', 'world', 'view'): 2,
#  ('world', 'view', 'focusses'): 2,
#  ('view', 'focusses', 'period'): 2,
#  ('focusses', 'period', '1770-1900'): 2,
#  ('period', '1770-1900', 'considering'): 2,
#  ('1770-1900', 'considering', 'france'): 2,
#  ('considering', 'france', 'britain'): 2,
#  ('france', 'britain', 'emphasis'): 2,
#  ('britain', 'emphasis', 'american'): 2,
#  ('emphasis', 'american', 'particularly'): 2,
#  ('american', 'particularly', 'new'): 2,
#  ('particularly', 'new', 'england'): 2,
#  ('new', 'england', 'development'): 2,
#  ('england', 'development', 'neither'): 2,
#  ('development', 'neither', 'religious'): 2,
#  ('neither', 'religious', 'history'): 2,
#  ('religious', 'history', 'secularization'): 2,
#  ('history', 'secularization', 'atheism'): 2,
#  ('secularization', 'atheism', 'without'): 2,
#  ('atheism', 'without', 'god'): 2,
#  ('without', 'creed', 'rather'): 2,
#  ('creed', 'rather', 'intellectual'): 2,
#  ('rather', 'intellectual', 'history'): 2,
#  ('intellectual', 'history', 'fate'): 2,
#  ('history', 'fate', 'single'): 2,
#  ('fate', 'single', 'idea'): 2,
#  ('single', 'idea', 'belief'): 2,
#  ('idea', 'belief', 'god'): 2,
#  ('belief', 'god', 'exists'): 4,
#  ('god', 'exists', '3'): 2,
#  ('exists', '3', '1'): 2,
#  ('3', '1', '6'): 105,
#  ('1', '6', 'page'): 2,
#  ('6', 'page', 'isbn'): 2,
#  ('page', 'isbn', 'hardcover'): 2,
#  ('isbn', 'hardcover', '0-8018'): 2,
#  ('hardcover', '0-8018', '2'): 2,
#  ('0-8018', '2', '4'): 2,
#  ('2', '4', '9'): 93,
#  ('4', '9', '4'): 38,
#  ('9', '4', 'x'): 4,
#  ('4', 'x', 'paper'): 2,
#  ('x', 'paper', '0-8018'): 2,
#  ('paper', '0-8018', '3407-4'): 2,
#  ('0-8018', '3407-4', 'george'): 2,
#  ('3407-4', 'george', 'seldes'): 2,
#  ('george', 'seldes', 'editor'): 2,
#  ('seldes', 'editor', 'great'): 2,
#  ('editor', 'great', 'thought'): 2,
#  ('great', 'thought', 'ballantine'): 2,
#  ('thought', 'ballantine', 'books'): 2,
#  ('ballantine', 'books', 'new'): 2,
#  ('books', 'new', 'york'): 4,
#  ('new', 'york', 'usa'): 11,
#  ('york', 'usa', 'dictionary'): 2,
#  ('usa', 'dictionary', 'quotation'): 2,
#  ('dictionary', 'quotation', 'different'): 2,
#  ('quotation', 'different', 'kind'): 2,
#  ('different', 'kind', 'concentrating'): 2,
#  ('kind', 'concentrating', 'statement'): 2,
#  ('concentrating', 'statement', 'writing'): 2,
#  ('statement', 'writing', 'explicitly'): 2,
#  ('writing', 'explicitly', 'implicitly'): 2,
#  ('explicitly', 'implicitly', 'present'): 2,
#  ('implicitly', 'present', "person's"): 2,
#  ('present', "person's", 'philosophy'): 2,
#  ("person's", 'philosophy', 'world'): 2,
#  ('philosophy', 'world', 'view'): 2,
#  ('world', 'view', 'includes'): 2,
#  ('view', 'includes', 'obscure'): 2,
#  ('includes', 'obscure', 'often'): 2,
#  ('obscure', 'often', 'suppressed'): 2,
#  ('often', 'suppressed', 'opinion'): 2,
#  ('suppressed', 'opinion', 'many'): 2,
#  ('opinion', 'many', 'people'): 2,
#  ('many', 'people', 'popular'): 2,
#  ('people', 'popular', 'observation'): 2,
#  ('popular', 'observation', 'trace'): 2,
#  ('observation', 'trace', 'way'): 2,
#  ('trace', 'way', 'various'): 2,
#  ('way', 'various', 'people'): 2,
#  ('various', 'people', 'expressed'): 2,
#  ('people', 'expressed', 'twisted'): 2,
#  ('expressed', 'twisted', 'idea'): 2,
#  ('twisted', 'idea', 'century'): 2,
#  ('idea', 'century', 'quite'): 2,
#  ('century', 'quite', 'number'): 2,
#  ('quite', 'number', 'quotation'): 2,
#  ('number', 'quotation', 'derived'): 2,
#  ('quotation', 'derived', "cardiff's"): 2,
#  ('derived', "cardiff's", 'great'): 2,
#  ("cardiff's", 'great', 'men'): 2,
#  ('great', 'men', 'think'): 2,
#  ('men', 'think', 'religion'): 2,
#  ('think', 'religion', "noyes'"): 2,
#  ('religion', "noyes'", 'views'): 2,
#  ("noyes'", 'views', 'religion'): 2,
#  ('views', 'religion', '4'): 2,
#  ('religion', '4', '9'): 2,
#  ('4', '9', '0'): 60,
#  ...}

# %%
freqs= dict()
for d in data:
    freqs[d] = freqs.get(d, 0) + 1

# %%
freqs
# Out:
# {'mathew': 161,
#  'mathew@mantis.co.uk': 84,
#  'subject': 20474,
#  'alt': 571,
#  'atheism': 544,
#  'faq': 1016,
#  'atheist': 784,
#  'resources': 87,
#  'summary': 967,
#  'books': 143,
#  'address': 1493,
#  'music': 271,
#  'anything': 2336,
#  'related': 681,
#  'keywords': 1505,
#  'book': 2285,
#  'fiction': 107,
#  'contact': 1028,
#  'expires': 153,
#  'thu': 160,
#  '29 apr 1993': 10,
#  '11:57:19': 1,
#  'gmt': 883,
#  'distribution': 4571,
#  'world': 4198,
#  'organization': 18926,
#  'mantis': 52,
#  'consultants': 60,
#  'cambridge': 400,
#  'uk': 795,
#  'supersedes': 50,
#  '19930301143317@mantis.co.uk': 1,
#  'lines': 18927,
#  '2': 62661,
#  '9': 47316,
#  '0': 68739,
#  'archive': 610,
#  'name': 2518,
#  '/': 54151,
#  'resource': 701,
#  'last': 3043,
#  'modified': 226,
#  '11 december 1992': 1,
#  'version': 2149,
#  '1': 92039,
#  'addresses': 24,
#  'organizations': 19,
#  'usa': 2885,
#  'freedom': 623,
#  'religion': 1385,
#  'foundation': 267,
#  'darwin': 39,
#  'fish': 126,
#  'bumper': 57,
#  'sticker': 90,
#  'assorted': 25,
#  'paraphernalia': 5,
#  'available': 2490,
#  'us': 2311,
#  'write': 1016,
#  'ffrf': 2,
#  'p': 8476,
#  'box': 1406,
#  '7': 33029,
#  '5': 43267,
#  'madison': 121,
#  'wi': 102,
#  '53701': 4,
#  'telephone': 338,
#  'evolution': 142,
#  'designs': 26,
#  'sell': 884,
#  'symbol': 115,
#  'like': 9781,
#  'one': 15106,
#  'christians': 970,
#  'stick': 408,
#  'car': 2794,
#  'foot': 499,
#  'word': 2413,
#  'written': 864,
#  'inside': 583,
#  'deluxe': 44,
#  'moulded': 4,
#  '3': 56131,
#  'plastic': 204,
#  '$4.95': 10,
#  'postpaid': 3,
#  'laurel': 17,
#  'canyon': 27,
#  '#': 27273,
#  '4': 44939,
#  'north': 629,
#  'hollywood': 30,
#  'ca': 1985,
#  '91605': 2,
#  'people': 9344,
#  'san': 930,
#  'francisco': 297,
#  'bay': 246,
#  'area': 1526,
#  'get': 9041,
#  'lynn': 65,
#  'gold': 172,
#  'try': 2220,
#  'mailing': 454,
#  'figmo@netcom.com': 2,
#  'net': 1582,
#  'go': 4998,
#  'directly': 570,
#  'price': 1622,
#  'per': 924,
#  'american': 1409,
#  'press': 943,
#  'aap': 15,
#  'publish': 115,
#  'various': 734,
#  'critique': 36,
#  'bible': 1253,
#  'list': 2272,
#  'biblical': 286,
#  'contradiction': 139,
#  'handbook': 77,
#  'w': 9101,
#  'ball': 494,
#  'g': 8820,
#  'foote': 8,
#  'pp': 450,
#  'isbn': 109,
#  '0-910309': 2,
#  '6': 38746,
#  'nd': 521,
#  'edition': 250,
#  '8': 38629,
#  'absurdity': 54,
#  'atrocity': 82,
#  'immorality': 13,
#  'contains': 471,
#  'contradicts': 41,
#  'based': 1730,
#  'king': 504,
#  'james': 947,
#  '140195': 2,
#  'austin': 447,
#  'tx': 417,
#  '78714-0195': 2,
#  'cameron': 18,
#  'road': 976,
#  '78752-2973': 2,
#  'fax': 1364,
#  'prometheus': 12,
#  'including': 1104,
#  "haught's": 2,
#  'holy': 394,
#  'horrors': 8,
#  'see': 5265,
#  'east': 567,
#  'amherst': 58,
#  'street': 592,
#  'buffalo': 371,
#  'new': 6353,
#  'york': 866,
#  '14215': 2,
#  'alternate': 55,
#  'may': 5520,
#  'newer': 166,
#  'older': 299,
#  'glenn': 105,
#  'drive': 3313,
#  'ny': 628,
#  '14228-2197': 2,
#  'african': 105,
#  'americans': 441,
#  'humanism': 17,
#  'promoting': 52,
#  'black': 995,
#  'secular': 113,
#  'uncovering': 6,
#  'history': 1139,
#  'freethought': 3,
#  'quarterly': 42,
#  'newsletter': 197,
#  'aah': 2,
#  'examiner': 35,
#  'norm': 60,
#  'r': 9278,
#  'allen': 315,
#  'jr': 297,
#  '14226': 2,
#  'united': 718,
#  'kingdom': 228,
#  'rationalist': 2,
#  'association': 306,
#  'national': 1504,
#  'society': 876,
#  'islington': 2,
#  'high': 2026,
#  'holloway': 16,
#  'london': 261,
#  'n': 4992,
#  'ew': 106,
#  'nl': 255,
#  '071 226': 2,
#  'british': 411,
#  'humanist': 31,
#  'south': 504,
#  'place': 2147,
#  'ethical': 76,
#  "lamb's": 3,
#  'conduit': 28,
#  'passage': 313,
#  'conway': 14,
#  'hall': 364,
#  'wc': 134,
#  'rh': 124,
#  'red': 813,
#  'lion': 33,
#  'square': 162,
#  '071 430': 2,
#  'rl': 170,
#  'fax 071 430': 2,
#  'freethinker': 2,
#  'monthly': 109,
#  'magazine': 475,
#  'founded': 102,
#  'germany': 638,
#  'ibka': 6,
#  'e': 8335,
#  'v': 9279,
#  'internationaler': 4,
#  'bund': 6,
#  'der': 95,
#  'konfessionslosen': 4,
#  'und': 41,
#  'atheisten': 4,
#  'postfach': 14,
#  '00 berlin 41': 4,
#  'journal': 268,
#  'miz': 5,
#  'materialien': 2,
#  'informationen': 2,
#  'zur': 12,
#  'zeit': 6,
#  'politisches': 2,
#  'konfessionslosesn': 2,
#  'hrsg': 2,
#  'vertrieb': 2,
#  'ibdk': 2,
#  'b': 8902,
#  'ucherdienst': 2,
#  '00 hannover 1': 2,
#  '0511/2112': 2,
#  'thomas': 706,
#  'disch': 2,
#  'santa': 227,
#  'claus': 19,
#  'compromise': 159,
#  'short': 814,
#  'story': 902,
#  'ultimate': 112,
#  'proof': 499,
#  'exists': 571,
#  'character': 486,
#  'event': 909,
#  'fictitious': 6,
#  'similarity': 50,
#  'living': 606,
#  'dead': 907,
#  'god': 4639,
#  'uh': 218,
#  'well': 5628,
#  'walter': 99,
#  'miller': 297,
#  'canticle': 2,
#  'leibowitz': 4,
#  'gem': 32,
#  'post': 2359,
#  'atomic': 87,
#  'doomsday': 5,
#  'novel': 64,
#  'monk': 21,
#  'spent': 302,
#  'life': 2476,
#  'copying': 73,
#  'blueprint': 5,
#  'saint': 144,
#  'filling': 53,
#  'sheet': 195,
#  'paper': 819,
#  'ink': 93,
#  'leaving': 203,
#  'white': 1097,
#  'line': 2877,
#  'letter': 704,
#  'edgar': 36,
#  'pangborn': 2,
#  'davy': 11,
#  'set': 2370,
#  'clerical': 7,
#  'state': 4266,
#  'church': 1266,
#  'example': 1887,
#  'forbids': 16,
#  'anyone': 4153,
#  'produce': 471,
#  'describe': 192,
#  'use': 6662,
#  'substance': 162,
#  'containing': 207,
#  'atom': 120,
#  'philip': 74,
#  'k': 5945,
#  'dick': 163,
#  'wrote': 1585,
#  'many': 4792,
#  'philosophical': 86,
#  'thought': 1881,
#  'provoking': 15,
#  'bizarre': 60,
#  'time': 7953,
#  'approachable': 2,
#  'mainly': 169,
#  'sf': 157,
#  'truth': 1000,
#  'rather': 1845,
#  'technology': 1856,
#  'although': 1033,
#  'often': 1171,
#  'believed': 294,
#  'met': 213,
#  'sort': 1122,
#  'remained': 79,
#  'sceptical': 26,
#  'amongst': 78,
#  'following': 1616,
#  'relevance': 47,
#  'galactic': 32,
#  'pot': 81,
#  'healer': 20,
#  'fallible': 13,
#  'alien': 98,
#  'deity': 81,
#  'summons': 10,
#  'group': 2951,
#  'earth': 1047,
#  'craftsman': 6,
#  'woman': 1111,
#  'remote': 430,
#  'planet': 397,
#  'raise': 242,
#  'giant': 95,
#  'cathedral': 7,
#  'beneath': 29,
#  'ocean': 69,
#  'begin': 472,
#  'demand': 284,
#  'faith': 1013,
#  'earthers': 9,
#  'joe': 560,
#  'fernwright': 2,
#  'unable': 199,
#  'comply': 28,
#  'polished': 12,
#  'ironic': 41,
#  'amusing': 73,
#  'maze': 7,
#  'death': 1289,
#  'noteworthy': 18,
#  'description': 380,
#  'valis': 4,
#  'schizophrenic': 4,
#  'hero': 65,
#  'search': 496,
#  'hidden': 150,
#  'mystery': 126,
#  'gnostic': 8,
#  'christianity': 710,
#  'reality': 434,
#  'fired': 228,
#  'brain': 418,
#  'pink': 101,
#  'laser': 293,
#  'beam': 128,
#  'unknown': 227,
#  'possibly': 436,
#  'divine': 181,
#  'origin': 262,
#  'accompanied': 35,
#  'dogmatic': 21,
#  'dismissively': 2,
#  'friend': 1060,
#  'odd': 175,
#  'invasion': 114,
#  'invades': 8,
#  'making': 1048,
#  'young': 733,
#  'pregnant': 56,
#  'return': 875,
#  'another': 2740,
#  'star': 488,
#  'system': 5444,
#  'unfortunately': 522,
#  'terminally': 7,
#  'ill': 114,
#  'must': 2829,
#  'assisted': 42,
#  'man': 1772,
#  'whose': 535,
#  'wired': 48,
#  'hour': 805,
#  'easy': 838,
#  'listening': 146,
#  'margaret': 14,
#  'atwood': 5,
#  "handmaid's": 2,
#  'tale': 63,
#  'premise': 137,
#  'congress': 510,
#  'mysteriously': 6,
#  'assassinated': 7,
#  'fundamentalist': 112,
#  'quickly': 305,
#  'take': 3690,
#  'charge': 547,
#  'nation': 492,
#  'right': 5515,
#  'diary': 26,
#  "woman's": 30,
#  'live': 1142,
#  'christian': 1651,
#  'theocracy': 4,
#  "women's": 75,
#  'property': 435,
#  'revoked': 13,
#  'bank': 366,
#  'account': 631,
#  'closed': 404,
#  'sinful': 78,
#  'luxury': 59,
#  'outlawed': 24,
#  'radio': 849,
#  'used': 4036,
#  'reading': 919,
#  'crimes': 5,
#  'punished': 72,
#  'retroactively': 3,
#  'doctor': 610,
#  'performed': 172,
#  'legal': 690,
#  'abortion': 178,
#  'old': 1988,
#  'hunted': 7,
#  'hanged': 32,
#  "atwood's": 2,
#  'writing': 541,
#  'style': 354,
#  'difficult': 537,
#  'first': 4816,
#  'grows': 42,
#  'chilling': 19,
#  'authors': 24,
#  'somewhat': 287,
#  'dull': 46,
#  'rambling': 15,
#  'work': 4906,
#  'ha': 11800,
#  'criticized': 20,
#  'however': 2320,
#  'probably': 2217,
#  'worth': 672,
#  'know': 9249,
#  'fuss': 19,
#  'different': 2169,
#  'make': 6150,
#  'sure': 2763,
#  'true': 2161,
#  'non': 1724,
#  'peter': 789,
#  'de': 1658,
#  'rosa': 29,
#  'vicars': 2,
#  'christ': 966,
#  'bantam': 7,
#  'seems': 2213,
#  'even': 5371,
#  'catholic': 366,
#  'enlighting': 2,
#  'papal': 26,
#  'adultery': 27,
#  'fallacy': 134,
#  'etc': 2789,
#  'german': 331,
#  'translation': 309,
#  'gottes': 2,
#  'erste': 4,
#  'diener': 2,
#  'die': 623,
#  'dunkle': 2,
#  'seite': 2,
#  'papsttums': 2,
#  'droemer': 2,
#  'knaur': 2,
#  'michael': 1467,
#  'martin': 286,
#  'justification': 151,
#  'temple': 184,
#  'university': 9436,
#  'philadelphia': 242,
#  'detailed': 170,
#  'scholarly': 41,
#  'outstanding': 38,
#  'appendix': 17,
#  'defining': 66,
#  'terminology': 54,
#  'usage': 196,
#  'necessarily': 556,
#  'tendentious': 7,
#  'argues': 33,
#  'negative': 196,
#  'belief': 1196,
#  'existence': 556,
#  'also': 7239,
#  'positive': 312,
#  'includes': 682,
#  'great': 2042,
#  'refutation': 29,
#  'challenging': 24,
#  'argument': 1287,
#  'particular': 855,
#  'attention': 312,
#  'paid': 383,
#  'refuting': 9,
#  'contempory': 2,
#  'theist': 174,
#  'platinga': 2,
#  'swinburne': 14,
#  'page': 947,
#  '0-87722': 4,
#  '642-3': 2,
#  'hardcover': 21,
#  'paperback': 39,
#  'case': 3306,
#  'comprehensive': 142,
#  'considers': 51,
#  'best': 2249,
#  'contemporary': 61,
#  'defence': 104,
#  'ultimately': 92,
#  'demonstrates': 55,
#  'unsupportable': 2,
#  'incoherent': 10,
#  '767-5': 2,
#  'turner': 85,
#  'without': 2718,
#  'creed': 79,
#  'johns': 83,
#  'hopkins': 154,
#  'baltimore': 219,
#  'md': 676,
#  'subtitled': 2,
#  'origins': 12,
#  'unbelief': 6,
#  'america': 511,
#  'examines': 5,
#  'way': 5625,
#  'whether': 1520,
#  'agnostic': 80,
#  'atheistic': 22,
#  'became': 326,
#  'mainstream': 71,
#  'alternative': 420,
#  'view': 1526,
#  'focusses': 2,
#  'period': 923,
#  '1770-1900': 2,
#  'considering': 398,
#  'france': 221,
#  'britain': 111,
#  'emphasis': 112,
#  'particularly': 387,
#  'england': 241,
#  'development': 684,
#  'neither': 551,
#  'religious': 834,
#  'secularization': 3,
#  'intellectual': 118,
#  'fate': 86,
#  'single': 1060,
#  'idea': 2110,
#  '0-8018': 4,
#  'x': 16218,
#  '3407-4': 2,
#  'george': 640,
#  'seldes': 3,
#  'editor': 325,
#  'ballantine': 2,
#  'dictionary': 213,
#  'quotation': 70,
#  'kind': 1702,
#  'concentrating': 13,
#  'statement': 1185,
#  'explicitly': 131,
#  'implicitly': 29,
#  'present': 699,
#  "person's": 66,
#  'philosophy': 205,
#  'obscure': 70,
#  'suppressed': 34,
#  'opinion': 2238,
#  'popular': 330,
#  'observation': 319,
#  'trace': 153,
#  'expressed': 410,
#  'twisted': 51,
#  'century': 437,
#  'quite': 1606,
#  'number': 3574,
#  'derived': 125,
#  "cardiff's": 2,
#  'men': 1072,
#  'think': 7765,
#  "noyes'": 2,
#  'views': 31,
#  '0-345': 5,
#  '29887': 2,
#  'richard': 645,
#  'revised': 93,
#  'clarendon': 4,
#  'paperbacks': 4,
#  'oxford': 80,
#  'second': 2156,
#  'volume': 553,
#  'trilogy': 4,
#  'began': 293,
#  'coherence': 9,
#  'theism': 171,
#  'wa': 22631,
#  'concluded': 81,
#  'reason': 2312,
#  'attempt': 689,
#  'construct': 62,
#  'series': 824,
#  'inductive': 30,
#  'rely': 133,
#  'upon': 799,
#  'imputation': 5,
#  'late': 484,
#  'th': 1230,
#  'western': 861,
#  'value': 1265,
#  'aesthetic': 30,
#  'supposedly': 201,
#  'simple': 893,
#  'conceived': 41,
#  'decisively': 5,
#  'rejected': 114,
#  "mackie's": 3,
#  'miracle': 159,
#  'rebut': 10,
#  'mackie': 34,
#  'j': 4810,
#  'l': 5697,
#  'posthumous': 2,
#  'review': 423,
#  'principal': 61,
#  'range': 532,
#  'classical': 57,
#  'position': 1059,
#  'descartes': 12,
#  'anselm': 6,
#  'berkeley': 409,
#  'hume': 4,
#  'et': 450,
#  'al': 849,
#  'moral': 820,
#  'newman': 39,
#  'kant': 13,
#  'sidgwick': 2,
#  'recent': 499,
#  'restatement': 4,
#  'thesis': 55,
#  'plantinga': 2,
#  'push': 221,
#  'concept': 461,
#  'beyond': 436,
#  'realm': 42,
#  'rational': 188,
#  'kierkegaard': 6,
#  'kung': 6,
#  'philips': 61,
#  'replacement': 222,
#  "lelie's": 2,
#  'axiarchism': 2,
#  'delight': 16,
#  'read': 3036,
#  'le': 1730,
#  'formalistic': 3,
#  'better': 2923,
#  "martin's": 10,
#  'refreshingly': 2,
#  'direct': 405,
#  'compared': 365,
#  'hand': 1610,
#  'waving': 46,
#  'haught': 2,
#  'illustrated': 28,
#  'murder': 479,
#  'madness': 36,
#  'looks': 57,
#  'persecution': 98,
#  'ancient': 270,
#  'day': 3561,
#  'library': 772,
#  'catalog': 154,
#  'card': 2385,
#  '89-64079': 2,
#  'anthology': 7,
#  'listing': 137,
#  'gordon': 426,
#  'stein': 106,
#  'rationalism': 7,
#  'covering': 96,
#  'wide': 427,
#  'devil': 125,
#  'evil': 493,
#  "morality'": 6,
#  "freethought'": 2,
#  'bibliography': 63,
#  'edmund': 12,
#  'cohen': 52,
#  'mind': 1320,
#  'believer': 184,
#  'study': 1168,
#  'become': 868,
#  'effect': 1173,
#  "there's": 1266,
#  'small': 1307,
#  'mail': 3235,
#  'server': 1303,
#  'co': 689,
#  'carry': 607,
#  'moderated': 44,
#  'article': 12652,
#  'file': 4867,
#  'information': 3171,
#  'send': 1673,
#  'server@mantis.co.uk': 4,
#  'saying': 1281,
#  'help': 3453,
#  'index': 215,
#  'back': 3439,
#  'reply': 4197,
#  'я': 18,
#  'introduction': 179,
#  'please': 3600,
#  'posting': 9396,
#  '6 may 1993': 20,
#  '12:22:45': 1,
#  '19930308134439@mantis.co.uk': 1,
#  '5 april 1993': 5,
#  'pgp': 414,
#  'signed': 195,
#  'message': 2172,
#  'provide': 877,
#  'general': 1685,
#  'whilst': 21,
#  'tried': 1015,
#  'neutral': 213,
#  'possible': 1888,
#  'regarding': 427,
#  'contentious': 15,
#  'issue': 1839,
#  'always': 1668,
#  'remember': 1426,
#  'document': 537,
#  'represents': 178,
#  'viewpoint': 89,
#  'would': 14798,
#  'encourage': 116,
#  'widely': 160,
#  'draw': 412,
#  'conclusion': 468,
#  'relevant': 244,
#  'listed': 244,
#  'companion': 42,
#  'sense': 898,
#  'cohesion': 2,
#  'progression': 31,
#  'presented': 259,
#  'imaginary': 34,
#  'conversation': 318,
#  'question': 4223,
#  'asked': 934,
#  'cropped': 7,
#  'repeatedly': 102,
#  'since': 3491,
#  'newsgroup': 599,
#  'created': 569,
#  'frequently': 266,
#  'answered': 186,
#  'note': 1585,
#  'arguably': 27,
#  'slanted': 8,
#  'towards': 357,
#  'answering': 91,
#  'posed': 34,
#  'reflect': 176,
#  'actually': 2043,
#  'predominantly': 16,
#  'proselytize': 6,
#  'talk': 1193,
#  'talking': 903,
#  'primarily': 194,
#  'judaism': 90,
#  'islam': 456,
#  'involve': 153,
#  'superhuman': 12,
#  'much': 4790,
#  'discussion': 1053,
#  'apply': 469,
#  'characterized': 35,
#  'absence': 87,
#  'believe': 3426,
#  'doe': 5124,
#  'exist': 753,
#  'former': 438,
#  'referred': 167,
#  'weak': 232,
#  'latter': 227,
#  'strong': 711,
#  'important': 1127,
#  'difference': 1220,
#  'two': 4939,
#  'scepticism': 9,
#  'disbelief': 30,
#  'fall': 572,
#  'trap': 114,
#  'assuming': 387,
#  'gods': 46,
#  'others': 1691,
#  'limit': 443,
#  'specific': 812,
#  'flat': 200,
#  'denial': 76,
#  'disbelieving': 3,
#  'thing': 5346,
#  'believing': 174,
#  'definitely': 294,
#  'proposition': 71,
#  'mean': 3315,
#  'something': 3574,
#  'equivalent': 228,
#  'false': 430,
#  'simply': 1134,
#  'brings': 120,
#  'u': 12128,
#  'agnosticism': 21,
#  'term': 1192,
#  "agnosticism'": 1,
#  'coined': 24,
#  'professor': 312,
#  'huxley': 6,
#  'meeting': 318,
#  'metaphysical': 23,
#  'defined': 385,
#  'someone': 2628,
#  'disclaimed': 6,
#  'cause': 1399,
#  'unknowable': 11,
#  'thus': 877,
#  'cannot': 1344,
#  'words': 37,
#  'slippery': 21,
#  'language': 662,
#  'inexact': 4,
#  'beware': 61,
#  "someone's": 67,
#  'point': 3810,
#  'fact': 2733,
#  'call': 2243,
#  'referring': 169,
#  'shade': 45,
#  'meaning': 612,
#  'generalize': 13,
#  'say': 6491,
#  'certainly': 1075,
#  'science': 2115,
#  'find': 3255,
#  'universe': 455,
#  'basis': 559,
#  'person': 1871,
#  'chooses': 58,
#  'ask': 1327,
#  'feel': 1315,
#  'major': 1011,
#  'essentially': 239,
#  'self': 929,
#  'contradictory': 93,
#  'logically': 53,
#  'impossible': 352,
#  'could': 5830,
#  'evidence': 1476,
#  'prove': 496,
#  'counter': 159,
#  'prime': 186,
#  'larger': 327,
#  'course': 2131,
#  'deal': 960,
#  'object': 826,
#  'obeying': 21,
#  'rule': 1067,
#  'similarly': 149,
#  'matter': 1390,
#  'debate': 267,
#  'moment': 415,
#  'provably': 6,
#  'still': 3355,
#  'subtle': 41,
#  'assume': 697,
#  'show': 1694,
#  'assumption': 319,
#  'invalid': 70,
#  'finding': 328,
#  'showing': 273,
#  'require': 479,
#  'exhaustive': 21,
#  'might': 3013,
#  'found': 1736,
#  'impractical': 17,
#  'problem': 5265,
#  'largest': 107,
#  'therefore': 785,
#  'generally': 504,
#  'accepted': 341,
#  'unless': 1007,
#  'follow': 598,
#  'unicorn': 26,
#  'though': 1958,
#  "can't": 2825,
#  'conclusively': 6,
#  'anywhere': 303,
#  'tested': 219,
#  'everywhere': 139,
#  'assumes': 87,
#  'default': 394,
#  'test': 1134,
#  'profess': 18,
#  'usually': 872,
#  'claim': 1647,
#  'instead': 1076,
#  'restrict': 84,
#  'cover': 715,
#  'variety': 228,
#  'described': 401,
#  'follower': 206,
#  'practice': 548,
#  'close': 735,
#  'sufficiently': 60,
#  'impossibility': 5,
#  'disproving': 10,
#  'every': 2245,
#  'really': 3635,
#  'applicable': 70,
#  'detectable': 25,
#  'interacts': 6,
#  'interaction': 66,
#  'measurable': 19,
#  'hence': 216,
#  'interact': 38,
#  'argue': 311,
#  'importance': 154,
#  'easily': 536,
#  'israelites': 60,
#  'surely': 255,
#  'today': 1351,
#  'demanding': 53,
#  'scientifically': 14,
#  'verifiable': 17,
#  'physical': 459,
#  'perceive': 33,
#  'caused': 426,
#  'presence': 196,
#  'otherwise': 605,
#  'distinguish': 76,
#  'ok': 959,
#  'common': 875,
#  'pastime': 5,
#  'redefinition': 5,
#  'game': 3450,
#  'cynical': 37,
#  'follows': 286,
#  'gradually': 44,
#  'defines': 90,
#  'arrives': 20,
#  'prepared': 202,
#  'accept': 706,
#  'record': 742,
#  'along': 680,
#  'agreed': 197,
#  'continues': 148,
#  ...}

# %% [markdown]
# Алгоритм расчета меры ассоциации: лексемы, MI (вариант 3)

# %%
from math import pow
import math

def mi(threegram, freqs_treegram,freqs, N):
    ngram = 3
    return math.log((freqs_treegram[threegram]/(freqs[threegram[0]]*freqs[threegram[1]]*freqs[threegram[2]]))*pow(N, ngram - 1),2)

# %%
mi_measures=dict()
for threegram in threegrams:
    mi_measures[threegram]=mi(threegram=threegram,freqs_treegram=freqs_treegram,freqs=freqs,N=len(data))

# %%
mi_measures
# Out:
# {('mathew', 'mathew@mantis.co.uk', 'subject'): 21.34866772289835,
#  ('mathew@mantis.co.uk', 'subject', 'alt'): 17.12013922207878,
#  ('subject', 'alt', 'atheism'): 14.787563882991911,
#  ('alt', 'atheism', 'faq'): 20.535422063897343,
#  ('atheism', 'faq', 'atheist'): 17.49309665442382,
#  ('faq', 'atheist', 'resources'): 20.13761599982543,
#  ('atheist', 'resources', 'summary'): 19.208928607120757,
#  ('resources', 'summary', 'books'): 21.663767114457574,
#  ('summary', 'books', 'address'): 17.562712160171763,
#  ('books', 'address', 'music'): 19.397935198294732,
#  ('address', 'music', 'anything'): 15.367981976193102,
#  ('music', 'anything', 'related'): 16.500469438315573,
#  ('anything', 'related', 'atheism'): 15.495155638419106,
#  ('related', 'atheism', 'keywords'): 16.12943242565206,
#  ('atheism', 'keywords', 'faq'): 16.552258726891964,
#  ('keywords', 'faq', 'atheism'): 17.552258726891964,
#  ('faq', 'atheism', 'book'): 14.949828048593595,
#  ('atheism', 'book', 'music'): 16.85636369401189,
#  ('book', 'music', 'fiction'): 19.202359548861082,
#  ('music', 'fiction', 'address'): 19.816339548671976,
#  ('fiction', 'address', 'contact'): 17.892864040831967,
#  ('address', 'contact', 'expires'): 17.376943184540462,
#  ('contact', 'expires', 'thu'): 20.59901353978764,
#  ('expires', 'thu', '29 apr 1993'): 26.28270999409416,
#  ('thu', '29 apr 1993', '11:57:19'): 33.54009783678681,
#  ('29 apr 1993', '11:57:19', 'gmt'): 31.07575630402571,
#  ('11:57:19', 'gmt', 'distribution'): 22.239390295309033,
#  ('gmt', 'distribution', 'world'): 13.663335462654176,
#  ('distribution', 'world', 'organization'): 14.400477063942828,
#  ('world', 'organization', 'mantis'): 15.699377565784461,
#  ('organization', 'mantis', 'consultants'): 23.86039489916047,
#  ('mantis', 'consultants', 'cambridge'): 29.424620619366873,
#  ('consultants', 'cambridge', 'uk'): 25.490249287336248,
#  ('cambridge', 'uk', 'supersedes'): 23.068785518897972,
#  ('uk', 'supersedes', '19930301143317@mantis.co.uk'): 28.905286786615093,
#  ('supersedes', '19930301143317@mantis.co.uk', 'lines'): 24.33193970061272,
#  ('19930301143317@mantis.co.uk', 'lines', '2'): 14.04051571713399,
#  ('lines', '2', '9'): 7.0535070415602545,
#  ('2', '9', '0'): 2.7372549553303482,
#  ('9', '0', 'archive'): 4.332406854883212,
#  ('0', 'archive', 'name'): 10.564384782993168,
#  ('archive', 'name', 'atheism'): 17.35311810719953,
#  ('name', 'atheism', '/'): 10.881083179945035,
#  ('atheism', '/', 'resource'): 11.918520191595825,
#  ('/', 'resource', 'alt'): 10.84863609748332,
#  ('resource', 'alt', 'atheism'): 17.485873615937727,
#  ('alt', 'atheism', 'archive'): 19.493833739555708,
#  ('atheism', 'archive', 'name'): 17.35311810719953,
#  ('archive', 'name', 'resource'): 15.179955392381647,
#  ('name', 'resource', 'last'): 12.861342206317298,
#  ('resource', 'last', 'modified'): 16.339225811621127,
#  ('last', 'modified', '11 december 1992'): 24.79249644563175,
#  ('modified', '11 december 1992', 'version'): 25.29432529671856,
#  ('11 december 1992', 'version', '1'): 16.62454657076022,
#  ('version', '1', '0'): 6.555705327361118,
#  ('1', '0', 'atheist'): 2.010445250673694,
#  ('0', 'atheist', 'resources'): 12.057459443198498,
#  ('atheist', 'resources', 'addresses'): 24.54133818587644,
#  ('resources', 'addresses', 'atheist'): 24.54133818587644,
#  ('addresses', 'atheist', 'organizations'): 26.736354168281586,
#  ('atheist', 'organizations', 'usa'): 19.826961065469895,
#  ('organizations', 'usa', 'freedom'): 20.158582556561104,
#  ('usa', 'freedom', 'religion'): 13.970839809068137,
#  ('freedom', 'religion', 'foundation'): 18.72642757580079,
#  ('religion', 'foundation', 'darwin'): 21.402185615075183,
#  ('foundation', 'darwin', 'fish'): 24.860575952511816,
#  ('darwin', 'fish', 'bumper'): 27.088381870034627,
#  ('fish', 'bumper', 'sticker'): 25.881930992567202,
#  ('bumper', 'sticker', 'assorted'): 28.215354726292393,
#  ('sticker', 'assorted', 'atheist'): 24.433534896341925,
#  ('assorted', 'atheist', 'paraphernalia'): 28.60345989778424,
#  ('atheist', 'paraphernalia', 'available'): 21.96538606060352,
#  ('paraphernalia', 'available', 'freedom'): 22.297007551694726,
#  ('available', 'freedom', 'religion'): 14.183265385645537,
#  ('religion', 'foundation', 'us'): 15.513286289469796,
#  ('foundation', 'us', 'write'): 15.960271863634182,
#  ('us', 'write', 'ffrf'): 23.020967795321738,
#  ('write', 'ffrf', 'p'): 21.146101467417196,
#  ('ffrf', 'p', 'box'): 20.67740527511683,
#  ('p', 'box', '7'): 9.572850200537639,
#  ('box', '7', '5'): 4.314148005537616,
#  ('7', '5', '0'): 5.941092380536131,
#  ('5', '0', 'madison'): 6.795270074124165,
#  ('0', 'madison', 'wi'): 15.523824203916345,
#  ('madison', 'wi', '53701'): 30.592665447315447,
#  ('wi', '53701', 'telephone'): 28.11064924830785,
#  ('53701', 'telephone', 'evolution'): 27.633327470774667,
#  ('telephone', 'evolution', 'designs'): 24.932887752633572,
#  ('evolution', 'designs', 'evolution'): 26.184020069411076,
#  ('designs', 'evolution', 'designs'): 28.633327470774667,
#  ('evolution', 'designs', 'sell'): 23.54586462952433,
#  ('designs', 'sell', 'darwin'): 25.410209530166764,
#  ('sell', 'darwin', 'fish'): 23.133369324807937,
#  ('darwin', 'fish', 'fish'): 25.943991960699453,
#  ('fish', 'fish', 'symbol'): 24.383904128617328,
#  ('fish', 'symbol', 'like'): 18.105417794988433,
#  ('symbol', 'like', 'one'): 11.199863646942728,
#  ('like', 'one', 'christians'): 8.123512760812613,
#  ('one', 'christians', 'stick'): 12.706853675969928,
#  ('christians', 'stick', 'car'): 15.141571442106086,
#  ('stick', 'car', 'foot'): 16.100516373843316,
#  ('car', 'foot', 'word'): 13.536329515599059,
#  ('foot', 'word', 'darwin'): 19.699043602146276,
#  ('word', 'darwin', 'written'): 18.907052105320066,
#  ('darwin', 'written', 'inside'): 20.95631223233532,
#  ('written', 'inside', 'deluxe'): 20.782282832560274,
#  ('inside', 'deluxe', 'moulded'): 28.53717033472374,
#  ('deluxe', 'moulded', '3'): 21.94801226655953,
#  ('moulded', '3', 'plastic'): 19.73501854322533,
#  ('3', 'plastic', 'fish'): 14.757738619725414,
#  ('plastic', 'fish', '$4.95'): 27.21232066620276,
#  ('fish', '$4.95', 'postpaid'): 33.2997835074531,
#  ('$4.95', 'postpaid', 'us'): 29.102761886485386,
#  ('postpaid', 'us', 'write'): 22.436005294600584,
#  ('us', 'write', 'evolution'): 16.871220675817053,
#  ('write', 'evolution', 'designs'): 23.345082502143594,
#  ('evolution', 'designs', '7'): 18.322321518728053,
#  ('designs', '7', '1'): 8.982110949859203,
#  ('7', '1', '1'): 3.7003876198254604,
#  ('1', '1', '9'): 3.639782438647586,
#  ('1', '9', 'laurel'): 9.076493001108691,
#  ('9', 'laurel', 'canyon'): 20.811563187318754,
#  ('laurel', 'canyon', '#'): 21.60641789974878,
#  ('canyon', '#', '4'): 10.238200339982416,
#  ('#', '4', 'north'): 5.696171635266596,
#  ('4', 'north', 'hollywood'): 15.524466823057024,
#  ('north', 'hollywood', 'ca'): 20.025223932043406,
#  ('hollywood', 'ca', '91605'): 28.322140138922695,
#  ('ca', '91605', 'people'): 20.0392061756512,
#  ('91605', 'people', 'san'): 21.133042561686125,
#  ('people', 'san', 'francisco'): 14.503685941606513,
#  ('san', 'francisco', 'bay'): 22.335958495868447,
#  ('francisco', 'bay', 'area'): 21.69950866703058,
#  ('bay', 'area', 'get'): 14.108596136473217,
#  ('area', 'get', 'darwin'): 16.180745922229054,
#  ('get', 'darwin', 'fish'): 19.779005245563667,
#  ('darwin', 'fish', 'lynn'): 26.898904071170914,
#  ('fish', 'lynn', 'gold'): 24.758041535331067,
#  ('lynn', 'gold', 'try'): 20.618977497593512,
#  ('gold', 'try', 'mailing'): 17.81479682333105,
#  ('try', 'mailing', 'figmo@netcom.com'): 24.24106157803315,
#  ('mailing', 'figmo@netcom.com', 'net'): 24.72987165479783,
#  ('figmo@netcom.com', 'net', 'people'): 20.366595583208724,
#  ('net', 'people', 'go'): 9.07946039712202,
#  ('people', 'go', 'lynn'): 13.684626468566359,
#  ('go', 'lynn', 'directly'): 17.71963291839427,
#  ('lynn', 'directly', 'price'): 19.343210000263703,
#  ('directly', 'price', '$4.95'): 22.043649718404794,
#  ('price', '$4.95', 'per'): 21.34671878604084,
#  ('$4.95', 'per', 'fish'): 25.032996966758198,
#  ('per', 'fish', 'american'): 16.894469165335924,
#  ('fish', 'american', 'atheist'): 17.131508362636772,
#  ('american', 'atheist', 'press'): 17.227674325461592,
#  ('atheist', 'press', 'aap'): 21.781239626162712,
#  ('press', 'aap', 'publish'): 24.550459419333546,
#  ('aap', 'publish', 'various'): 24.911937127165427,
#  ('publish', 'various', 'atheist'): 19.204117878658735,
#  ('various', 'atheist', 'book'): 14.891629479657682,
#  ('atheist', 'book', 'critique'): 19.241340731058582,
#  ('book', 'critique', 'bible'): 18.56487987585193,
#  ('critique', 'bible', 'list'): 18.57311120629268,
#  ('bible', 'list', 'biblical'): 15.583164870956601,
#  ('list', 'biblical', 'contradiction'): 21.34035699827611,
#  ('biblical', 'contradiction', 'one'): 16.022307545514018,
#  ('contradiction', 'one', 'book'): 13.024200432346973,
#  ('one', 'book', 'bible'): 9.85197080574862,
#  ('book', 'bible', 'handbook'): 17.46801833659934,
#  ('bible', 'handbook', 'w'): 15.474187427365006,
#  ('handbook', 'w', 'p'): 12.716190254314697,
#  ('w', 'p', 'ball'): 10.03460956342492,
#  ('p', 'ball', 'g'): 10.079855982159803,
#  ('ball', 'g', 'w'): 9.977214495352207,
#  ('g', 'w', 'foote'): 15.925581726936885,
#  ('w', 'foote', 'american'): 18.571688771072132,
#  ('foote', 'american', 'atheist'): 22.108788286136686,
#  ('atheist', 'press', '3'): 9.911620080406522,
#  ('press', '3', '7'): 4.514884254334022,
#  ('3', '7', '2'): 3.886982796457765,
#  ('7', '2', 'pp'): 5.423446991903337,
#  ('2', 'pp', 'isbn'): 13.666708337314118,
#  ('pp', 'isbn', '0-910309'): 28.60198851056757,
#  ('isbn', '0-910309', '2'): 21.480489528531155,
#  ('0-910309', '2', '6'): 13.006914094417711,
#  ('2', '6', '4'): 3.5285136169009266,
#  ('6', '4', '2'): 3.76068705902996,
#  ('4', '2', 'nd'): 6.352816390734027,
#  ('2', 'nd', 'edition'): 15.164640601976005,
#  ('nd', 'edition', '1'): 11.703072491247408,
#  ('edition', '1', '9'): 7.005526479754547,
#  ('1', '9', '8'): 7.540348596689135,
#  ('9', '8', '6'): 5.617700557548443,
#  ('8', '6', 'bible'): 4.413626858206827,
#  ('6', 'bible', 'contradiction'): 12.532082495625795,
#  ('bible', 'contradiction', 'absurdity'): 22.0189547523527,
#  ('contradiction', 'absurdity', 'atrocity'): 25.952573447056473,
#  ('absurdity', 'atrocity', 'immorality'): 29.37107480163889,
#  ('atrocity', 'immorality', 'contains'): 26.246379054189575,
#  ('immorality', 'contains', 'ball'): 23.65556382722298,
#  ('contains', 'ball', 'foote'): 24.35600354536407,
#  ('ball', 'foote', 'bible'): 22.944416095654997,
#  ('foote', 'bible', 'contradicts'): 26.53523132262159,
#  ('bible', 'contradicts', 'aap'): 25.628340727013068,
#  ('contradicts', 'aap', 'based'): 25.16295510381084,
#  ('aap', 'based', 'king'): 21.543227184929012,
#  ('based', 'king', 'james'): 15.562897165069145,
#  ('king', 'james', 'version'): 16.57193181505281,
#  ('james', 'version', 'bible'): 14.521075445064659,
#  ('version', 'bible', 'write'): 13.834648873039724,
#  ('bible', 'write', 'american'): 14.44364274415787,
#  ('write', 'american', 'atheist'): 15.120103599364523,
#  ('atheist', 'press', 'p'): 12.638962349399058,
#  ('press', 'p', 'box'): 12.38125381516289,
#  ('p', 'box', '140195'): 20.67740527511683,
#  ('box', '140195', 'austin'): 24.92244212630568,
#  ('140195', 'austin', 'tx'): 26.675919431933554,
#  ('austin', 'tx', '78714-0195'): 26.675919431933554,
#  ('tx', '78714-0195', '7'): 20.468604782929162,
#  ('78714-0195', '7', '2'): 13.237228183120376,
#  ('7', '2', '1'): 3.4887374811479903,
#  ('2', '1', '5'): 3.679664788058239,
#  ('1', '5', 'cameron'): 9.123091864982017,
#  ('5', 'cameron', 'road'): 15.682312215792662,
#  ('cameron', 'road', 'austin'): 22.279160666373016,
#  ('road', 'austin', 'tx'): 17.745182094370666,
#  ('austin', 'tx', '78752-2973'): 26.675919431933554,
#  ('tx', '78752-2973', 'telephone'): 27.079171016834685,
#  ('78752-2973', 'telephone', 'fax'): 25.369446661255175,
#  ('telephone', 'fax', 'prometheus'): 22.78448416053402,
#  ('fax', 'prometheus', 'books'): 24.02549226003782,
#  ('prometheus', 'books', 'sell'): 24.65121762967056,
#  ('books', 'sell', 'book'): 17.07820168044628,
#  ('sell', 'book', 'including'): 14.129548560446501,
#  ('book', 'including', "haught's"): 22.91745111983793,
#  ('including', "haught's", 'holy'): 25.45337775032699,
#  ("haught's", 'holy', 'horrors'): 32.561902207105156,
#  ('holy', 'horrors', 'see'): 21.199684391192076,
#  ('horrors', 'see', 'write'): 19.83305152387629,
#  ('see', 'write', '7'): 7.821605853688581,
#  ('write', '7', '0'): 4.11498242620256,
#  ('7', '0', '0'): 5.249144990376391,
#  ('0', '0', 'east'): 5.220994709708466,
#  ('0', 'east', 'amherst'): 14.109926863092632,
#  ('east', 'amherst', 'street'): 20.969314740862785,
#  ('amherst', 'street', 'buffalo'): 21.58124428918421,
#  ('street', 'buffalo', 'new'): 14.806002980510991,
#  ('buffalo', 'new', 'york'): 14.842195632134374,
#  ('new', 'york', '14215'): 21.79250850803402,
#  ('york', '14215', 'telephone'): 26.024851375552625,
#  ('14215', 'telephone', 'alternate'): 30.001714876754686,
#  ('telephone', 'alternate', 'address'): 20.45771642662015,
#  ('alternate', 'address', 'may'): 16.428143311236802,
#  ('address', 'may', 'newer'): 14.834463593414537,
#  ('may', 'newer', 'older'): 17.15446036935097,
#  ('newer', 'older', 'prometheus'): 25.99995042029535,
#  ('older', 'prometheus', 'books'): 26.21511851486388,
#  ('prometheus', 'books', '5'): 19.03814071729831,
#  ('books', '5', '9'): 7.0930627221904965,
#  ('5', '9', 'glenn'): 7.538688541302764,
#  ('9', 'glenn', 'drive'): 11.245745524985423,
#  ('glenn', 'drive', 'buffalo'): 18.24051064419359,
#  ('drive', 'buffalo', 'ny'): 15.660135412968089,
#  ('buffalo', 'ny', '14228-2197'): 26.354057901049103,
#  ('ny', '14228-2197', 'african'): 28.17508776000378,
#  ('14228-2197', 'african', 'americans'): 28.68507366333789,
#  ('african', 'americans', 'humanism'): 27.182573322808707,
#  ('americans', 'humanism', 'organization'): 18.103774429772553,
#  ('humanism', 'organization', 'promoting'): 21.18796955718898,
#  ('organization', 'promoting', 'black'): 15.316879683008308,
#  ('promoting', 'black', 'secular'): 22.704782630574243,
#  ('black', 'secular', 'humanism'): 24.317759507464995,
#  ('secular', 'humanism', 'uncovering'): 31.691349722174852,
#  ('humanism', 'uncovering', 'history'): 28.357976652881923,
#  ('uncovering', 'history', 'black'): 22.486886778701255,
#  ('history', 'black', 'freethought'): 23.48688677870125,
#  ('black', 'freethought', 'publish'): 26.794948759464994,
#  ('freethought', 'publish', 'quarterly'): 31.361184052117242,
#  ('publish', 'quarterly', 'newsletter'): 25.324094733382022,
#  ('quarterly', 'newsletter', 'aah'): 31.169584784326396,
#  ('newsletter', 'aah', 'examiner'): 31.432619190160192,
#  ('aah', 'examiner', 'write'): 29.0659863228444,
#  ('examiner', 'write', 'norm'): 24.159095727235883,
#  ('write', 'norm', 'r'): 16.108780613331014,
#  ('norm', 'r', 'allen'): 18.7982572817159,
#  ('r', 'allen', 'jr'): 16.490828756523655,
#  ('allen', 'jr', 'african'): 22.956181369707366,
#  ('jr', 'african', 'americans'): 21.470754542537126,
#  ('americans', 'humanism', 'p'): 19.262688467381505,
#  ('humanism', 'p', 'box'): 17.58994243386649,
#  ('p', 'box', '6'): 9.342536111834978,
#  ('box', '6', '6'): 5.564981724595622,
#  ('6', '6', '4'): 4.244754107764092,
#  ('6', '4', 'buffalo'): 5.951238490033658,
#  ('4', 'buffalo', 'ny'): 11.8983775000324,
#  ('buffalo', 'ny', '14226'): 26.354057901049103,
#  ('ny', '14226', 'united'): 25.401493243846854,
#  ('14226', 'united', 'kingdom'): 26.863223978573743,
#  ('united', 'kingdom', 'rationalist'): 26.863223978573743,
#  ('kingdom', 'rationalist', 'press'): 26.469950051721696,
#  ('rationalist', 'press', 'association'): 26.045452223193784,
#  ('press', 'association', 'national'): 16.49086337151615,
#  ('association', 'national', 'secular'): 19.551798369776055,
#  ('national', 'secular', 'society'): 19.034399152867536,
#  ('secular', 'society', '8'): 13.351591294402697,
#  ('society', '8', '8'): 4.934373546675407,
#  ('8', '8', 'islington'): 13.709160606276582,
#  ('8', 'islington', 'high'): 17.96213885761792,
#  ('islington', 'high', 'street'): 23.990082202131447,
#  ('high', 'street', '7'): 9.978636531943739,
#  ('street', '7', '0'): 4.894213747345775,
#  ('7', '0', '2'): 3.543426371068198,
#  ('0', '2', 'holloway'): 9.179832609908981,
#  ('2', 'holloway', 'road'): 15.317936515745197,
#  ('holloway', 'road', 'london'): 23.225310692428764,
#  ('road', 'london', 'n'): 14.939908473566515,
#  ('london', 'n', '1'): 9.702616217643232,
#  ('n', '1', '8'): 2.171197409183278,
#  ('1', '8', 'ew'): 6.728679173482328,
#  ('8', 'ew', 'london'): 15.190730865285975,
#  ('ew', 'london', 'n'): 18.142725356566203,
#  ('n', '1', '9'): 1.4635161242179375,
#  ('1', '9', '3'): 4.4427281364955125,
#  ('9', '3', 'nl'): 6.468012453230151,
#  ('3', 'nl', 'nl'): 13.418737011479111,
#  ('nl', 'nl', 'nl'): 21.20089371598496,
#  ('nl', 'nl', '071 226'): 28.19524715284382,
#  ('nl', '071 226', '7'): 21.178154919514967,
#  ('071 226', '7', '2'): 13.237228183120376,
#  ('7', '2', '5'): 4.604433036133626,
#  ('2', '5', '1'): 4.591356369930579,
#  ('5', '1', '0'): 4.005535336549888,
#  ('1', '0', '7'): 4.235761244057572,
#  ('0', '7', '1'): 3.0231003607388964,
#  ('7', '1', '2'): 3.4054819774986385,
#  ('1', '2', '7'): 4.660159830976806,
#  ('2', '7', '2'): 3.9018608520540505,
#  ('2', '1', '2'): 3.889525182138872,
#  ('1', '2', '6'): 3.7166287508805462,
#  ('2', '6', '6'): 4.635519055110748,
#  ('6', '6', 'british'): 6.0174399250991115,
#  ('6', 'british', 'humanist'): 16.305003373602606,
#  ('british', 'humanist', 'association'): 23.289375289800322,
#  ('humanist', 'association', 'south'): 22.99508994998209,
#  ('association', 'south', 'place'): 16.88117978451019,
#  ('south', 'place', 'ethical'): 18.890640113759257,
#  ('place', 'ethical', 'society'): 18.093132977658,
#  ('ethical', 'society', '1'): 12.671281765143243,
#  ('society', '1', '4'): 3.4635288775701265,
#  ('1', '4', "lamb's"): 11.653353436450145,
#  ('4', "lamb's", 'conduit'): 23.33595620276607,
#  ("lamb's", 'conduit', 'passage'): 30.501617756850152,
#  ('conduit', 'passage', 'conway'): 28.279225335513708,
#  ('passage', 'conway', 'hall'): 24.578785617372613,
#  ('conway', 'hall', 'london'): 24.84089846773535,
#  ('hall', 'london', 'wc'): 21.582164199335182,
#  ('london', 'wc', '1'): 14.600001151160345,
#  ('wc', '1', 'r'): 9.448309016880394,
#  ('1', 'r', '4'): 6.651174843589544,
#  ('r', '4', 'rh'): 9.594479184308119,
#  ('4', 'rh', 'red'): 13.10696577308293,
#  ('rh', 'red', 'lion'): 23.51825205474118,
#  ('red', 'lion', 'square'): 23.132598362243428,
#  ('lion', 'square', 'square'): 25.45985990143383,
#  ('square', 'square', 'square'): 23.16440401790766,
#  ('square', 'square', '071 430'): 29.50425402079229,
#  ('square', '071 430', '0'): 20.77526278027781,
#  ('071 430', '0', '9'): 12.58507228733346,
#  ('0', '9', '0'): 2.891270475281285,
#  ('9', '0', '8'): 2.5176005786332967,
#  ('0', '8', 'london'): 6.849810076450073,
#  ('8', 'london', 'wc'): 14.852562129391401,
#  ('r', '4', 'rl'): 9.139284558557293,
#  ('4', 'rl', 'fax 071 430'): 21.31888268940713,
#  ('rl', 'fax 071 430', '1'): 20.284605402050303,
#  ('fax 071 430', '1', '2'): 11.758716164934553,
#  ('2', '7', '1'): 3.4054819774986385,
#  ('7', '1', '0'): 3.471690419728767,
#  ('7', '1', '8'): 3.399350268244694,
#  ('1', '8', '3'): 3.8093725036257857,
#  ('8', '3', '1'): 2.7244836060392723,
#  ('3', '1', '7'): 3.445199337743619,
#  ('1', '7', '7'): 4.965725746704214,
#  ('7', '7', '2'): 4.492569053627568,
#  ('7', '2', '3'): 3.6104651612603487,
#  ('2', '3', 'national'): 2.917574860265737,
#  ('3', 'national', 'secular'): 12.032676071104001,
#  ('secular', 'society', 'publish'): 21.743497953600798,
#  ('society', 'publish', 'freethinker'): 27.563676916015982,
#  ('publish', 'freethinker', 'monthly'): 30.57027965084023,
#  ('freethinker', 'monthly', 'magazine'): 28.523985998566296,
#  ('monthly', 'magazine', 'founded'): 22.851560656594803,
#  ('magazine', 'founded', '1'): 13.129787292998198,
#  ('founded', '1', '8'): 6.784174286074031,
#  ('1', '8', '8'): 4.00056263142771,
#  ('8', '8', '1'): 3.5411310127904123,
#  ('8', '1', 'germany'): 4.139187014280657,
#  ('1', 'germany', 'ibka'): 16.791621223701977,
#  ('germany', 'ibka', 'e'): 20.25661242820173,
#  ('ibka', 'e', 'v'): 17.394271423156177,
#  ('e', 'v', 'internationaler'): 16.979233923877334,
#  ('v', 'internationaler', 'bund'): 27.419237907029956,
#  ('internationaler', 'bund', 'der'): 34.02913591750943,
#  ('bund', 'der', 'konfessionslosen'): 34.02913591750943,
#  ('der', 'konfessionslosen', 'und'): 31.256546413612504,
#  ('konfessionslosen', 'und', 'atheisten'): 35.82640202194345,
#  ('und', 'atheisten', 'postfach'): 34.019047099885846,
#  ('atheisten', 'postfach', '8'): 24.139202394361455,
#  ('postfach', '8', '8'): 11.901805684218976,
#  ('8', '8', '0'): 3.3127447048489764,
#  ('8', '0', '1'): 3.2825761479543694,
#  ('0', '1', '0'): 4.487051188952688,
#  ('1', '0', '00 berlin 41'): 11.625155094788903,
#  ('0', '00 berlin 41', 'germany'): 18.797700169397565,
#  ('00 berlin 41', 'germany', 'ibka'): 31.28157891207551,
#  ('germany', 'ibka', 'publish'): 26.436088861131132,
#  ('ibka', 'publish', 'journal'): 27.68741228443823,
#  ('publish', 'journal', 'miz'): 27.950446690272027,
#  ('journal', 'miz', 'materialien'): 33.795936741216394,
#  ('miz', 'materialien', 'und'): 36.50447392705609,
#  ('materialien', 'und', 'informationen'): 37.82640202194345,
#  ('und', 'informationen', 'zur'): 35.2414395212223,
#  ('informationen', 'zur', 'zeit'): 38.01402902511922,
#  ('zur', 'zeit', 'politisches'): 38.01402902511922,
#  ('zeit', 'politisches', 'journal'): 33.5329023353826,
#  ('politisches', 'journal', 'der'): 29.548009227772816,
#  ('journal', 'der', 'konfessionslosesn'): 29.548009227772816,
#  ('der', 'konfessionslosesn', 'und'): 32.2565464136125,
#  ('konfessionslosesn', 'und', 'atheisten'): 36.82640202194345,
#  ('und', 'atheisten', 'hrsg'): 36.82640202194345,
#  ('atheisten', 'hrsg', 'ibka'): 39.59899152584038,
#  ('hrsg', 'ibka', 'e'): 28.5740250419666,
#  ('e', 'v', 'miz'): 16.65730582898997,
#  ('v', 'miz', 'vertrieb'): 28.682272312863752,
#  ('miz', 'vertrieb', 'postfach'): 38.05467100961657,
#  ('vertrieb', 'postfach', '8'): 25.139202394361455,
#  ('00 berlin 41', 'germany', 'atheist'): 24.251831568681457,
#  ('germany', 'atheist', 'book'): 15.093853118736023,
#  ('atheist', 'book', 'write'): 14.422581045728728,
#  ('book', 'write', 'ibdk'): 23.037290889843938,
#  ('write', 'ibdk', 'internationaler'): 32.19526933978937,
#  ('ibdk', 'internationaler', 'b'): 29.064040241109264,
#  ('internationaler', 'b', 'ucherdienst'): 29.064040241109264,
#  ('b', 'ucherdienst', 'der'): 24.494184632778317,
#  ('ucherdienst', 'der', 'konfessionslosen'): 35.61409841823058,
#  ('der', 'konfessionslosen', 'postfach'): 32.806743496172984,
#  ('konfessionslosen', 'postfach', '3'): 23.60008896313922,
#  ('postfach', '3', '0'): 9.531247719740122,
#  ('3', '0', '0'): 6.314155517757079,
#  ('0', '0', '5'): 3.6452920679996588,
#  ('0', '5', '3'): 2.770513184198793,
#  ('5', '3', '0'): 3.8202662193958927,
#  ('3', '0', '00 hannover 1'): 12.338602641797726,
#  ('0', '00 hannover 1', 'germany'): 18.797700169397565,
#  ('00 hannover 1', 'germany', 'telephone'): 26.46566197651448,
#  ('germany', 'telephone', '0511/2112'): 26.46566197651448,
#  ('telephone', '0511/2112', '1'): 19.29311690190582,
#  ('0511/2112', '1', '6'): 12.452236579297633,
#  ('1', '6', 'books'): 6.292365242519245,
#  ('6', 'books', 'fiction'): 16.04085594449163,
#  ('books', 'fiction', 'thomas'): 21.81909133011082,
#  ('fiction', 'thomas', 'disch'): 27.978962666889206,
#  ('thomas', 'disch', 'santa'): 26.893881165999442,
#  ('disch', 'santa', 'claus'): 32.10947802582704,
#  ('santa', 'claus', 'compromise'): 25.79659507054268,
#  ('claus', 'compromise', 'short'): 23.954258573567344,
#  ('compromise', 'short', 'story'): 18.38520246375555,
#  ('short', 'story', 'ultimate'): 18.8907304969823,
#  ('story', 'ultimate', 'proof'): 19.59671947591129,
#  ('ultimate', 'proof', 'santa'): 21.587154611875754,
#  ('proof', 'santa', 'exists'): 19.237162598570517,
#  ('santa', 'exists', 'character'): 19.275246100301995,
#  ('exists', 'character', 'event'): 17.273658103398805,
#  ('character', 'event', 'fictitious'): 23.84604253804049,
#  ('event', 'fictitious', 'similarity'): 27.126998851871548,
#  ('fictitious', 'similarity', 'living'): 27.711961352592702,
#  ('similarity', 'living', 'dead'): 20.471965112785334,
#  ('living', 'dead', 'god'): 13.936223171710223,
#  ('dead', 'god', 'uh'): 15.41121283040625,
#  ('god', 'uh', 'well'): 12.77776495769824,
#  ('uh', 'well', 'walter'): 18.328006468468466,
#  ('well', 'walter', 'miller'): 17.881871672444625,
#  ('walter', 'miller', 'jr'): 22.125959164880392,
#  ('miller', 'jr', 'canticle'): 27.755315784960004,
#  ('jr', 'canticle', 'leibowitz'): 33.96963490576076,
#  ('canticle', 'leibowitz', 'one'): 28.30111995501591,
#  ('leibowitz', 'one', 'gem'): 24.301119955015917,
#  ('one', 'gem', 'post'): 15.09716025177645,
#  ('gem', 'post', 'atomic'): 22.537050827473344,
#  ('post', 'atomic', 'doomsday'): 26.21512273258598,
#  ('atomic', 'doomsday', 'novel'): 31.41908243582544,
#  ('doomsday', 'novel', 'monk'): 32.46970850889541,
#  ('novel', 'monk', 'spent'): 26.553231864457693,
#  ('monk', 'spent', 'life'): 21.27943626524343,
#  ('spent', 'life', 'copying'): 19.481929129142173,
#  ('life', 'copying', 'blueprint'): 25.39840577357989,
#  ('copying', 'blueprint', 'saint'): 29.50227637135184,
#  ('blueprint', 'saint', 'leibowitz'): 33.69210093023186,
#  ('saint', 'leibowitz', 'filling'): 30.286108570556024,
#  ('leibowitz', 'filling', 'sheet'): 29.848703258248722,
#  ('filling', 'sheet', 'paper'): 22.170983616607714,
#  ('sheet', 'paper', 'ink'): 21.359745260062883,
#  ('paper', 'ink', 'leaving'): 21.30173965662732,
#  ('ink', 'leaving', 'white'): 20.880111487865133,
#  ('leaving', 'white', 'line'): 15.928920793233877,
#  ('white', 'line', 'letter'): 14.134825091781757,
#  ('line', 'letter', 'edgar'): 19.064247900742636,
#  ('letter', 'edgar', 'pangborn'): 29.554597406481925,
#  ('edgar', 'pangborn', 'davy'): 35.554597406481925,
#  ('pangborn', 'davy', 'post'): 29.52056270468477,
#  ('davy', 'post', 'atomic'): 24.077619208836044,
#  ('doomsday', 'novel', 'set'): 25.651354587888548,
#  ('novel', 'set', 'clerical'): 25.165927760718308,
#  ('set', 'clerical', 'state'): 19.107259510377737,
#  ('clerical', 'state', 'church'): 20.011869164735018,
#  ('state', 'church', 'example'): 11.937345379192173,
#  ('church', 'example', 'forbids'): 19.996013629532747,
#  ('example', 'forbids', 'anyone'): 18.282137162536294,
#  ('forbids', 'anyone', 'produce'): 20.284432620523955,
#  ('anyone', 'produce', 'describe'): 16.6994701198028,
#  ('produce', 'describe', 'use'): 16.017668637553243,
#  ('describe', 'use', 'substance'): 17.557401884281404,
#  ('use', 'substance', 'containing'): 17.448877427503234,
#  ('substance', 'containing', 'atom'): 23.24372647056907,
#  ('containing', 'atom', 'philip'): 24.374123107824744,
#  ('atom', 'philip', 'k'): 19.530148970691048,
#  ('philip', 'k', 'dick'): 20.08831141206849,
#  ('k', 'dick', 'philip'): 19.08831141206849,
#  ('dick', 'philip', 'k'): 19.08831141206849,
#  ('k', 'dick', 'dick'): 17.94903662346636,
#  ('dick', 'dick', 'wrote'): 19.85623059307261,
#  ('dick', 'wrote', 'many'): 14.978546554514901,
#  ('wrote', 'many', 'philosophical'): 15.901009954043879,
#  ('many', 'philosophical', 'thought'): 15.653992945547454,
#  ('philosophical', 'thought', 'provoking'): 23.973514542727724,
#  ('thought', 'provoking', 'short'): 20.730894313163574,
#  ('provoking', 'short', 'story'): 21.791194823431386,
#  ('short', 'story', 'novel'): 19.698085419039906,
#  ('story', 'novel', 'story'): 19.54998678005077,
#  ('novel', 'story', 'bizarre'): 23.460079807697635,
#  ('story', 'bizarre', 'time'): 16.50279635210922,
#  ('bizarre', 'time', 'approachable'): 25.3197799753646,
#  ('time', 'approachable', 'wrote'): 20.59640344594635,
#  ('approachable', 'wrote', 'mainly'): 26.15280746525258,
#  ('wrote', 'mainly', 'sf'): 19.85818671636095,
#  ('mainly', 'sf', 'wrote'): 19.85818671636095,
#  ('sf', 'wrote', 'people'): 14.069241593763119,
#  ('wrote', 'people', 'truth'): 11.39807805799266,
#  ('people', 'truth', 'religion'): 11.592674922082878,
#  ('truth', 'religion', 'rather'): 13.933094380015136,
#  ('religion', 'rather', 'technology'): 13.040897669549652,
#  ('rather', 'technology', 'although'): 13.463943391621143,
#  ('technology', 'although', 'often'): 14.119823132067687,
#  ('although', 'often', 'believed'): 16.778131782358894,
#  ('often', 'believed', 'met'): 19.056046700998117,
#  ('believed', 'met', 'sort'): 19.11771510089054,
#  ('met', 'sort', 'god'): 15.137789314877066,
#  ('sort', 'god', 'remained'): 16.5687181869258,
#  ('god', 'remained', 'sceptical'): 22.000135429393502,
#  ('remained', 'sceptical', 'amongst'): 27.894331341381093,
#  ('sceptical', 'amongst', 'novel'): 28.198112089558194,
#  ('amongst', 'novel', 'following'): 22.24034032494749,
#  ('novel', 'following', 'relevance'): 22.971153692132102,
#  ('following', 'relevance', 'galactic'): 23.971153692132102,
#  ('relevance', 'galactic', 'pot'): 28.289515171999273,
#  ('galactic', 'pot', 'healer'): 29.522175928789547,
#  ('pot', 'healer', 'fallible'): 30.821736210648453,
#  ('healer', 'fallible', 'alien'): 30.546876369417873,
#  ('fallible', 'alien', 'deity'): 28.528954461420607,
#  ('alien', 'deity', 'summons'): 28.90746608467434,
#  ('deity', 'summons', 'group'): 23.99518772335754,
#  ('summons', 'group', 'earth'): 20.302991999311356,
#  ('group', 'earth', 'craftsman'): 21.03995759347756,
#  ('earth', 'craftsman', 'woman'): 22.449302697520476,
#  ('craftsman', 'woman', 'remote'): 23.733155574861826,
#  ('woman', 'remote', 'planet'): 17.685122878440023,
#  ('remote', 'planet', 'raise'): 19.883902742554522,
#  ('planet', 'raise', 'giant'): 22.062239983813036,
#  ('raise', 'giant', 'cathedral'): 27.887880258898388,
#  ('giant', 'cathedral', 'beneath'): 30.948762501045408,
#  ('cathedral', 'beneath', 'ocean'): 31.41009365259819,
#  ('beneath', 'ocean', 'deity'): 27.877598571771166,
#  ('ocean', 'deity', 'begin'): 23.852936517536897,
#  ('deity', 'begin', 'demand'): 21.811713854810385,
#  ('begin', 'demand', 'faith'): 18.167145398893872,
#  ('demand', 'faith', 'earthers'): 23.879863446813403,
#  ('faith', 'earthers', 'pot'): 25.68976056343346,
#  ('earthers', 'pot', 'healer'): 31.352250927347235,
#  ('pot', 'healer', 'joe'): 25.39289291184458,
#  ('healer', 'joe', 'fernwright'): 30.732742914729204,
#  ('joe', 'fernwright', 'unable'): 27.41804638907292,
#  ('fernwright', 'unable', 'comply'): 31.73997448396028,
#  ('unable', 'comply', 'polished'): 29.155011983239127,
#  ('comply', 'polished', 'ironic'): 31.43408459916469,
#  ('polished', 'ironic', 'amusing'): 30.051614962342274,
#  ('ironic', 'amusing', 'novel'): 27.636577463063432,
#  ('amusing', 'novel', 'maze'): 30.186774545623912,
#  ('novel', 'maze', 'death'): 26.04456255614228,
#  ('maze', 'death', 'noteworthy'): 27.87463755469997,
#  ('death', 'noteworthy', 'description'): 22.112136868426624,
#  ('noteworthy', 'description', 'technology'): 21.5861924216607,
#  ('description', 'technology', 'based'): 14.999561100578926,
#  ('technology', 'based', 'religion'): 13.133746447973325,
#  ('based', 'religion', 'valis'): 21.991727443100896,
#  ('religion', 'valis', 'schizophrenic'): 30.74828376562498,
#  ('valis', 'schizophrenic', 'hero'): 35.16158621353308,
#  ('schizophrenic', 'hero', 'search'): 28.207389903146204,
#  ('hero', 'search', 'hidden'): 22.978571212650323,
#  ('search', 'hidden', 'mystery'): 22.02365910217886,
#  ('hidden', 'mystery', 'gnostic'): 27.977855412565738,
#  ('mystery', 'gnostic', 'christianity'): 25.734998888669576,
#  ('gnostic', 'christianity', 'reality'): 23.95072757972501,
#  ('christianity', 'reality', 'fired'): 19.11783756556027,
#  ('reality', 'fired', 'brain'): 19.88215364787143,
#  ('fired', 'brain', 'pink'): 21.985493397564113,
#  ('brain', 'pink', 'laser'): 21.623626557306608,
#  ('pink', 'laser', 'beam'): 23.330985689387493,
#  ('laser', 'beam', 'unknown'): 22.16264868484837,
#  ('beam', 'unknown', 'possibly'): 21.589221214493694,
#  ('unknown', 'possibly', 'divine'): 21.089375327410487,
#  ('possibly', 'divine', 'origin'): 20.88250081316395,
#  ('divine', 'origin', 'accompanied'): 24.521402120995912,
#  ('origin', 'accompanied', 'dogmatic'): 27.628930585300356,
#  ('accompanied', 'dogmatic', 'dismissively'): 34.66235358683781,
#  ('dogmatic', 'dismissively', 'atheist'): 30.176926759667566,
#  ('dismissively', 'atheist', 'friend'): 24.519395632995767,
#  ('atheist', 'friend', 'assorted'): 20.87553944322104,
#  ('friend', 'assorted', 'odd'): 23.03903817550392,
#  ('assorted', 'odd', 'character'): 24.1640742213487,
#  ('odd', 'character', 'divine'): 21.30808452404022,
#  ('character', 'divine', 'invasion'): 21.926405621707804,
#  ('divine', 'invasion', 'god'): 18.67161999446375,
#  ('invasion', 'god', 'invades'): 23.171465881546954,
#  ('god', 'invades', 'earth'): 19.97231016878089,
#  ('invades', 'earth', 'making'): 22.118485298093276,
#  ('earth', 'making', 'young'): 15.600815909959463,
#  ('making', 'young', 'woman'): 15.515218535501178,
#  ('young', 'woman', 'pregnant'): 19.74128661498103,
#  ('woman', 'pregnant', 'return'): 19.485816796395145,
#  ('pregnant', 'return', 'another'): 18.18349971993635,
#  ('return', 'another', 'star'): 15.060117304431065,
#  ('another', 'star', 'system'): 12.422805159646764,
#  ('star', 'system', 'unfortunately'): 14.81485934092477,
#  ('system', 'unfortunately', 'terminally'): 20.93824175643005,
#  ('unfortunately', 'terminally', 'ill'): 26.515803093769307,
#  ('terminally', 'ill', 'must'): 24.077632628942936,
#  ('ill', 'must', 'assisted'): 21.49267012822178,
#  ('must', 'assisted', 'dead'): 18.500601401858,
#  ('assisted', 'dead', 'man'): 19.175514974699233,
#  ('dead', 'man', 'whose'): 15.504437316189485,
#  ('man', 'whose', 'brain'): 16.622036924637126,
#  ('whose', 'brain', 'wired'): 21.828237312470986,
#  ('brain', 'wired', '2'): 14.956352220506044,
#  ('wired', '2', '4'): 8.208030951570223,
#  ('2', '4', 'hour'): 10.300019816067788,
#  ('4', 'hour', 'easy'): 10.364622218843499,
#  ('hour', 'easy', 'listening'): 18.630478060980188,
#  ('easy', 'listening', 'music'): 20.201173992628295,
#  ('listening', 'music', 'margaret'): 26.104625504270043,
#  ('music', 'margaret', 'atwood'): 30.972521968262697,
#  ('margaret', 'atwood', "handmaid's"): 38.05467100961657,
#  ('atwood', "handmaid's", 'tale'): 35.884746008174254,
#  ("handmaid's", 'tale', 'story'): 28.389690479806234,
#  ('tale', 'story', 'based'): 18.63313415728215,
#  ('story', 'based', 'premise'): 17.51238199782154,
#  ('based', 'premise', 'us'): 16.15506407660929,
#  ('premise', 'us', 'congress'): 17.917266962274518,
#  ('us', 'congress', 'mysteriously'): 22.43033654451389,
#  ('congress', 'mysteriously', 'assassinated'): 30.797283166923915,
#  ('mysteriously', 'assassinated', 'fundamentalist'): 32.984281681725165,
#  ('assassinated', 'fundamentalist', 'quickly'): 27.316578749996076,
#  ('fundamentalist', 'quickly', 'take'): 18.27452857110592,
#  ('quickly', 'take', 'charge'): 15.98648647037097,
#  ('take', 'charge', 'nation'): 15.296637397481978,
#  ('charge', 'nation', 'set'): 15.935371154644114,
#  ('nation', 'set', 'right'): 12.601623006957928,
#  ('set', 'right', 'book'): 10.386159062351735,
#  ('right', 'book', 'diary'): 16.896390687996266,
#  ('book', 'diary', "woman's"): 24.41864526286649,
#  ('diary', "woman's", 'life'): 24.30282811359766,
#  ("woman's", 'life', 'try'): 17.886923870501285,
#  ('life', 'try', 'live'): 12.636467530746957,
#  ('try', 'live', 'new'): 11.277040826160434,
#  ('live', 'new', 'christian'): 11.704260382484646,
#  ('new', 'christian', 'theocracy'): 19.861607317847486,
#  ('christian', 'theocracy', "women's"): 26.266010931152397,
#  ('theocracy', "women's", 'right'): 24.525990165586908,
#  ("women's", 'right', 'property'): 17.761118574850816,
#  ('right', 'property', 'revoked'): 20.289497547205606,
#  ('property', 'revoked', 'bank'): 24.202942879400307,
#  ('revoked', 'bank', 'account'): 23.66631827515385,
#  ('bank', 'account', 'closed'): 18.708546510543147,
#  ('account', 'closed', 'sinful'): 20.93884412996494,
#  ('closed', 'sinful', 'luxury'): 24.35769727558565,
#  ('sinful', 'luxury', 'outlawed'): 28.430946257616288,
#  ('luxury', 'outlawed', 'radio'): 24.986727732925498,
#  ('outlawed', 'radio', 'used'): 18.89066032318098,
#  ('radio', 'used', 'reading'): 13.631701772613104,
#  ('used', 'reading', 'bible'): 13.070151816844282,
#  ('reading', 'bible', 'crimes'): 22.726934181063278,
#  ('bible', 'crimes', 'punished'): 26.40093023091,
#  ('crimes', 'punished', 'retroactively'): 35.107138429510705,
#  ('punished', 'retroactively', 'doctor'): 28.176401091947817,
#  ('retroactively', 'doctor', 'performed'): 26.920061338688033,
#  ('doctor', 'performed', 'legal'): 19.074571287743655,
#  ('performed', 'legal', 'abortion'): 20.85150328922751,
#  ('legal', 'abortion', 'old'): 17.320666002367318,
#  ('abortion', 'old', 'world'): 14.715632102740694,
#  ('old', 'world', 'hunted'): 19.38401061164949,
#  ('world', 'hunted', 'hanged'): 25.341112653211777,
#  ('hunted', 'hanged', "atwood's"): 36.37659910450393,
#  ('hanged', "atwood's", 'writing'): 30.10446924273472,
#  ("atwood's", 'writing', 'style'): 26.636863692651723,
#  ('writing', 'style', 'difficult'): 18.56808541466631,
#  ('style', 'difficult', 'get'): 14.50530355985742,
#  ('difficult', 'get', 'used'): 10.994198650834061,
#  ('get', 'used', 'first'): 7.829357252059772,
#  ('used', 'first', 'tale'): 14.994343967195558,
#  ('first', 'tale', 'grows'): 21.580737003523154,
#  ('tale', 'grows', 'chilling'): 29.56642916683927,
#  ('grows', 'chilling', 'go'): 23.256573904252484,
#  ('chilling', 'go', 'various'): 19.12925507418803,
#  ('go', 'various', 'authors'): 18.79222008691046,
#  ('various', 'authors', 'bible'): 20.788184573675302,
#  ('authors', 'bible', 'somewhat'): 22.142913899842828,
#  ('bible', 'somewhat', 'dull'): 21.20431444450697,
#  ('somewhat', 'dull', 'rambling'): 27.588594548220314,
#  ('dull', 'rambling', 'work'): 23.493169956338402,
#  ('rambling', 'work', 'ha'): 15.490232673258847,
#  ('work', 'ha', 'often'): 10.20359790836615,
#  ('ha', 'often', 'criticized'): 17.14200133203639,
#  ('often', 'criticized', 'however'): 19.48859148115802,
#  ('criticized', 'however', 'probably'): 18.56772378679193,
#  ('however', 'probably', 'worth'): 13.49733445890053,
#  ('probably', 'worth', 'reading'): 14.833322497626433,
#  ('worth', 'reading', 'know'): 12.772633877665408,
#  ('reading', 'know', 'fuss'): 17.917023787000584,
#  ('know', 'fuss', 'exists'): 18.603597902926776,
#  ('fuss', 'exists', 'many'): 19.55226738496632,
#  ('exists', 'many', 'different'): 12.717380560737631,
#  ('many', 'different', 'version'): 11.805277728672689,
#  ('different', 'version', 'make'): 10.445319226347513,
#  ('version', 'make', 'sure'): 10.096113717207293,
#  ('make', 'sure', 'get'): 10.930187441607893,
#  ('sure', 'get', 'one'): 7.311795970288875,
#  ('get', 'one', 'true'): 7.081369959520703,
#  ('one', 'true', 'version'): 9.154186830728621,
#  ('true', 'version', 'books'): 15.877149565495854,
#  ('version', 'books', 'non'): 16.203088863266263,
#  ('books', 'non', 'fiction'): 20.5310716442929,
#  ('non', 'fiction', 'peter'): 18.06706149105783,
#  ('fiction', 'peter', 'de'): 18.12337725865118,
#  ('peter', 'de', 'rosa'): 20.006863249924752,
#  ('de', 'rosa', 'vicars'): 28.63074473993821,
#  ('rosa', 'vicars', 'christ'): 29.410093652598185,
#  ('vicars', 'christ', 'bantam'): 31.46071972566816,
#  ('christ', 'bantam', 'press'): 22.579605764993058,
#  ('bantam', 'press', '1'): 16.0055274554553,
#  ('press', '1', '9'): 8.492295247312883,
#  ('9', '8', '8'): 6.359029200462543,
#  ('8', '8', 'although'): 6.281498568132678,
#  ('8', 'although', 'de'): 9.238704486058248,
#  ('although', 'de', 'rosa'): 19.61812020107315,
#  ('de', 'rosa', 'seems'): 18.5189570041372,
#  ('rosa', 'seems', 'christian'): 18.52506089071969,
#  ('seems', 'christian', 'even'): 10.99206687969173,
#  ('christian', 'even', 'catholic'): 13.588154777208699,
#  ('even', 'catholic', 'enlighting'): 23.277279182121955,
#  ('catholic', 'enlighting', 'history'): 25.51470215656938,
#  ('enlighting', 'history', 'papal'): 29.329962276712333,
#  ('history', 'papal', 'immorality'): 26.62952255857124,
#  ('papal', 'immorality', 'adultery'): 32.028187088115885,
#  ('immorality', 'adultery', 'fallacy'): 29.6625376157992,
#  ('adultery', 'fallacy', 'etc'): 21.91744511491198,
#  ('fallacy', 'etc', 'german'): 18.301645210268234,
#  ('etc', 'german', 'translation'): 17.09627137282163,
#  ('german', 'translation', 'gottes'): 27.54180359184994,
#  ('translation', 'gottes', 'erste'): 33.912490998657155,
#  ('gottes', 'erste', 'diener'): 41.18395402656153,
#  ('erste', 'diener', 'die'): 32.90086567353753,
#  ('diener', 'die', 'dunkle'): 33.90086567353753,
#  ('die', 'dunkle', 'seite'): 33.90086567353753,
#  ('dunkle', 'seite', 'de'): 32.488725735065785,
#  ('seite', 'de', 'papsttums'): 32.488725735065785,
#  ('de', 'papsttums', 'droemer'): 32.488725735065785,
#  ('papsttums', 'droemer', 'knaur'): 42.18395402656154,
#  ('droemer', 'knaur', '1'): 26.693996338188004,
#  ('knaur', '1', '9'): 12.163955842359032,
#  ('9', '8', '9'): 5.858019878711884,
#  ('8', '9', 'michael'): 3.897863664916695,
#  ('9', 'michael', 'martin'): 10.975389038280781,
#  ('michael', 'martin', 'atheism'): 17.417966692859416,
#  ('martin', 'atheism', 'philosophical'): 21.510355093830707,
#  ('atheism', 'philosophical', 'justification'): 22.431821691284018,
#  ('philosophical', 'justification', 'temple'): 23.99572257647735,
#  ('justification', 'temple', 'university'): 17.21802762793998,
#  ('temple', 'university', 'press'): 15.575318406589961,
#  ('university', 'press', 'philadelphia'): 14.18001712537238,
#  ('press', 'philadelphia', 'usa'): 15.889621225078999,
#  ('philadelphia', 'usa', 'detailed'): 18.36134424961639,
#  ('usa', 'detailed', 'scholarly'): 20.922655482272905,
#  ('detailed', 'scholarly', 'justification'): 25.17860634648067,
#  ('scholarly', 'justification', 'atheism'): 23.500534441368032,
#  ('justification', 'atheism', 'contains'): 19.97850319637333,
#  ('atheism', 'contains', 'outstanding'): 21.968980422254827,
#  ('contains', 'outstanding', 'appendix'): 26.968980422254823,
#  ('outstanding', 'appendix', 'defining'): 29.804169552509155,
#  ('appendix', 'defining', 'terminology'): 29.297209563789274,
#  ('defining', 'terminology', 'usage'): 25.7699625609244,
#  ('terminology', 'usage', 'necessarily'): 22.69541560755935,
#  ('usage', 'necessarily', 'tendentious'): 25.642948187665215,
#  ('necessarily', 'tendentious', 'area'): 22.682118784945892,
#  ('tendentious', 'area', 'argues'): 26.756665738310943,
#  ('area', 'argues', 'negative'): 21.94931081625334,
#  ('argues', 'negative', 'atheism'): 23.437387221837533,
#  ('negative', 'atheism', 'e'): 15.456814857322208,
#  ('atheism', 'e', 'non'): 12.319980642348316,
#  ('e', 'non', 'belief'): 11.18344180940055,
#  ('non', 'belief', 'existence'): 15.089467220550823,
#  ('belief', 'existence', 'god'): 14.983341243677447,
#  ('existence', 'god', 'also'): 11.648802622772438,
#  ('god', 'also', 'positive'): 11.897378975912543,
#  ('also', 'positive', 'atheism'): 14.989514265512039,
#  ('positive', 'atheism', 'belief'): 17.587087292250843,
#  ('atheism', 'belief', 'non'): 15.120945452023992,
#  ('belief', 'non', 'existence'): 15.089467220550823,
#  ('non', 'existence', 'god'): 15.718833264620248,
#  ('existence', 'god', 'includes'): 14.471786893964017,
#  ('god', 'includes', 'great'): 12.594960815809724,
#  ('includes', 'great', 'refutation'): 19.916577951531988,
#  ('great', 'refutation', 'challenging'): 24.745243379835003,
#  ('refutation', 'challenging', 'argument'): 25.411214192492107,
#  ('challenging', 'argument', 'god'): 18.08959705676984,
#  ('argument', 'god', 'particular'): 12.934778947717737,
#  ('god', 'particular', 'attention'): 14.97917306707619,
#  ('particular', 'attention', 'paid'): 19.162533116722226,
#  ('attention', 'paid', 'refuting'): 25.147426224332015,
#  ('paid', 'refuting', 'contempory'): 32.43282844319426,
#  ('refuting', 'contempory', 'theist'): 33.5710855292705,
#  ('contempory', 'theist', 'platinga'): 35.741010530712806,
#  ('theist', 'platinga', 'swinburne'): 32.9336556086552,
#  ('platinga', 'swinburne', '5'): 24.975619632740255,
#  ('swinburne', '5', '4'): 10.519939231723551,
#  ('5', '4', '1'): 3.3130698963740235,
#  ('4', '1', 'page'): 3.9360578224240714,
#  ('1', 'page', 'isbn'): 12.038591397942692,
#  ('page', 'isbn', '0-87722'): 27.52854908631622,
#  ('isbn', '0-87722', '642-3'): 35.415769701784605,
#  ('0-87722', '642-3', 'hardcover'): 37.79163660378278,
#  ('642-3', 'hardcover', 'paperback'): 34.506234384920525,
#  ('hardcover', 'paperback', 'also'): 22.684659683983618,
#  ('paperback', 'also', 'available'): 15.795047079806935,
#  ('also', 'available', 'case'): 9.38957828937687,
#  ('available', 'case', 'christianity'): 12.739477775921731,
#  ('case', 'christianity', 'temple'): 16.497845846820162,
#  ('christianity', 'temple', 'university'): 14.984757152873014,
#  ('university', 'press', 'comprehensive'): 14.949133243142292,
#  ('press', 'comprehensive', 'critique'): 22.983167944939442,
#  ('comprehensive', 'critique', 'christianity'): 23.392606691222493,
#  ('critique', 'christianity', 'considers'): 24.86992846875568,
#  ('christianity', 'considers', 'best'): 18.904785524420177,
#  ('considers', 'best', 'contemporary'): 22.445723401249335,
#  ('best', 'contemporary', 'defence'): 21.41770902507974,
#  ('contemporary', 'defence', 'christianity'): 23.08110175646551,
#  ('defence', 'christianity', 'ultimately'): 22.488277137971384,
#  ('christianity', 'ultimately', 'demonstrates'): 23.407357142587816,
#  ('ultimately', 'demonstrates', 'unsupportable'): 31.87903235697986,
#  ('demonstrates', 'unsupportable', '/'): 22.677893953332127,
#  ('unsupportable', '/', 'incoherent'): 25.137325571969424,
#  ('/', 'incoherent', '2'): 10.202045398715972,
#  ('incoherent', '2', '7'): 10.915300088233012,
#  ('2', '7', '3'): 3.590001058700633,
#  ('7', '3', 'page'): 5.09374010026189,
#  ('3', 'page', 'isbn'): 12.752038944951515,
#  ('isbn', '0-87722', '767-5'): 35.415769701784605,
#  ('0-87722', '767-5', 'james'): 32.29673341109315,
#  ('767-5', 'james', 'turner'): 27.887342474955446,
#  ('james', 'turner', 'without'): 17.479012734188057,
#  ('turner', 'without', 'god'): 15.186635218806606,
#  ('without', 'god', 'without'): 11.187696414176916,
#  ('god', 'without', 'creed'): 16.292245406767204,
#  ('without', 'creed', 'johns'): 21.096804106270113,
#  ('creed', 'johns', 'hopkins'): 25.238347306342607,
#  ('johns', 'hopkins', 'university'): 23.446692808058415,
#  ('hopkins', 'university', 'press'): 16.639448744009677,
#  ('university', 'press', 'baltimore'): 16.131448225103405,
#  ('press', 'baltimore', 'md'): 18.127173570003077,
#  ('baltimore', 'md', 'usa'): 20.371912922272905,
#  ('md', 'usa', 'subtitled'): 23.288718986746506,
#  ('usa', 'subtitled', 'origins'): 29.10463592230753,
#  ('subtitled', 'origins', 'unbelief'): 38.01402902511922,
#  ('origins', 'unbelief', 'america'): 30.016849544181603,
#  ('unbelief', 'america', 'examines'): 31.279883950015396,
#  ('america', 'examines', 'way'): 21.407209069744788,
#  ('examines', 'way', 'unbelief'): 27.819426049961255,
#  ('way', 'unbelief', 'whether'): 19.57149853651767,
#  ('unbelief', 'whether', 'agnostic'): 25.707207822622067,
#  ('whether', 'agnostic', 'atheistic'): 23.83273870470593,
#  ('agnostic', 'atheistic', 'became'): 26.053866158805796,
#  ('atheistic', 'became', 'mainstream'): 26.226047134188477,
#  ('became', 'mainstream', 'alternative'): 21.97123323515965,
#  ('mainstream', 'alternative', 'world'): 18.284474938098576,
#  ('alternative', 'world', 'view'): 13.858682810768725,
#  ('world', 'view', 'focusses'): 21.57292832843485,
#  ('view', 'focusses', 'period'): 23.75822794208123,
#  ('focusses', 'period', '1770-1900'): 33.33376718891576,
#  ('period', '1770-1900', 'considering'): 25.697142568372115,
#  ('1770-1900', 'considering', 'france'): 27.759426846626457,
#  ('considering', 'france', 'britain'): 21.965010980276347,
#  ('france', 'britain', 'emphasis'): 23.79428067876239,
#  ('britain', 'emphasis', 'american'): 21.12172734184419,
#  ('emphasis', 'american', 'particularly'): 19.319953452049884,
#  ('american', 'particularly', 'new'): 13.4940860703067,
#  ('particularly', 'new', 'england'): 16.041652630386373,
#  ('new', 'england', 'development'): 15.219989871644884,
#  ('england', 'development', 'neither'): 18.747303666874515,
#  ('development', 'neither', 'religious'): 16.956289429659815,
#  ('neither', 'religious', 'history'): 16.2205899128376,
#  ('religious', 'history', 'secularization'): 23.7415359206876,
#  ('history', 'secularization', 'atheism'): 24.357976652881923,
#  ('secularization', 'atheism', 'without'): 23.10319894382265,
#  ('atheism', 'without', 'god'): 12.508563313693966,
#  ('without', 'creed', 'rather'): 16.62243843666928,
#  ('creed', 'rather', 'intellectual'): 21.14812512807483,
#  ('rather', 'intellectual', 'history'): 17.298353844543822,
#  ('intellectual', 'history', 'fate'): 21.721494190789482,
#  ('history', 'fate', 'single'): 18.554288690700762,
#  ('fate', 'single', 'idea'): 17.664813438814328,
#  ('single', 'idea', 'belief'): 13.86707651931832,
#  ('idea', 'belief', 'god'): 11.737326937919047,
#  ('belief', 'god', 'exists'): 14.62300728615075,
#  ('god', 'exists', '3'): 8.070498818984147,
#  ('exists', '3', '1'): 3.7601392614604525,
#  ('3', '1', '6'): 3.389971955599049,
#  ('1', '6', 'page'): 3.5650159638292482,
#  ('6', 'page', 'isbn'): 13.286789327425854,
#  ('page', 'isbn', 'hardcover'): 24.136231663537462,
#  ('isbn', 'hardcover', '0-8018'): 32.02345227900585,
#  ('hardcover', '0-8018', '2'): 22.856356430529324,
#  ('0-8018', '2', '4'): 11.792993452291379,
#  ('2', '4', '9'): 3.802111767570438,
#  ('4', '9', '4'): 2.9904802421427408,
#  ('9', '4', 'x'): 1.2129248324600068,
#  ('4', 'x', 'paper'): 6.0652456866479705,
#  ('x', 'paper', '0-8018'): 19.520926087664673,
#  ('paper', '0-8018', '3407-4'): 32.506234384920525,
#  ('0-8018', '3407-4', 'george'): 32.86202593167417,
#  ('3407-4', 'george', 'seldes'): 33.27706343095302,
#  ('george', 'seldes', 'editor'): 25.9327675230372,
#  ('seldes', 'editor', 'great'): 24.258928467046758,
#  ('editor', 'great', 'thought'): 14.96660683424472,
#  ('great', 'thought', 'ballantine'): 22.310902742160536,
#  ('thought', 'ballantine', 'books'): 26.14679855625995,
#  ('ballantine', 'books', 'new'): 24.390860385982357,
#  ('books', 'new', 'york'): 16.63263717125563,
#  ('new', 'york', 'usa'): 13.757584523138473,
#  ('york', 'usa', 'dictionary'): 16.196665588076126,
#  ('usa', 'dictionary', 'quotation'): 19.825605785857885,
#  ('dictionary', 'quotation', 'different'): 20.237147051718456,
#  ('quotation', 'different', 'kind'): 17.23884135025833,
#  ('different', 'kind', 'concentrating'): 19.667684649062203,
#  ('kind', 'concentrating', 'statement'): 20.539827642948858,
#  ('concentrating', 'statement', 'writing'): 22.193358180808005,
#  ('statement', 'writing', 'explicitly'): 18.860374897411646,
#  ('writing', 'explicitly', 'implicitly'): 24.213065246069696,
#  ('explicitly', 'implicitly', 'present'): 23.843401384521073,
#  ('implicitly', 'present', "person's"): 24.83243026670007,
#  ('present', "person's", 'philosophy'): 22.010931162322198,
#  ("person's", 'philosophy', 'world'): 19.42459335640548,
#  ('philosophy', 'world', 'view'): 14.893448228929403,
#  ('world', 'view', 'includes'): 13.159300399410677,
#  ('view', 'includes', 'obscure'): 19.065503833757866,
#  ('includes', 'obscure', 'often'): 19.447517720091177,
#  ('obscure', 'often', 'suppressed'): 23.77368280786501,
#  ('often', 'suppressed', 'opinion'): 18.774971503833584,
#  ('suppressed', 'opinion', 'many'): 16.742084671546014,
#  ('opinion', 'many', 'people'): 8.639722953916337,
#  ('many', 'people', 'popular'): 11.401395060646916,
#  ('people', 'popular', 'observation'): 15.310394639670832,
#  ('popular', 'observation', 'trace'): 21.242831355858197,
#  ('observation', 'trace', 'way'): 17.15151618911225,
#  ('trace', 'way', 'various'): 15.949292550033908,
#  ('way', 'various', 'people'): 10.016855833846542,
#  ('various', 'people', 'expressed'): 13.795013115332857,
#  ('people', 'expressed', 'twisted'): 17.642224026204573,
#  ('expressed', 'twisted', 'idea'): 19.789021301490045,
#  ('twisted', 'idea', 'century'): 19.69701193149489,
#  ('idea', 'century', 'quite'): 14.720181095949075,
#  ('century', 'quite', 'number'): 13.959884460502131,
#  ('quite', 'number', 'quotation'): 16.60209091305776,
#  ('number', 'quotation', 'derived'): 20.28556280591299,
#  ('quotation', 'derived', "cardiff's"): 31.08888672495448,
#  ('derived', "cardiff's", 'great'): 26.222402591021645,
#  ("cardiff's", 'great', 'men'): 23.122097685225963,
#  ('great', 'men', 'think'): 11.199327475951296,
#  ('men', 'think', 'religion'): 11.759424365892546,
#  ('think', 'religion', "noyes'"): 20.82551355635032,
#  ('religion', "noyes'", 'views'): 28.79408745523811,
#  ("noyes'", 'views', 'religion'): 28.79408745523811,
#  ('views', 'religion', '4'): 14.338407054221406,
#  ('religion', '4', '9'): 3.762562868779307,
#  ('4', '9', '0'): 3.0362824819252756,
#  ...}

# %%
mi_measures_sort=dict(sorted(mi_measures.items(), key=lambda item: item[1], reverse=True))

# %%
from collections import Counter

threegram_top=Counter(mi_measures).most_common(30)

# %%
threegram_top
# Out:
# [(('93090.1410', '01e62763@trmetu.bitnet', 'e62763@trmetu.bitnet'),
#   44.18395402656154),
#  (('31.230523', '13892@blaze.cs.jhu.edu', '11705@vice.ico.tek.com'),
#   44.18395402656154),
#  (('30.210423', '1302@bmerh85.bnr.ca', '1pcnqjinnpon@gap.caltech.edu'),
#   44.18395402656154),
#  (('4.1344', '733611641@po.cwru.edu', '1pi9btinnqa5@gap.calte'),
#   44.18395402656154),
#  (('30.205919', '26390@blaze.cs.jhu.edu', '1pcnp3innpom@gap.caltech.edu'),
#   44.18395402656154),
#  (('unixverstas', 'olutensin', 'finlandia'), 44.18395402656154),
#  (('nunca', 'llegare', 'cordoba'), 44.18395402656154),
#  (('calverts', 'fatti', 'maschii'), 44.18395402656154),
#  (('oys', '2clj@austin.ibm.com', 'yoder@austin.ibm.com'), 44.18395402656154),
#  (('twso', '8m2@hq.ileaf.com', 'mukesh@hq.ileaf.com'), 44.18395402656154),
#  (('8m2@hq.ileaf.com', 'mukesh@hq.ileaf.com', 'mukesh'), 44.18395402656154),
#  (('murtaza', "mutahhari's", "fundamental's"), 44.18395402656154),
#  (('cruell', 'nailes', 'plucke'), 44.18395402656154),
#  (('nailes', 'plucke', 'poore'), 44.18395402656154),
#  (('1q52q8inn6pi@gap.caltech.edu', '93099.2341', '44mvs104@psuvm.psu.edu'),
#   44.18395402656154),
#  (('93099.2341', '44mvs104@psuvm.psu.edu', '1q8lk3innitq@gap.caltech.edu'),
#   44.18395402656154),
#  (('44mvs104@psuvm.psu.edu', '1q8lk3innitq@gap.caltech.edu', '93102.0629'),
#   44.18395402656154),
#  (('1q8lk3innitq@gap.caltech.edu', '93102.0629', '08mvs104@psuvm.psu.edu'),
#   44.18395402656154),
#  (('93102.0629', '08mvs104@psuvm.psu.edu', '93105.0226'), 44.18395402656154),
#  (('08mvs104@psuvm.psu.edu', '93105.0226', '21tan102@psuvm.psu.edu'),
#   44.18395402656154),
#  (('3.183303', '6442@usl.edu', 'jna8182@ucs.usl.edu'), 44.18395402656154),
#  (('kiedas', 'rhcp', 'mbh2@engr.engr.uark.edu'), 44.18395402656154),
#  (('6.144520', '2190@unocal.com', 'h48vtis@zola.esd.sgi.com'),
#   44.18395402656154),
#  (('lform', 'lmenu', 'lpanel'), 44.18395402656154),
#  (('delauney', 'criiterion', 'krige'), 44.18395402656154),
#  (('20019', 'settimo', 'milanese'), 44.18395402656154),
#  (('466666', 'shankley', 'bob@black.ox.ac.uk'), 44.18395402656154),
#  (('8.122037', '19260@sun1x.res.utc.com', 'mark@sun1x.res.utc.com'),
#   44.18395402656154),
#  (('cymdeithas', 'genedlaethol', 'traddodiad'), 44.18395402656154),
#  (('archchancellor', 'mustrum', 'ridcully'), 44.18395402656154)]

# %%
with open("threegram_top.txt", "w") as f:
    for key in mi_measures_sort:
        f.write(str(key))
        f.write(str(mi_measures_sort[key]))
        f.write('\n')
f.close()

# %% [markdown]
# Проверка

# %%
import nltk
from nltk.collocations import *


trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder = TrigramCollocationFinder.from_words(data)

for i in finder.score_ngrams(trigram_measures.pmi):
    print(i)
